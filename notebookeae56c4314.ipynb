# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/altiarikaeka/features-all-10methods/Features_All_10Methods(2).csv

# %%
import pandas as pd
import os

csv_path = "/kaggle/input/datasets/altiarikaeka/features-all-10methods/Features_All_10Methods(2).csv"

df_features = pd.read_csv(csv_path)

print("Dataset berhasil diload.")
print("Shape dataset:", df_features.shape)

print("\nNama kolom:")
print(df_features.columns.tolist())

print("\nPreview data:")
display(df_features.head())
# Out:
# Dataset berhasil diload.
# Shape dataset: (4936, 213)
#
# Nama kolom:
# ['Epoch', 'subject_file', 'Condition', 'Label', 'epoch_id', 'RAW_TP9_BP_Delta', 'RAW_TP9_BP_Theta', 'RAW_TP9_BP_Alpha', 'RAW_TP9_BP_Beta', 'RAW_TP9_BP_Gamma', 'RAW_TP9_RP_Delta', 'RAW_TP9_RP_Theta', 'RAW_TP9_RP_Alpha', 'RAW_TP9_RP_Beta', 'RAW_TP9_RP_Gamma', 'RAW_TP9_EN', 'RAW_TP9_HJ_Activity', 'RAW_TP9_HJ_Mobility', 'RAW_TP9_HJ_Complexity', 'RAW_TP9_SF', 'RAW_TP9_SR_85', 'RAW_TP9_DWT_A5_Energy', 'RAW_TP9_DWT_A5_Entropy', 'RAW_TP9_DWT_A5_MAV', 'RAW_TP9_DWT_D5_Energy', 'RAW_TP9_DWT_D5_Entropy', 'RAW_TP9_DWT_D5_MAV', 'RAW_TP9_DWT_D4_Energy', 'RAW_TP9_DWT_D4_Entropy', 'RAW_TP9_DWT_D4_MAV', 'RAW_TP9_DWT_D3_Energy', 'RAW_TP9_DWT_D3_Entropy', 'RAW_TP9_DWT_D3_MAV', 'RAW_TP9_DWT_D2_Energy', 'RAW_TP9_DWT_D2_Entropy', 'RAW_TP9_DWT_D2_MAV', 'RAW_TP9_DWT_D1_Energy', 'RAW_TP9_DWT_D1_Entropy', 'RAW_TP9_DWT_D1_MAV', 'RAW_TP9_WP_L3_Node0_Energy', 'RAW_TP9_WP_L3_Node0_Entropy', 'RAW_TP9_WP_L3_Node1_Energy', 'RAW_TP9_WP_L3_Node1_Entropy', 'RAW_TP9_WP_L3_Node2_Energy', 'RAW_TP9_WP_L3_Node2_Entropy', 'RAW_TP9_WP_L3_Node3_Energy', 'RAW_TP9_WP_L3_Node3_Entropy', 'RAW_TP9_WP_L3_Node4_Energy', 'RAW_TP9_WP_L3_Node4_Entropy', 'RAW_TP9_WP_L3_Node5_Energy', 'RAW_TP9_WP_L3_Node5_Entropy', 'RAW_TP9_WP_L3_Node6_Energy', 'RAW_TP9_WP_L3_Node6_Entropy', 'RAW_TP9_WP_L3_Node7_Energy', 'RAW_TP9_WP_L3_Node7_Entropy', 'RAW_TP9_ZCR', 'RAW_TP9_RMS', 'RAW_AF7_BP_Delta', 'RAW_AF7_BP_Theta', 'RAW_AF7_BP_Alpha', 'RAW_AF7_BP_Beta', 'RAW_AF7_BP_Gamma', 'RAW_AF7_RP_Delta', 'RAW_AF7_RP_Theta', 'RAW_AF7_RP_Alpha', 'RAW_AF7_RP_Beta', 'RAW_AF7_RP_Gamma', 'RAW_AF7_EN', 'RAW_AF7_HJ_Activity', 'RAW_AF7_HJ_Mobility', 'RAW_AF7_HJ_Complexity', 'RAW_AF7_SF', 'RAW_AF7_SR_85', 'RAW_AF7_DWT_A5_Energy', 'RAW_AF7_DWT_A5_Entropy', 'RAW_AF7_DWT_A5_MAV', 'RAW_AF7_DWT_D5_Energy', 'RAW_AF7_DWT_D5_Entropy', 'RAW_AF7_DWT_D5_MAV', 'RAW_AF7_DWT_D4_Energy', 'RAW_AF7_DWT_D4_Entropy', 'RAW_AF7_DWT_D4_MAV', 'RAW_AF7_DWT_D3_Energy', 'RAW_AF7_DWT_D3_Entropy', 'RAW_AF7_DWT_D3_MAV', 'RAW_AF7_DWT_D2_Energy', 'RAW_AF7_DWT_D2_Entropy', 'RAW_AF7_DWT_D2_MAV', 'RAW_AF7_DWT_D1_Energy', 'RAW_AF7_DWT_D1_Entropy', 'RAW_AF7_DWT_D1_MAV', 'RAW_AF7_WP_L3_Node0_Energy', 'RAW_AF7_WP_L3_Node0_Entropy', 'RAW_AF7_WP_L3_Node1_Energy', 'RAW_AF7_WP_L3_Node1_Entropy', 'RAW_AF7_WP_L3_Node2_Energy', 'RAW_AF7_WP_L3_Node2_Entropy', 'RAW_AF7_WP_L3_Node3_Energy', 'RAW_AF7_WP_L3_Node3_Entropy', 'RAW_AF7_WP_L3_Node4_Energy', 'RAW_AF7_WP_L3_Node4_Entropy', 'RAW_AF7_WP_L3_Node5_Energy', 'RAW_AF7_WP_L3_Node5_Entropy', 'RAW_AF7_WP_L3_Node6_Energy', 'RAW_AF7_WP_L3_Node6_Entropy', 'RAW_AF7_WP_L3_Node7_Energy', 'RAW_AF7_WP_L3_Node7_Entropy', 'RAW_AF7_ZCR', 'RAW_AF7_RMS', 'RAW_AF8_BP_Delta', 'RAW_AF8_BP_Theta', 'RAW_AF8_BP_Alpha', 'RAW_AF8_BP_Beta', 'RAW_AF8_BP_Gamma', 'RAW_AF8_RP_Delta', 'RAW_AF8_RP_Theta', 'RAW_AF8_RP_Alpha', 'RAW_AF8_RP_Beta', 'RAW_AF8_RP_Gamma', 'RAW_AF8_EN', 'RAW_AF8_HJ_Activity', 'RAW_AF8_HJ_Mobility', 'RAW_AF8_HJ_Complexity', 'RAW_AF8_SF', 'RAW_AF8_SR_85', 'RAW_AF8_DWT_A5_Energy', 'RAW_AF8_DWT_A5_Entropy', 'RAW_AF8_DWT_A5_MAV', 'RAW_AF8_DWT_D5_Energy', 'RAW_AF8_DWT_D5_Entropy', 'RAW_AF8_DWT_D5_MAV', 'RAW_AF8_DWT_D4_Energy', 'RAW_AF8_DWT_D4_Entropy', 'RAW_AF8_DWT_D4_MAV', 'RAW_AF8_DWT_D3_Energy', 'RAW_AF8_DWT_D3_Entropy', 'RAW_AF8_DWT_D3_MAV', 'RAW_AF8_DWT_D2_Energy', 'RAW_AF8_DWT_D2_Entropy', 'RAW_AF8_DWT_D2_MAV', 'RAW_AF8_DWT_D1_Energy', 'RAW_AF8_DWT_D1_Entropy', 'RAW_AF8_DWT_D1_MAV', 'RAW_AF8_WP_L3_Node0_Energy', 'RAW_AF8_WP_L3_Node0_Entropy', 'RAW_AF8_WP_L3_Node1_Energy', 'RAW_AF8_WP_L3_Node1_Entropy', 'RAW_AF8_WP_L3_Node2_Energy', 'RAW_AF8_WP_L3_Node2_Entropy', 'RAW_AF8_WP_L3_Node3_Energy', 'RAW_AF8_WP_L3_Node3_Entropy', 'RAW_AF8_WP_L3_Node4_Energy', 'RAW_AF8_WP_L3_Node4_Entropy', 'RAW_AF8_WP_L3_Node5_Energy', 'RAW_AF8_WP_L3_Node5_Entropy', 'RAW_AF8_WP_L3_Node6_Energy', 'RAW_AF8_WP_L3_Node6_Entropy', 'RAW_AF8_WP_L3_Node7_Energy', 'RAW_AF8_WP_L3_Node7_Entropy', 'RAW_AF8_ZCR', 'RAW_AF8_RMS', 'RAW_TP10_BP_Delta', 'RAW_TP10_BP_Theta', 'RAW_TP10_BP_Alpha', 'RAW_TP10_BP_Beta', 'RAW_TP10_BP_Gamma', 'RAW_TP10_RP_Delta', 'RAW_ ...
#
# Preview data:
#    Epoch subject_file Condition  Label  epoch_id  RAW_TP9_BP_Delta  \
# 0      1        02ACF       ACF      1         0      1.498542e-07
# 1      2        02ACF       ACF      1         1      4.402825e-02
# 2      3        02ACF       ACF      1         2      1.981095e-02
# 3      4        02ACF       ACF      1         3      1.130674e-02
# 4      5        02ACF       ACF      1         4      8.442294e-03
#
#    RAW_TP9_BP_Theta  RAW_TP9_BP_Alpha  RAW_TP9_BP_Beta  RAW_TP9_BP_Gamma  ...  \
# 0      5.019572e-10      3.714421e-11     6.335135e-12      4.116387e-09  ...
# 1      3.478229e-02      1.509126e-02     5.982610e-02      5.150761e-01  ...
# 2      1.233861e-02      5.041333e-03     2.000281e-02      1.857348e-01  ...
# 3      2.580498e-02      2.544501e-02     6.363840e-02      4.459326e-01  ...
# 4      2.468260e-02      2.471044e-02     6.182528e-02      4.261384e-01  ...
#
#    RAW_TP10_WP_L3_Node4_Energy  RAW_TP10_WP_L3_Node4_Entropy  \
# 0                 1.073185e+01                      2.439930
# 1                 1.073185e+01                      2.439936
# 2                 3.625643e-07                      1.365571
# 3                 1.964156e-29                      6.129283
# 4                 1.964156e-29                      6.129283
#
#    RAW_TP10_WP_L3_Node5_Energy  RAW_TP10_WP_L3_Node5_Entropy  \
# 0                 9.385586e+00                      2.224980
# 1                 9.385565e+00                      2.224935
# 2                 6.638811e-08                      1.247912
# 3                 1.752716e-28                      6.129283
# 4                 1.752716e-28                      6.129283
#
#    RAW_TP10_WP_L3_Node6_Energy  RAW_TP10_WP_L3_Node6_Entropy  \
# 0                 2.362078e+00                      1.035868
# 1                 2.362077e+00                      1.035866
# 2                 1.382166e-08                      1.743298
# 3                 2.990023e-29                      6.129283
# 4                 2.990023e-29                      6.129283
#
#    RAW_TP10_WP_L3_Node7_Energy  RAW_TP10_WP_L3_Node7_Entropy  RAW_TP10_ZCR  \
# 0                 3.471412e+00                      0.615517           0.0
# 1                 3.471412e+00                      0.615516           0.0
# 2                 8.392461e-08                      1.810856           0.0
# 3                 1.386103e-26                      6.129283           0.0
# 4                 1.386103e-26                      6.129283           0.0
#
#    RAW_TP10_RMS
# 0    481.630658
# 1    481.630648
# 2    481.583145
# 3    481.583156
# 4    481.583156
#
# [5 rows x 213 columns]

# %%
required_cols = ["Label", "Condition", "subject_file"]

for col in required_cols:
    if col in df_features.columns:
        print(f"{col}: ADA")
    else:
        print(f"{col}: TIDAK ADA")

print("\nDistribusi Label:")
print(df_features["Label"].value_counts())

print("\nDistribusi Condition:")
print(df_features["Condition"].value_counts())
# Out:
# Label: ADA
# Condition: ADA
# subject_file: ADA
#
# Distribusi Label:
# Label
# 1    2481
# 0    2455
# Name: count, dtype: int64
#
# Distribusi Condition:
# Condition
# BCM    860
# ACF    842
# ACM    840
# BCF    835
# BM     449
# AM     428
# AF     371
# BF     311
# Name: count, dtype: int64

# %%
# ============================================================
# TAHAP 1: Filter Gamma & Persiapan Data
# ============================================================

# 1. Definisikan 8 kolom Gamma
gamma_cols = [
    'RAW_TP9_BP_Gamma',  'RAW_TP9_RP_Gamma',
    'RAW_AF7_BP_Gamma',  'RAW_AF7_RP_Gamma',
    'RAW_AF8_BP_Gamma',  'RAW_AF8_RP_Gamma',
    'RAW_TP10_BP_Gamma', 'RAW_TP10_RP_Gamma'
]

# 2. Kolom metadata (bukan fitur, tidak masuk model)
metadata_cols = ['Epoch', 'subject_file', 'Condition', 'Label', 'epoch_id']

# 3. Pastikan semua kolom ada di dataframe
missing_gamma = [c for c in gamma_cols if c not in df_features.columns]
missing_meta  = [c for c in metadata_cols if c not in df_features.columns]

if missing_gamma:
    print(f"PERINGATAN: Kolom Gamma tidak ditemukan: {missing_gamma}")
else:
    print("Semua 8 kolom Gamma ditemukan.")

if missing_meta:
    print(f"PERINGATAN: Kolom metadata tidak ditemukan: {missing_meta}")
else:
    print("Semua kolom metadata ditemukan.")

# 4. Pisahkan X, y, dan metadata
X_gamma = df_features[gamma_cols].copy()
y       = df_features['Label'].copy()
metadata = df_features[['Epoch', 'subject_file', 'Condition', 'Label']].copy()

# 5. Verifikasi hasil
print(f"\nShape X (fitur Gamma) : {X_gamma.shape}")
print(f"Shape y (label)       : {y.shape}")
print(f"Shape metadata         : {metadata.shape}")

print(f"\nDistribusi label:")
print(y.value_counts().sort_index())

print(f"\nDistribusi kondisi:")
print(metadata['Condition'].value_counts().sort_index())

print(f"\nPreview X_gamma (5 baris pertama):")
display(X_gamma.head())

print(f"\nStatistik deskriptif X_gamma:")
display(X_gamma.describe())
# Out:
# Semua 8 kolom Gamma ditemukan.
# Semua kolom metadata ditemukan.
#
# Shape X (fitur Gamma) : (4936, 8)
# Shape y (label)       : (4936,)
# Shape metadata         : (4936, 4)
#
# Distribusi label:
# Label
# 0    2455
# 1    2481
# Name: count, dtype: int64
#
# Distribusi kondisi:
# Condition
# ACF    842
# ACM    840
# AF     371
# AM     428
# BCF    835
# BCM    860
# BF     311
# BM     449
# Name: count, dtype: int64
#
# Preview X_gamma (5 baris pertama):
#    RAW_TP9_BP_Gamma  RAW_TP9_RP_Gamma  RAW_AF7_BP_Gamma  RAW_AF7_RP_Gamma  \
# 0      4.116387e-09          0.010032      9.833416e-59      7.608237e-33
# 1      5.150761e-01          0.518903      9.833416e-59      7.608237e-33
# 2      1.857348e-01          0.524463      9.833416e-59      7.608237e-33
# 3      4.459326e-01          0.554741      9.833416e-59      7.608237e-33
# 4      4.261384e-01          0.554065      9.833416e-59      7.608237e-33
#
#    RAW_AF8_BP_Gamma  RAW_AF8_RP_Gamma  RAW_TP10_BP_Gamma  RAW_TP10_RP_Gamma
# 0      1.366704e+00      5.450516e-01       1.384760e-01       5.091131e-01
# 1      4.459938e-01      5.357820e-01       1.662135e-01       5.121564e-01
# 2      7.624088e-01      5.267878e-01       1.217520e-13       8.141701e-04
# 3      3.549939e-01      5.142743e-01       9.833416e-59       7.608237e-33
# 4      9.833416e-59      7.608237e-33       9.833416e-59       7.608237e-33
# Statistik deskriptif X_gamma:
#        RAW_TP9_BP_Gamma  RAW_TP9_RP_Gamma  RAW_AF7_BP_Gamma  RAW_AF7_RP_Gamma  \
# count      4.936000e+03      4.936000e+03      4.936000e+03      4.936000e+03
# mean       1.438060e+01      6.599833e-02      5.979565e+00      3.842324e-02
# std        1.184006e+02      1.624035e-01      1.510174e+02      1.277445e-01
# min        0.000000e+00      0.000000e+00      9.833416e-59      7.608237e-33
# 25%        9.833416e-59      7.608237e-33      9.833416e-59      7.608237e-33
# 50%        9.833416e-59      7.608237e-33      9.833416e-59      7.608237e-33
# 75%        9.833416e-59      7.608237e-33      9.833416e-59      7.608237e-33
# max        3.271271e+03      6.880419e-01      5.682733e+03      6.377864e-01
#
#        RAW_AF8_BP_Gamma  RAW_AF8_RP_Gamma  RAW_TP10_BP_Gamma  \
# count      4.936000e+03      4.936000e+03       4.936000e+03
# mean       1.096578e+01      4.454763e-02       1.094966e+01
# std        6.431769e+01      1.344898e-01       1.034585e+02
# min        0.000000e+00      0.000000e+00       0.000000e+00
# 25%        9.833416e-59      7.608237e-33       9.833416e-59
# 50%        9.833416e-59      7.608237e-33       9.833416e-59
# 75%        9.833416e-59      7.608237e-33       9.833416e-59
# max        1.804928e+03      6.410295e-01       3.345453e+03
#
#        RAW_TP10_RP_Gamma
# count       4.936000e+03
# mean        5.395804e-02
# std         1.475783e-01
# min         0.000000e+00
# 25%         7.608237e-33
# 50%         7.608237e-33
# 75%         7.608237e-33
# max         6.202188e-01

# %%
# ============================================================
# TAHAP 2: Train-Validation-Test Split + Scaling
# ============================================================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# ---- 1. Train/Val/Test Split (70/15/15) dengan stratify ----
# Pertama: pisahkan test set (15%)
X_trainval, X_test, y_trainval, y_test, meta_trainval, meta_test = train_test_split(
    X_gamma, y, metadata,
    test_size=0.15,
    random_state=42,
    stratify=y
)

# Kedua: pisahkan train dan validation dari sisa (85%)
# 15% dari 85% ≈ 17.6% dari total, sehingga train ≈ 70%, val ≈ 15%, test ≈ 15%
X_train, X_val, y_train, y_val, meta_train, meta_val = train_test_split(
    X_trainval, y_trainval, meta_trainval,
    test_size=0.176,  # 0.176 dari 85% ≈ 15% dari total
    random_state=42,
    stratify=y_trainval
)

print("=== Ukuran Split ===")
print(f"Train      : {X_train.shape[0]} sampel ({X_train.shape[0]/len(X_gamma)*100:.1f}%)")
print(f"Validation : {X_val.shape[0]} sampel ({X_val.shape[0]/len(X_gamma)*100:.1f}%)")
print(f"Test       : {X_test.shape[0]} sampel ({X_test.shape[0]/len(X_gamma)*100:.1f}%)")
print(f"Total      : {X_train.shape[0] + X_val.shape[0] + X_test.shape[0]} sampel")

# ---- 2. Cek distribusi label di setiap split ----
print("\n=== Distribusi Label per Split ===")
for name, ys in [("Train", y_train), ("Validation", y_val), ("Test", y_test)]:
    dist = ys.value_counts().sort_index()
    print(f"{name:12s} -> Label 0: {dist[0]:5d}, Label 1: {dist[1]:5d}, "
          f"Ratio 0:1 = {dist[0]/dist[1]:.2f}")

# ---- 3. Scaling (fit hanya pada training data!) ----
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)   # fit + transform
X_val_scaled   = scaler.transform(X_val)          # transform saja
X_test_scaled  = scaler.transform(X_test)         # transform saja

print("\n=== Setelah Scaling (statistik X_train) ===")
print(f"Mean (seharusnya ~0): {X_train_scaled.mean(axis=0).round(4)}")
print(f"Std  (seharusnya ~1): {X_train_scaled.std(axis=0).round(4)}")

# ---- 4. Reshape untuk CNN: (samples, 8, 1) ----
X_train_cnn = X_train_scaled.reshape(-1, 8, 1)
X_val_cnn   = X_val_scaled.reshape(-1, 8, 1)
X_test_cnn  = X_test_scaled.reshape(-1, 8, 1)

print(f"\n=== Shape untuk CNN ===")
print(f"X_train_cnn : {X_train_cnn.shape}")
print(f"X_val_cnn   : {X_val_cnn.shape}")
print(f"X_test_cnn  : {X_test_cnn.shape}")

# ---- 5. Simpan juga versi unscaled untuk RF (Random Forest tidak butuh scaling) ----
X_train_unscaled = X_train.values
X_val_unscaled   = X_val.values
X_test_unscaled  = X_test.values

print("\nTahap 2 selesai. Variabel yang tersedia:")
print("  - X_train_scaled, X_val_scaled, X_test_scaled  (untuk SVM)")
print("  - X_train_cnn, X_val_cnn, X_test_cnn          (untuk CNN)")
print("  - X_train_unscaled, X_val_unscaled, X_test_unscaled (untuk RF)")
print("  - y_train, y_val, y_test                       (target)")
print("  - meta_train, meta_val, meta_test              (metadata)")
print("  - scaler (StandardScaler yang sudah di-fit)")
# Out:
# === Ukuran Split ===
# Train      : 3456 sampel (70.0%)
# Validation : 739 sampel (15.0%)
# Test       : 741 sampel (15.0%)
# Total      : 4936 sampel
#
# === Distribusi Label per Split ===
# Train        -> Label 0:  1719, Label 1:  1737, Ratio 0:1 = 0.99
# Validation   -> Label 0:   367, Label 1:   372, Ratio 0:1 = 0.99
# Test         -> Label 0:   369, Label 1:   372, Ratio 0:1 = 0.99
#
# === Setelah Scaling (statistik X_train) ===
# Mean (seharusnya ~0): [-0.  0. -0.  0.  0. -0. -0. -0.]
# Std  (seharusnya ~1): [1. 1. 1. 1. 1. 1. 1. 1.]
#
# === Shape untuk CNN ===
# X_train_cnn : (3456, 8, 1)
# X_val_cnn   : (739, 8, 1)
# X_test_cnn  : (741, 8, 1)
#
# Tahap 2 selesai. Variabel yang tersedia:
#   - X_train_scaled, X_val_scaled, X_test_scaled  (untuk SVM)
#   - X_train_cnn, X_val_cnn, X_test_cnn          (untuk CNN)
#   - X_train_unscaled, X_val_unscaled, X_test_unscaled (untuk RF)
#   - y_train, y_val, y_test                       (target)
#   - meta_train, meta_val, meta_test              (metadata)
#   - scaler (StandardScaler yang sudah di-fit)

# %%
# ============================================================
# TAHAP 3A: Baseline SVM (Support Vector Machine)
# ============================================================

from sklearn.svm import SVC
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, confusion_matrix, classification_report)
import time

# ---- 1. Training ----
print("Training SVM (RBF kernel)...")
start = time.time()

svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm_model.fit(X_train_scaled, y_train)

train_time = time.time() - start
print(f"Training selesai dalam {train_time:.2f} detik")

# ---- 2. Prediksi ----
y_pred_val_svm  = svm_model.predict(X_val_scaled)
y_pred_test_svm = svm_model.predict(X_test_scaled)

# ---- 3. Evaluasi Validation Set ----
print("\n" + "="*50)
print("HASIL SVM - VALIDATION SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_svm):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_svm, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_svm, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_svm, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_svm)}")
print(f"\n{classification_report(y_val, y_pred_val_svm, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# ---- 4. Evaluasi Test Set ----
print("="*50)
print("HASIL SVM - TEST SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_svm):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_svm, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_svm, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_svm, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_svm)}")
print(f"\n{classification_report(y_test, y_pred_test_svm, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# Training SVM (RBF kernel)...
# Training selesai dalam 0.37 detik
#
# ==================================================
# HASIL SVM - VALIDATION SET
# ==================================================
# Accuracy  : 0.5940
# Precision : 0.6587
# Recall    : 0.5940
# F1-Score  : 0.5458
#
# Confusion Matrix:
# [[ 98 269]
#  [ 31 341]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.76      0.27      0.40       367
#  Label 1 (After)       0.56      0.92      0.69       372
#
#         accuracy                           0.59       739
#        macro avg       0.66      0.59      0.54       739
#     weighted avg       0.66      0.59      0.55       739
#
# ==================================================
# HASIL SVM - TEST SET
# ==================================================
# Accuracy  : 0.5749
# Precision : 0.6333
# Recall    : 0.5749
# F1-Score  : 0.5210
#
# Confusion Matrix:
# [[ 88 281]
#  [ 34 338]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.72      0.24      0.36       369
#  Label 1 (After)       0.55      0.91      0.68       372
#
#         accuracy                           0.57       741
#        macro avg       0.63      0.57      0.52       741
#     weighted avg       0.63      0.57      0.52       741

# %%
# ============================================================
# TAHAP 3B: Baseline Random Forest
# ============================================================

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, confusion_matrix, classification_report)
import time

# ---- 1. Training ----
print("Training Random Forest...")
start = time.time()

rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)
rf_model.fit(X_train_unscaled, y_train)

train_time = time.time() - start
print(f"Training selesai dalam {train_time:.2f} detik")

# ---- 2. Prediksi ----
y_pred_val_rf  = rf_model.predict(X_val_unscaled)
y_pred_test_rf = rf_model.predict(X_test_unscaled)

# ---- 3. Evaluasi Validation Set ----
print("\n" + "="*50)
print("HASIL RANDOM FOREST - VALIDATION SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_rf):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_rf, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_rf, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_rf, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_rf)}")
print(f"\n{classification_report(y_val, y_pred_val_rf, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# ---- 4. Evaluasi Test Set ----
print("="*50)
print("HASIL RANDOM FOREST - TEST SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_rf):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_rf, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_rf, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_rf, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_rf)}")
print(f"\n{classification_report(y_test, y_pred_test_rf, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# ---- 5. Feature Importance ----
importances = rf_model.feature_importances_
feature_names = gamma_cols
feat_imp = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

print("="*50)
print("FEATURE IMPORTANCE (Top 8)")
print("="*50)
for feat, imp in feat_imp:
    print(f"  {feat:30s} : {imp:.4f}")
# Out:
# Training Random Forest...
# Training selesai dalam 0.53 detik
#
# ==================================================
# HASIL RANDOM FOREST - VALIDATION SET
# ==================================================
# Accuracy  : 0.6495
# Precision : 0.7271
# Recall    : 0.6495
# F1-Score  : 0.6155
#
# Confusion Matrix:
# [[129 238]
#  [ 21 351]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.86      0.35      0.50       367
#  Label 1 (After)       0.60      0.94      0.73       372
#
#         accuracy                           0.65       739
#        macro avg       0.73      0.65      0.61       739
#     weighted avg       0.73      0.65      0.62       739
#
# ==================================================
# HASIL RANDOM FOREST - TEST SET
# ==================================================
# Accuracy  : 0.6410
# Precision : 0.7339
# Recall    : 0.6410
# F1-Score  : 0.6006
#
# Confusion Matrix:
# [[119 250]
#  [ 16 356]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.88      0.32      0.47       369
#  Label 1 (After)       0.59      0.96      0.73       372
#
#         accuracy                           0.64       741
#        macro avg       0.73      0.64      0.60       741
#     weighted avg       0.73      0.64      0.60       741
#
# ==================================================
# FEATURE IMPORTANCE (Top 8)
# ==================================================
#   RAW_TP9_BP_Gamma               : 0.1730
#   RAW_TP10_RP_Gamma              : 0.1451
#   RAW_TP9_RP_Gamma               : 0.1408
#   RAW_AF8_BP_Gamma               : 0.1337
#   RAW_AF7_BP_Gamma               : 0.1196
#   RAW_TP10_BP_Gamma              : 0.1180
#   RAW_AF7_RP_Gamma               : 0.1040
#   RAW_AF8_RP_Gamma               : 0.0657

# %%
# ============================================================
# TAHAP 3C: Baseline CNN
# ============================================================

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv1D, MaxPooling1D, Flatten, Dense,
                                     Dropout, BatchNormalization, Input)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, confusion_matrix, classification_report)
import time

# ---- 1. Bangun Model CNN ----
model_cnn = Sequential([
    Input(shape=(8, 1)),
    Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model_cnn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model_cnn.summary()

# ---- 2. Callbacks ----
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# ---- 3. Training ----
print("\nTraining CNN...")
start = time.time()

history = model_cnn.fit(
    X_train_cnn, y_train,
    validation_data=(X_val_cnn, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

train_time = time.time() - start
print(f"\nTraining selesai dalam {train_time:.2f} detik")
print(f"Total epoch berjalan: {len(history.history['loss'])}")

# ---- 4. Prediksi ----
y_prob_val_cnn  = model_cnn.predict(X_val_cnn, verbose=0).flatten()
y_prob_test_cnn = model_cnn.predict(X_test_cnn, verbose=0).flatten()

y_pred_val_cnn  = (y_prob_val_cnn >= 0.5).astype(int)
y_pred_test_cnn = (y_prob_test_cnn >= 0.5).astype(int)

# ---- 5. Evaluasi Validation Set ----
print("\n" + "="*50)
print("HASIL CNN - VALIDATION SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_cnn):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_cnn, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_cnn, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_cnn, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_cnn)}")
print(f"\n{classification_report(y_val, y_pred_val_cnn, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# ---- 6. Evaluasi Test Set ----
print("="*50)
print("HASIL CNN - TEST SET")
print("="*50)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_cnn):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_cnn, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_cnn, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_cnn, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_cnn)}")
print(f"\n{classification_report(y_test, y_pred_test_cnn, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783705394.892369      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783705394.895524      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 8, 32)          │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 4, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 4, 64)          │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 4, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,089 (66.75 KB)
#  Trainable params: 16,897 (66.00 KB)
#  Non-trainable params: 192 (768.00 B)
# Training CNN...
# Epoch 1/100
#  60/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4958 - loss: 0.9090
# I0000 00:00:1783705401.849382     160 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.5243 - loss: 0.7508 - val_accuracy: 0.5196 - val_loss: 0.6969 - learning_rate: 0.0010
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5399 - loss: 0.6737 - val_accuracy: 0.5156 - val_loss: 0.6875 - learning_rate: 0.0010
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5466 - loss: 0.6556 - val_accuracy: 0.5156 - val_loss: 0.6681 - learning_rate: 0.0010
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5446 - loss: 0.6545 - val_accuracy: 0.5237 - val_loss: 0.6559 - learning_rate: 0.0010
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5460 - loss: 0.6476 - val_accuracy: 0.5386 - val_loss: 0.6560 - learning_rate: 0.0010
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5506 - loss: 0.6469 - val_accuracy: 0.5913 - val_loss: 0.6394 - learning_rate: 0.0010
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5567 - loss: 0.6454 - val_accuracy: 0.5535 - val_loss: 0.6440 - learning_rate: 0.0010
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5567 - loss: 0.6428 - val_accuracy: 0.6008 - val_loss: 0.6359 - learning_rate: 0.0010
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5613 - loss: 0.6423 - val_accuracy: 0.5995 - val_loss: 0.6370 - learning_rate: 0.0010
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5434 - loss: 0.6445 - val_accuracy: 0.6008 - val_loss: 0.6405 - learning_rate: 0.0010
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5625 - loss: 0.6391 - val_accuracy: 0.5575 - val_loss: 0.6374 - learning_rate: 0.0010
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5506 - loss: 0.6401 - val_accuracy: 0.5575 - val_loss: 0.6414 - learning_rate: 0.0010
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5660 - loss: 0.6352
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5596 - loss: 0.6401 - val_accuracy: 0.5602 - val_loss: 0.6379 - learning_rate: 0.0010
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5613 - loss: 0.6363 - val_accuracy: 0.6022 - val_loss: 0.6375 - learning_rate: 5.0000e-04
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5674 - loss: 0.6342 - val_accuracy: 0.5616 - val_loss: 0.6355 - learning_rate: 5.0000e-04
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6356 - val_accuracy: 0.5616 - val_loss: 0.6373 - learning_rate: 5.0000e-04
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5637 - loss: 0.6357 - val_accuracy: 0.5629 - val_loss: 0.6334 - learning_rate: 5.0000e-04
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5628 - loss: 0.6379 - val_accuracy: 0.5629 - val_loss: 0.6314 - learning_rate: 5.0000e-04
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5645 - loss: 0.6335 - val_accuracy: 0.5981 - val_loss: 0.6311 - learning_rate: 5.0000e-04
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5692 - loss: 0.6327 - val_accuracy: 0.5954 - val_loss: 0.6352 - learning_rate: 5.0000e-04
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5579 - loss: 0.6295 - val_accuracy: 0.6008 - val_loss: 0.6302 - learning_rate: 5.0000e-04
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5619 - loss: 0.6322 - val_accuracy: 0.5656 - val_loss: 0.6326 - learning_rate: 5.0000e-04
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5700 - loss: 0.6309 - val_accuracy: 0.6076 - val_loss: 0.6303 - learning_rate: 5.0000e-04
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5660 - loss: 0.6289 - val_accuracy: 0.6062 - val_loss: 0.6300 - learning_rate: 5.0000e-04
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5668 - loss: 0.6285 - val_accuracy: 0.6035 - val_loss: 0.6290 - learning_rate: 5.0000e-04
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5634 - loss: 0.6321 - val_accuracy: 0.5995 - val_loss: 0.6326 - learning_rate: 5.0000e-04
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5637 - loss: 0.6327 - val_accuracy: 0.5995 - val_loss: 0.6293 - learning_rate: 5.0000e-04
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5648 - loss: 0.6316 - val_accuracy: 0.5602 - val_loss: 0.6303 - learning_rate: 5.0000e-04
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5616 - loss: 0.6289 - val_accuracy: 0.5616 - val_loss: 0.6302 - learning_rate: 5.0000e-04
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5686 - loss: 0.6296 - val_accuracy: 0.6035 - val_loss: 0.6288 - learning_rate: 5.0000e-04
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5634 - loss: 0.6260 - val_accuracy: 0.5616 - val_loss: 0.6329 - learning_rate: 5.0000e-04
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5631 - loss: 0.6269 - val_accuracy: 0.5575 - val_loss: 0.6281 - learning_rate: 5.0000e-04
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5582 - loss: 0.6275 - val_accuracy: 0.5589 - val_loss: 0.6302 - learning_rate: 5.0000e-04
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5660 - loss: 0.6230 - val_accuracy: 0.5562 - val_loss: 0.6295 - learning_rate: 5.0000e-04
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5651 - loss: 0.6219 - val_accuracy: 0.6022 - val_loss: 0.6334 - learning_rate: 5.0000e-04
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5787 - loss: 0.6219 - val_accuracy: 0.6035 - val_loss: 0.6278 - learning_rate: 5.0000e-04
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5741 - loss: 0.6228 - val_accuracy: 0.5968 - val_loss: 0.6234 - learning_rate: 5.0000e-04
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5804 - loss: 0.6190 - val_accuracy: 0.5535 - val_loss: 0.6304 - learning_rate: 5.0000e-04
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5671 - loss: 0.6205 - val_accuracy: 0.5954 - val_loss: 0.6268 - learning_rate: 5.0000e-04
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5825 - loss: 0.6196 - val_accuracy: 0.6008 - val_loss: 0.6293 - learning_rate: 5.0000e-04
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5706 - loss: 0.6206 - val_accuracy: 0.5913 - val_loss: 0.6366 - learning_rate: 5.0000e-04
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5891 - loss: 0.6174 - val_accuracy: 0.5656 - val_loss: 0.6141 - learning_rate: 5.0000e-04
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5761 - loss: 0.6172 - val_accuracy: 0.6022 - val_loss: 0.6191 - learning_rate: 5.0000e-04
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5816 - loss: 0.6130 - val_accuracy: 0.6076 - val_loss: 0.6211 - learning_rate: 5.0000e-04
# Epoch 45/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5718 - loss: 0.6161 - val_accuracy: 0.6049 - val_loss: 0.6183 - learning_rate: 5.0000e-04
# Epoch 46/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5822 - loss: 0.6183 - val_accuracy: 0.5981 - val_loss: 0.6252 - learning_rate: 5.0000e-04
# Epoch 47/100
# 105/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5886 - loss: 0.6180
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5923 - loss: 0.6150 - val_accuracy: 0.5900 - val_loss: 0.6278 - learning_rate: 5.0000e-04
# Epoch 48/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5726 - loss: 0.6165 - val_accuracy: 0.5968 - val_loss: 0.6199 - learning_rate: 2.5000e-04
# Epoch 49/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5799 - loss: 0.6138 - val_accuracy: 0.5940 - val_loss: 0.6194 - learning_rate: 2.5000e-04
# Epoch 50/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5828 - loss: 0.6119 - val_accuracy: 0.6008 - val_loss: 0.6260 - learning_rate: 2.5000e-04
# Epoch 51/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5755 - loss: 0.6146 - val_accuracy: 0.5981 - val_loss: 0.6203 - learning_rate: 2.5000e-04
# Epoch 52/100
# 103/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5942 - loss: 0.6081
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5929 - loss: 0.6095 - val_accuracy: 0.5548 - val_loss: 0.6224 - learning_rate: 2.5000e-04
# Epoch 53/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5764 - loss: 0.6087 - val_accuracy: 0.5913 - val_loss: 0.6254 - learning_rate: 1.2500e-04
# Epoch 54/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5723 - loss: 0.6110 - val_accuracy: 0.5968 - val_loss: 0.6163 - learning_rate: 1.2500e-04
# Epoch 55/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5787 - loss: 0.6085 - val_accuracy: 0.5981 - val_loss: 0.6180 - learning_rate: 1.2500e-04
# Epoch 56/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5752 - loss: 0.6118 - val_accuracy: 0.6022 - val_loss: 0.6164 - learning_rate: 1.2500e-04
# Epoch 57/100
# 106/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5818 - loss: 0.6129
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5856 - loss: 0.6072 - val_accuracy: 0.5940 - val_loss: 0.6236 - learning_rate: 1.2500e-04
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 42.
#
# Training selesai dalam 30.91 detik
# Total epoch berjalan: 57
#
# ==================================================
# HASIL CNN - VALIDATION SET
# ==================================================
# Accuracy  : 0.5656
# Precision : 0.7144
# Recall    : 0.5656
# F1-Score  : 0.4771
#
# Confusion Matrix:
# [[360   7]
#  [314  58]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.53      0.98      0.69       367
#  Label 1 (After)       0.89      0.16      0.27       372
#
#         accuracy                           0.57       739
#        macro avg       0.71      0.57      0.48       739
#     weighted avg       0.71      0.57      0.48       739
#
# ==================================================
# HASIL CNN - TEST SET
# ==================================================
# Accuracy  : 0.5682
# Precision : 0.7355
# Recall    : 0.5682
# F1-Score  : 0.4764
#
# Confusion Matrix:
# [[365   4]
#  [316  56]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.54      0.99      0.70       369
#  Label 1 (After)       0.93      0.15      0.26       372
#
#         accuracy                           0.57       741
#        macro avg       0.73      0.57      0.48       741
#     weighted avg       0.74      0.57      0.48       741

# %%
# ============================================================
# RINGKASAN HASIL BASELINE MODELS TANPA ACGAN
# ============================================================

import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

baseline_results = []

# SVM
baseline_results.append({
    "Experiment": "Gamma-only Baseline",
    "Model": "SVM",
    "Validation Accuracy": accuracy_score(y_val, y_pred_val_svm),
    "Validation Precision": precision_score(y_val, y_pred_val_svm, average='weighted'),
    "Validation Recall": recall_score(y_val, y_pred_val_svm, average='weighted'),
    "Validation F1": f1_score(y_val, y_pred_val_svm, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_svm),
    "Test Precision": precision_score(y_test, y_pred_test_svm, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_svm, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_svm, average='weighted')
})

# Random Forest
baseline_results.append({
    "Experiment": "Gamma-only Baseline",
    "Model": "Random Forest",
    "Validation Accuracy": accuracy_score(y_val, y_pred_val_rf),
    "Validation Precision": precision_score(y_val, y_pred_val_rf, average='weighted'),
    "Validation Recall": recall_score(y_val, y_pred_val_rf, average='weighted'),
    "Validation F1": f1_score(y_val, y_pred_val_rf, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_rf),
    "Test Precision": precision_score(y_test, y_pred_test_rf, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_rf, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_rf, average='weighted')
})

# CNN
baseline_results.append({
    "Experiment": "Gamma-only Baseline",
    "Model": "CNN",
    "Validation Accuracy": accuracy_score(y_val, y_pred_val_cnn),
    "Validation Precision": precision_score(y_val, y_pred_val_cnn, average='weighted'),
    "Validation Recall": recall_score(y_val, y_pred_val_cnn, average='weighted'),
    "Validation F1": f1_score(y_val, y_pred_val_cnn, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_cnn),
    "Test Precision": precision_score(y_test, y_pred_test_cnn, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_cnn, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_cnn, average='weighted')
})

df_baseline_results = pd.DataFrame(baseline_results)

# Tampilkan hasil dengan pembulatan 4 desimal
display(df_baseline_results.round(4))

# Simpan ke CSV
df_baseline_results.to_csv("baseline_gamma_only_results.csv", index=False)

print("Ringkasan baseline berhasil disimpan sebagai baseline_gamma_only_results.csv")
# Out:
#             Experiment          Model  Validation Accuracy  \
# 0  Gamma-only Baseline            SVM               0.5940
# 1  Gamma-only Baseline  Random Forest               0.6495
# 2  Gamma-only Baseline            CNN               0.5656
#
#    Validation Precision  Validation Recall  Validation F1  Test Accuracy  \
# 0                0.6587             0.5940         0.5458         0.5749
# 1                0.7271             0.6495         0.6155         0.6410
# 2                0.7144             0.5656         0.4771         0.5682
#
#    Test Precision  Test Recall  Test F1
# 0          0.6333       0.5749   0.5210
# 1          0.7339       0.6410   0.6006
# 2          0.7355       0.5682   0.4764
# Ringkasan baseline berhasil disimpan sebagai baseline_gamma_only_results.csv

# %%
# ============================================================
# TAHAP 4: ACGAN AUGMENTATION UNTUK GAMMA-ONLY FEATURES
# ============================================================

import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, BatchNormalization, Dropout, Embedding, Flatten, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# ============================================================
# 1. SETUP AWAL
# ============================================================

np.random.seed(42)
tf.random.set_seed(42)

# Data training yang dipakai ACGAN
X_train_acgan = np.array(X_train_scaled, dtype=np.float32)
y_train_acgan = np.array(y_train).astype(int)

feature_dim = X_train_acgan.shape[1]   # 8 fitur Gamma
num_classes = 2                        # Label 0 dan Label 1
noise_dim = 32                         # Dimensi noise generator

print("=== Data untuk ACGAN ===")
print(f"X_train_acgan shape : {X_train_acgan.shape}")
print(f"y_train_acgan shape : {y_train_acgan.shape}")
print(f"Feature dim         : {feature_dim}")
print(f"Jumlah kelas        : {num_classes}")
print(f"Noise dim           : {noise_dim}")

unique, counts = np.unique(y_train_acgan, return_counts=True)
print("\nDistribusi label training asli:")
for u, c in zip(unique, counts):
    print(f"Label {u}: {c} sampel")

# ============================================================
# 2. BUILD GENERATOR
# Generator menerima noise + label, lalu menghasilkan 8 fitur Gamma sintetis
# ============================================================

def build_generator(noise_dim, num_classes, feature_dim):
    noise_input = Input(shape=(noise_dim,), name="noise_input")
    label_input = Input(shape=(1,), dtype="int32", name="label_input")

    label_embedding = Embedding(num_classes, noise_dim)(label_input)
    label_embedding = Flatten()(label_embedding)

    x = Concatenate()([noise_input, label_embedding])

    x = Dense(64)(x)
    x = LeakyReLU(negative_slope=0.2)(x)
    x = BatchNormalization()(x)

    x = Dense(128)(x)
    x = LeakyReLU(negative_slope=0.2)(x)
    x = BatchNormalization()(x)

    x = Dense(64)(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    output = Dense(feature_dim, activation="linear", name="generated_features")(x)

    model = Model([noise_input, label_input], output, name="Generator")
    return model

# ============================================================
# 3. BUILD DISCRIMINATOR
# Discriminator menghasilkan dua output:
#   1. validitas real/fake
#   2. prediksi kelas Label 0/1
# ============================================================

def build_discriminator(feature_dim, num_classes):
    feature_input = Input(shape=(feature_dim,), name="feature_input")

    x = Dense(128)(feature_input)
    x = LeakyReLU(negative_slope=0.2)(x)
    x = Dropout(0.3)(x)

    x = Dense(64)(x)
    x = LeakyReLU(negative_slope=0.2)(x)
    x = Dropout(0.3)(x)

    x = Dense(32)(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    validity_output = Dense(1, activation="sigmoid", name="validity_output")(x)
    class_output = Dense(num_classes, activation="softmax", name="class_output")(x)

    model = Model(feature_input, [validity_output, class_output], name="Discriminator")
    return model

generator = build_generator(noise_dim, num_classes, feature_dim)
discriminator = build_discriminator(feature_dim, num_classes)

# Compile discriminator
discriminator.compile(
    optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss={
        "validity_output": "binary_crossentropy",
        "class_output": "sparse_categorical_crossentropy"
    },
    metrics={
        "validity_output": "accuracy",
        "class_output": "accuracy"
    }
)

# ============================================================
# 4. BUILD COMBINED ACGAN MODEL
# Generator dilatih untuk menipu discriminator dan menghasilkan kelas sesuai label
# ============================================================

discriminator.trainable = False

noise_input = Input(shape=(noise_dim,), name="combined_noise_input")
label_input = Input(shape=(1,), dtype="int32", name="combined_label_input")

generated_features = generator([noise_input, label_input])
validity_output, class_output = discriminator(generated_features)

combined = Model(
    [noise_input, label_input],
    [validity_output, class_output],
    name="ACGAN_Combined"
)

combined.compile(
    optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss={
        "Discriminator": "binary_crossentropy"
    }
)

# Re-compile combined dengan output loss eksplisit
combined.compile(
    optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss=["binary_crossentropy", "sparse_categorical_crossentropy"]
)

print("\n=== Generator Summary ===")
generator.summary()

print("\n=== Discriminator Summary ===")
discriminator.summary()

# ============================================================
# 5. TRAINING ACGAN
# ============================================================

epochs = 1500
batch_size = 64
sample_interval = 100

d_losses = []
g_losses = []

half_batch = batch_size // 2

print("\n=== Mulai Training ACGAN ===")

for epoch in range(1, epochs + 1):

    # --------------------------------------------------------
    # Train Discriminator
    # --------------------------------------------------------

    # Ambil real samples
    idx = np.random.randint(0, X_train_acgan.shape[0], half_batch)
    real_features = X_train_acgan[idx]
    real_labels = y_train_acgan[idx]

    # Label validitas untuk real dan fake
    valid = np.ones((half_batch, 1)) * 0.9   # label smoothing
    fake = np.zeros((half_batch, 1))

    # Generate fake samples
    noise = np.random.normal(0, 1, (half_batch, noise_dim))
    sampled_labels = np.random.randint(0, num_classes, half_batch).reshape(-1, 1)
    fake_features = generator.predict([noise, sampled_labels], verbose=0)

    # Pastikan discriminator trainable saat dilatih
    discriminator.trainable = True

    # Train discriminator pada real
    d_loss_real = discriminator.train_on_batch(
        real_features,
        [valid, real_labels]
    )

    # Train discriminator pada fake
    d_loss_fake = discriminator.train_on_batch(
        fake_features,
        [fake, sampled_labels.flatten()]
    )

    # Rata-rata loss discriminator
    d_loss = 0.5 * np.add(d_loss_real[0], d_loss_fake[0])

    # --------------------------------------------------------
    # Train Generator
    # --------------------------------------------------------

    noise = np.random.normal(0, 1, (batch_size, noise_dim))
    sampled_labels = np.random.randint(0, num_classes, batch_size).reshape(-1, 1)

    valid_for_generator = np.ones((batch_size, 1))

    discriminator.trainable = False

    g_loss = combined.train_on_batch(
        [noise, sampled_labels],
        [valid_for_generator, sampled_labels.flatten()]
    )

    d_losses.append(d_loss)
    g_losses.append(g_loss[0] if isinstance(g_loss, list) else g_loss)

    # --------------------------------------------------------
    # Print progress
    # --------------------------------------------------------
    if epoch % sample_interval == 0 or epoch == 1:
        print(
            f"Epoch {epoch:4d}/{epochs} | "
            f"D loss: {float(d_loss):.4f} | "
            f"G loss: {float(g_losses[-1]):.4f}"
        )

print("\nTraining ACGAN selesai.")

# ============================================================
# 6. GENERATE SYNTHETIC DATA
# ============================================================

# Rasio synthetic data.
# 1.0 berarti jumlah synthetic per class = jumlah real training per class.
# Jika ingin lebih ringan, ubah ke 0.5.
synthetic_ratio = 1.0

n_label_0 = np.sum(y_train_acgan == 0)
n_label_1 = np.sum(y_train_acgan == 1)

n_synth_0 = int(n_label_0 * synthetic_ratio)
n_synth_1 = int(n_label_1 * synthetic_ratio)

print("\n=== Jumlah Synthetic Data yang Akan Dibuat ===")
print(f"Synthetic Label 0: {n_synth_0}")
print(f"Synthetic Label 1: {n_synth_1}")

# Generate label 0
noise_0 = np.random.normal(0, 1, (n_synth_0, noise_dim))
labels_0 = np.zeros((n_synth_0, 1), dtype=int)
X_synth_0_scaled = generator.predict([noise_0, labels_0], verbose=0)
y_synth_0 = np.zeros(n_synth_0, dtype=int)

# Generate label 1
noise_1 = np.random.normal(0, 1, (n_synth_1, noise_dim))
labels_1 = np.ones((n_synth_1, 1), dtype=int)
X_synth_1_scaled = generator.predict([noise_1, labels_1], verbose=0)
y_synth_1 = np.ones(n_synth_1, dtype=int)

# Gabungkan synthetic label 0 dan 1
X_synth_scaled = np.vstack([X_synth_0_scaled, X_synth_1_scaled])
y_synth = np.concatenate([y_synth_0, y_synth_1])

print("\n=== Synthetic Data Generated ===")
print(f"X_synth_scaled shape : {X_synth_scaled.shape}")
print(f"y_synth shape        : {y_synth.shape}")

unique_synth, counts_synth = np.unique(y_synth, return_counts=True)
print("\nDistribusi label synthetic:")
for u, c in zip(unique_synth, counts_synth):
    print(f"Label {u}: {c} sampel")

# ============================================================
# 7. GABUNGKAN REAL TRAINING + SYNTHETIC TRAINING
# Validation dan test TIDAK disentuh
# ============================================================

X_train_aug_scaled = np.vstack([X_train_scaled, X_synth_scaled])
y_train_aug = np.concatenate([np.array(y_train), y_synth])

# Shuffle augmented training data
X_train_aug_scaled, y_train_aug = shuffle(
    X_train_aug_scaled,
    y_train_aug,
    random_state=42
)

print("\n=== Augmented Training Data ===")
print(f"X_train_aug_scaled shape : {X_train_aug_scaled.shape}")
print(f"y_train_aug shape        : {y_train_aug.shape}")

unique_aug, counts_aug = np.unique(y_train_aug, return_counts=True)
print("\nDistribusi label setelah augmentation:")
for u, c in zip(unique_aug, counts_aug):
    print(f"Label {u}: {c} sampel")

# ============================================================
# 8. SIAPKAN DATA AUGMENTED UNTUK SVM, RF, DAN CNN
# ============================================================

# Untuk SVM: gunakan scaled augmented data
X_train_aug_svm = X_train_aug_scaled

# Untuk CNN: reshape menjadi (samples, 8, 1)
X_train_aug_cnn = X_train_aug_scaled.reshape(-1, feature_dim, 1)

# Untuk RF: gunakan versi unscaled.
# Synthetic data dibuat dalam scaled space, jadi kita inverse transform dulu.
X_synth_unscaled = scaler.inverse_transform(X_synth_scaled)
X_train_aug_unscaled = np.vstack([X_train_unscaled, X_synth_unscaled])
y_train_aug_rf = np.concatenate([np.array(y_train), y_synth])

X_train_aug_unscaled, y_train_aug_rf = shuffle(
    X_train_aug_unscaled,
    y_train_aug_rf,
    random_state=42
)

print("\n=== Variabel Augmented yang Siap Dipakai ===")
print(f"X_train_aug_svm shape      : {X_train_aug_svm.shape}")
print(f"X_train_aug_cnn shape      : {X_train_aug_cnn.shape}")
print(f"X_train_aug_unscaled shape : {X_train_aug_unscaled.shape}")
print(f"y_train_aug shape          : {y_train_aug.shape}")
print(f"y_train_aug_rf shape       : {y_train_aug_rf.shape}")

print("\nValidation dan test set tetap sama:")
print(f"X_val_scaled shape   : {X_val_scaled.shape}")
print(f"X_test_scaled shape  : {X_test_scaled.shape}")
print(f"X_val_cnn shape      : {X_val_cnn.shape}")
print(f"X_test_cnn shape     : {X_test_cnn.shape}")
print(f"X_val_unscaled shape : {X_val_unscaled.shape}")
print(f"X_test_unscaled shape: {X_test_unscaled.shape}")

# ============================================================
# 9. VISUALISASI LOSS ACGAN
# ============================================================

plt.figure(figsize=(10, 4))
plt.plot(d_losses, label="Discriminator Loss")
plt.plot(g_losses, label="Generator Loss")
plt.title("ACGAN Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

print("\nTahap 4 selesai.")
print("Gunakan variabel berikut untuk training ulang model:")
print("  SVM : X_train_aug_svm, y_train_aug")
print("  RF  : X_train_aug_unscaled, y_train_aug_rf")
print("  CNN : X_train_aug_cnn, y_train_aug")
# Out:
# === Data untuk ACGAN ===
# X_train_acgan shape : (3456, 8)
# y_train_acgan shape : (3456,)
# Feature dim         : 8
# Jumlah kelas        : 2
# Noise dim           : 32
#
# Distribusi label training asli:
# Label 0: 1719 sampel
# Label 1: 1737 sampel
#
# === Generator Summary ===
# Model: "Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ label_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 1, 32)     │         64 │ label_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ noise_input         │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 32)        │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64)        │          0 │ noise_input[0][0… │
# │ (Concatenate)       │                   │            │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │      4,160 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 64)        │          0 │ dense_3[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ leaky_re_lu[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │      8,320 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 128)       │          0 │ dense_4[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ leaky_re_lu_1[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 64)        │          0 │ dense_5[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ generated_features  │ (None, 8)         │        520 │ leaky_re_lu_2[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,088 (86.28 KB)
#  Trainable params: 21,704 (84.78 KB)
#  Non-trainable params: 384 (1.50 KB)
# === Discriminator Summary ===
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ feature_input       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │      1,152 │ feature_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 128)       │          0 │ dense_6[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      8,256 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 64)        │          0 │ dense_7[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ leaky_re_lu_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │      2,080 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 32)        │          0 │ dense_8[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ validity_output     │ (None, 1)         │         33 │ leaky_re_lu_5[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class_output        │ (None, 2)         │         66 │ leaky_re_lu_5[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,587 (45.26 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 11,587 (45.26 KB)
# === Mulai Training ACGAN ===
# Epoch    1/1500 | D loss: 1.4077 | G loss: 1.4927
# Epoch  100/1500 | D loss: 1.3533 | G loss: 1.3402
# Epoch  200/1500 | D loss: 1.2736 | G loss: 1.2799
# Epoch  300/1500 | D loss: 1.2039 | G loss: 1.2689
# Epoch  400/1500 | D loss: 1.1577 | G loss: 1.2401
# Epoch  500/1500 | D loss: 1.1255 | G loss: 1.2130
# Epoch  600/1500 | D loss: 1.0981 | G loss: 1.1916
# Epoch  700/1500 | D loss: 1.0788 | G loss: 1.1799
# Epoch  800/1500 | D loss: 1.0615 | G loss: 1.1760
# Epoch  900/1500 | D loss: 1.0481 | G loss: 1.1753
# Epoch 1000/1500 | D loss: 1.0388 | G loss: 1.1769
# Epoch 1100/1500 | D loss: 1.0326 | G loss: 1.1828
# Epoch 1200/1500 | D loss: 1.0279 | G loss: 1.1860
# Epoch 1300/1500 | D loss: 1.0257 | G loss: 1.1924
# Epoch 1400/1500 | D loss: 1.0280 | G loss: 1.1980
# Epoch 1500/1500 | D loss: 1.0256 | G loss: 1.2028
#
# Training ACGAN selesai.
#
# === Jumlah Synthetic Data yang Akan Dibuat ===
# Synthetic Label 0: 1719
# Synthetic Label 1: 1737
#
# === Synthetic Data Generated ===
# X_synth_scaled shape : (3456, 8)
# y_synth shape        : (3456,)
#
# Distribusi label synthetic:
# Label 0: 1719 sampel
# Label 1: 1737 sampel
#
# === Augmented Training Data ===
# X_train_aug_scaled shape : (6912, 8)
# y_train_aug shape        : (6912,)
#
# Distribusi label setelah augmentation:
# Label 0: 3438 sampel
# Label 1: 3474 sampel
#
# === Variabel Augmented yang Siap Dipakai ===
# X_train_aug_svm shape      : (6912, 8)
# X_train_aug_cnn shape      : (6912, 8, 1)
# X_train_aug_unscaled shape : (6912, 8)
# y_train_aug shape          : (6912,)
# y_train_aug_rf shape       : (6912,)
#
# Validation dan test set tetap sama:
# X_val_scaled shape   : (739, 8)
# X_test_scaled shape  : (741, 8)
# X_val_cnn shape      : (739, 8, 1)
# X_test_cnn shape     : (741, 8, 1)
# X_val_unscaled shape : (739, 8)
# X_test_unscaled shape: (741, 8)
# Tahap 4 selesai.
# Gunakan variabel berikut untuk training ulang model:
#   SVM : X_train_aug_svm, y_train_aug
#   RF  : X_train_aug_unscaled, y_train_aug_rf
#   CNN : X_train_aug_cnn, y_train_aug

# %%
# ============================================================
# SANITY CHECK ACGAN, VERSI BERSIH TANPA PLOT BERMASALAH
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Tutup semua figure sebelumnya agar tidak ketimpa output lama
plt.close("all")

# Buat dataframe real dan synthetic dalam scaled space
df_real_scaled = pd.DataFrame(X_train_scaled, columns=gamma_cols)
df_real_scaled["Label"] = np.array(y_train)

df_synth_scaled = pd.DataFrame(X_synth_scaled, columns=gamma_cols)
df_synth_scaled["Label"] = y_synth

print("=== SHAPE DATA ===")
print(f"Real training data : {df_real_scaled.shape}")
print(f"Synthetic data     : {df_synth_scaled.shape}")

print("\n=== DISTRIBUSI LABEL REAL ===")
print(df_real_scaled["Label"].value_counts().sort_index())

print("\n=== DISTRIBUSI LABEL SYNTHETIC ===")
print(df_synth_scaled["Label"].value_counts().sort_index())

print("\n=== CEK NILAI BERMASALAH ===")
print("NaN pada synthetic :", np.isnan(X_synth_scaled).sum())
print("Inf pada synthetic :", np.isinf(X_synth_scaled).sum())
print("Min synthetic      :", np.min(X_synth_scaled))
print("Max synthetic      :", np.max(X_synth_scaled))

# Statistik real vs synthetic
real_stats = df_real_scaled[gamma_cols].agg(["mean", "std", "min", "max"]).T
synth_stats = df_synth_scaled[gamma_cols].agg(["mean", "std", "min", "max"]).T

comparison_stats = pd.concat(
    [
        real_stats.add_prefix("Real_"),
        synth_stats.add_prefix("Synth_")
    ],
    axis=1
)

# Tambahkan selisih mean dan std
comparison_stats["Mean_Diff"] = comparison_stats["Synth_mean"] - comparison_stats["Real_mean"]
comparison_stats["Std_Diff"] = comparison_stats["Synth_std"] - comparison_stats["Real_std"]

print("\n=== PERBANDINGAN STATISTIK REAL VS SYNTHETIC, SCALED SPACE ===")
display(comparison_stats.round(4))

# Ringkasan apakah aman lanjut
nan_count = np.isnan(X_synth_scaled).sum()
inf_count = np.isinf(X_synth_scaled).sum()
min_val = np.min(X_synth_scaled)
max_val = np.max(X_synth_scaled)

print("\n=== KESIMPULAN AWAL ===")

if nan_count == 0 and inf_count == 0:
    print("OK: Tidak ada NaN atau Inf pada synthetic data.")
else:
    print("PERINGATAN: Ada NaN atau Inf pada synthetic data.")

if min_val > -10 and max_val < 10:
    print("OK: Range synthetic masih wajar untuk scaled data.")
else:
    print("PERINGATAN: Range synthetic cukup ekstrem. Perlu dicek sebelum lanjut.")

print("\nSanity check selesai.")
# Out:
# === SHAPE DATA ===
# Real training data : (3456, 9)
# Synthetic data     : (3456, 9)
#
# === DISTRIBUSI LABEL REAL ===
# Label
# 0    1719
# 1    1737
# Name: count, dtype: int64
#
# === DISTRIBUSI LABEL SYNTHETIC ===
# Label
# 0    1719
# 1    1737
# Name: count, dtype: int64
#
# === CEK NILAI BERMASALAH ===
# NaN pada synthetic : 0
# Inf pada synthetic : 0
# Min synthetic      : -1.8570303
# Max synthetic      : 4.3966722
#
# === PERBANDINGAN STATISTIK REAL VS SYNTHETIC, SCALED SPACE ===
#                    Real_mean  Real_std  Real_min  Real_max  Synth_mean  \
# RAW_TP9_BP_Gamma        -0.0    1.0001   -0.1183   26.2279      0.1836
# RAW_TP9_RP_Gamma         0.0    1.0001   -0.4045    3.8581      0.2088
# RAW_AF7_BP_Gamma        -0.0    1.0001   -0.0403   35.9761      0.0359
# RAW_AF7_RP_Gamma         0.0    1.0001   -0.2963    4.7359     -0.1128
# RAW_AF8_BP_Gamma         0.0    1.0001   -0.1681   27.1151      0.2677
# RAW_AF8_RP_Gamma        -0.0    1.0001   -0.3239    4.5293      0.1893
# RAW_TP10_BP_Gamma       -0.0    1.0001   -0.1109   31.8349      0.1478
# RAW_TP10_RP_Gamma       -0.0    1.0001   -0.3599    3.8750      0.1538
#
#                    Synth_std  Synth_min  Synth_max  Mean_Diff  Std_Diff
# RAW_TP9_BP_Gamma      0.3616    -0.3472     1.5866     0.1836   -0.6385
# RAW_TP9_RP_Gamma      0.8104    -1.8362     4.1402     0.2088   -0.1897
# RAW_AF7_BP_Gamma      0.1927    -0.6820     1.0858     0.0359   -0.8074
# RAW_AF7_RP_Gamma      0.4083    -1.3820     2.5682    -0.1128   -0.5919
# RAW_AF8_BP_Gamma      0.6030    -0.7178     2.6943     0.2677   -0.3972
# RAW_AF8_RP_Gamma      0.8744    -1.8570     4.3967     0.1893   -0.1257
# RAW_TP10_BP_Gamma     0.2950    -0.2864     1.0590     0.1478   -0.7052
# RAW_TP10_RP_Gamma     0.7472    -1.5041     3.8672     0.1538   -0.2530
# === KESIMPULAN AWAL ===
# OK: Tidak ada NaN atau Inf pada synthetic data.
# OK: Range synthetic masih wajar untuk scaled data.
#
# Sanity check selesai.

# %%
# ============================================================
# TAHAP 5A: SVM dengan ACGAN Augmented Training Data
# ============================================================

from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)
import time

print("Training SVM dengan ACGAN augmented data...")
start = time.time()

svm_acgan_model = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    random_state=42
)

svm_acgan_model.fit(X_train_aug_svm, y_train_aug)

train_time = time.time() - start
print(f"Training selesai dalam {train_time:.2f} detik")

# Prediksi validation dan test
y_pred_val_svm_acgan = svm_acgan_model.predict(X_val_scaled)
y_pred_test_svm_acgan = svm_acgan_model.predict(X_test_scaled)

# Evaluasi Validation Set
print("\n" + "="*60)
print("HASIL SVM + ACGAN - VALIDATION SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_svm_acgan):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_svm_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_svm_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_svm_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_svm_acgan)}")
print(f"\n{classification_report(y_val, y_pred_val_svm_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# Evaluasi Test Set
print("="*60)
print("HASIL SVM + ACGAN - TEST SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_svm_acgan):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_svm_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_svm_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_svm_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_svm_acgan)}")
print(f"\n{classification_report(y_test, y_pred_test_svm_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# Training SVM dengan ACGAN augmented data...
# Training selesai dalam 1.10 detik
#
# ============================================================
# HASIL SVM + ACGAN - VALIDATION SET
# ============================================================
# Accuracy  : 0.5656
# Precision : 0.6685
# Recall    : 0.5656
# F1-Score  : 0.4903
#
# Confusion Matrix:
# [[350  17]
#  [304  68]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.54      0.95      0.69       367
#  Label 1 (After)       0.80      0.18      0.30       372
#
#         accuracy                           0.57       739
#        macro avg       0.67      0.57      0.49       739
#     weighted avg       0.67      0.57      0.49       739
#
# ============================================================
# HASIL SVM + ACGAN - TEST SET
# ============================================================
# Accuracy  : 0.5749
# Precision : 0.7161
# Recall    : 0.5749
# F1-Score  : 0.4934
#
# Confusion Matrix:
# [[361   8]
#  [307  65]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.54      0.98      0.70       369
#  Label 1 (After)       0.89      0.17      0.29       372
#
#         accuracy                           0.57       741
#        macro avg       0.72      0.58      0.49       741
#     weighted avg       0.72      0.57      0.49       741

# %%
# ============================================================
# TAHAP 5B: Random Forest dengan ACGAN Augmented Training Data
# ============================================================

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)
import time

print("Training Random Forest dengan ACGAN augmented data...")
start = time.time()

rf_acgan_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf_acgan_model.fit(X_train_aug_unscaled, y_train_aug_rf)

train_time = time.time() - start
print(f"Training selesai dalam {train_time:.2f} detik")

# Prediksi validation dan test
y_pred_val_rf_acgan = rf_acgan_model.predict(X_val_unscaled)
y_pred_test_rf_acgan = rf_acgan_model.predict(X_test_unscaled)

# Evaluasi Validation Set
print("\n" + "="*60)
print("HASIL RANDOM FOREST + ACGAN - VALIDATION SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_rf_acgan):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_rf_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_rf_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_rf_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_rf_acgan)}")
print(f"\n{classification_report(y_val, y_pred_val_rf_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# Evaluasi Test Set
print("="*60)
print("HASIL RANDOM FOREST + ACGAN - TEST SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_rf_acgan):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_rf_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_rf_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_rf_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_rf_acgan)}")
print(f"\n{classification_report(y_test, y_pred_test_rf_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# Feature importance setelah ACGAN
importances_acgan = rf_acgan_model.feature_importances_
feat_imp_acgan = sorted(zip(gamma_cols, importances_acgan), key=lambda x: x[1], reverse=True)

print("="*60)
print("FEATURE IMPORTANCE RF + ACGAN")
print("="*60)
for feat, imp in feat_imp_acgan:
    print(f"{feat:30s} : {imp:.4f}")
# Out:
# Training Random Forest dengan ACGAN augmented data...
# Training selesai dalam 0.73 detik
#
# ============================================================
# HASIL RANDOM FOREST + ACGAN - VALIDATION SET
# ============================================================
# Accuracy  : 0.6509
# Precision : 0.7303
# Recall    : 0.6509
# F1-Score  : 0.6167
#
# Confusion Matrix:
# [[129 238]
#  [ 20 352]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.87      0.35      0.50       367
#  Label 1 (After)       0.60      0.95      0.73       372
#
#         accuracy                           0.65       739
#        macro avg       0.73      0.65      0.62       739
#     weighted avg       0.73      0.65      0.62       739
#
# ============================================================
# HASIL RANDOM FOREST + ACGAN - TEST SET
# ============================================================
# Accuracy  : 0.6424
# Precision : 0.7348
# Recall    : 0.6424
# F1-Score  : 0.6025
#
# Confusion Matrix:
# [[120 249]
#  [ 16 356]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.88      0.33      0.48       369
#  Label 1 (After)       0.59      0.96      0.73       372
#
#         accuracy                           0.64       741
#        macro avg       0.74      0.64      0.60       741
#     weighted avg       0.73      0.64      0.60       741
#
# ============================================================
# FEATURE IMPORTANCE RF + ACGAN
# ============================================================
# RAW_TP9_BP_Gamma               : 0.2302
# RAW_TP10_BP_Gamma              : 0.1669
# RAW_TP9_RP_Gamma               : 0.1330
# RAW_AF8_BP_Gamma               : 0.1249
# RAW_TP10_RP_Gamma              : 0.1109
# RAW_AF8_RP_Gamma               : 0.1102
# RAW_AF7_RP_Gamma               : 0.0644
# RAW_AF7_BP_Gamma               : 0.0593

# %%
# ============================================================
# TAHAP 5C: CNN dengan ACGAN Augmented Training Data
# ============================================================

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, Flatten, Dense,
    Dropout, BatchNormalization, Input
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)
import time

# Set seed agar lebih reproducible
tf.random.set_seed(42)

# Bangun model CNN baru
model_cnn_acgan = Sequential([
    Input(shape=(8, 1)),

    Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Flatten(),

    Dense(64, activation='relu'),
    Dropout(0.5),

    Dense(32, activation='relu'),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

model_cnn_acgan.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model_cnn_acgan.summary()

# Callbacks
early_stop_acgan = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_acgan = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# Training
print("\nTraining CNN dengan ACGAN augmented data...")
start = time.time()

history_cnn_acgan = model_cnn_acgan.fit(
    X_train_aug_cnn, y_train_aug,
    validation_data=(X_val_cnn, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_acgan, reduce_lr_acgan],
    verbose=1
)

train_time = time.time() - start
print(f"\nTraining selesai dalam {train_time:.2f} detik")
print(f"Total epoch berjalan: {len(history_cnn_acgan.history['loss'])}")

# Prediksi validation dan test
y_prob_val_cnn_acgan = model_cnn_acgan.predict(X_val_cnn, verbose=0).flatten()
y_prob_test_cnn_acgan = model_cnn_acgan.predict(X_test_cnn, verbose=0).flatten()

y_pred_val_cnn_acgan = (y_prob_val_cnn_acgan >= 0.5).astype(int)
y_pred_test_cnn_acgan = (y_prob_test_cnn_acgan >= 0.5).astype(int)

# Evaluasi Validation Set
print("\n" + "="*60)
print("HASIL CNN + ACGAN - VALIDATION SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_val, y_pred_val_cnn_acgan):.4f}")
print(f"Precision : {precision_score(y_val, y_pred_val_cnn_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val, y_pred_val_cnn_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val, y_pred_val_cnn_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val, y_pred_val_cnn_acgan)}")
print(f"\n{classification_report(y_val, y_pred_val_cnn_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# Evaluasi Test Set
print("="*60)
print("HASIL CNN + ACGAN - TEST SET")
print("="*60)
print(f"Accuracy  : {accuracy_score(y_test, y_pred_test_cnn_acgan):.4f}")
print(f"Precision : {precision_score(y_test, y_pred_test_cnn_acgan, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_test_cnn_acgan, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred_test_cnn_acgan, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred_test_cnn_acgan)}")
print(f"\n{classification_report(y_test, y_pred_test_cnn_acgan, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 8, 32)          │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 4, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 4, 64)          │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,089 (66.75 KB)
#  Trainable params: 16,897 (66.00 KB)
#  Non-trainable params: 192 (768.00 B)
# Training CNN dengan ACGAN augmented data...
# Epoch 1/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7418 - loss: 0.5091 - val_accuracy: 0.5088 - val_loss: 0.7062 - learning_rate: 0.0010
# Epoch 2/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7690 - loss: 0.4110 - val_accuracy: 0.5562 - val_loss: 0.8787 - learning_rate: 0.0010
# Epoch 3/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7705 - loss: 0.3880 - val_accuracy: 0.5507 - val_loss: 0.7244 - learning_rate: 0.0010
# Epoch 4/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7742 - loss: 0.3655 - val_accuracy: 0.5548 - val_loss: 0.6528 - learning_rate: 0.0010
# Epoch 5/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7753 - loss: 0.3539 - val_accuracy: 0.5562 - val_loss: 0.6348 - learning_rate: 0.0010
# Epoch 6/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7781 - loss: 0.3564 - val_accuracy: 0.5602 - val_loss: 0.6360 - learning_rate: 0.0010
# Epoch 7/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7808 - loss: 0.3428 - val_accuracy: 0.5616 - val_loss: 0.6481 - learning_rate: 0.0010
# Epoch 8/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7812 - loss: 0.3387 - val_accuracy: 0.5589 - val_loss: 0.6419 - learning_rate: 0.0010
# Epoch 9/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7807 - loss: 0.3363 - val_accuracy: 0.5589 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7827 - loss: 0.3377 - val_accuracy: 0.5575 - val_loss: 0.6339 - learning_rate: 0.0010
# Epoch 11/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7798 - loss: 0.3359 - val_accuracy: 0.6022 - val_loss: 0.6320 - learning_rate: 0.0010
# Epoch 12/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7817 - loss: 0.3310 - val_accuracy: 0.6022 - val_loss: 0.6296 - learning_rate: 0.0010
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7779 - loss: 0.3280 - val_accuracy: 0.5575 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 14/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7771 - loss: 0.3275 - val_accuracy: 0.5656 - val_loss: 0.6376 - learning_rate: 0.0010
# Epoch 15/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7912 - loss: 0.3296 - val_accuracy: 0.5616 - val_loss: 0.6375 - learning_rate: 0.0010
# Epoch 16/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.3392 - val_accuracy: 0.5602 - val_loss: 0.7036 - learning_rate: 0.0010
# Epoch 17/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.3336 - val_accuracy: 0.5453 - val_loss: 0.7142 - learning_rate: 0.0010
# Epoch 18/100
# 210/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.3301
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7889 - loss: 0.3287 - val_accuracy: 0.5589 - val_loss: 0.6480 - learning_rate: 0.0010
# Epoch 19/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7895 - loss: 0.3208 - val_accuracy: 0.6035 - val_loss: 0.6272 - learning_rate: 5.0000e-04
# Epoch 20/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7847 - loss: 0.3201 - val_accuracy: 0.6062 - val_loss: 0.6266 - learning_rate: 5.0000e-04
# Epoch 21/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7820 - loss: 0.3169 - val_accuracy: 0.6089 - val_loss: 0.6246 - learning_rate: 5.0000e-04
# Epoch 22/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7817 - loss: 0.3168 - val_accuracy: 0.5995 - val_loss: 0.6218 - learning_rate: 5.0000e-04
# Epoch 23/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7931 - loss: 0.3159 - val_accuracy: 0.5521 - val_loss: 0.6249 - learning_rate: 5.0000e-04
# Epoch 24/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7888 - loss: 0.3174 - val_accuracy: 0.5589 - val_loss: 0.6312 - learning_rate: 5.0000e-04
# Epoch 25/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.3146 - val_accuracy: 0.6008 - val_loss: 0.6226 - learning_rate: 5.0000e-04
# Epoch 26/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7889 - loss: 0.3151 - val_accuracy: 0.5981 - val_loss: 0.6207 - learning_rate: 5.0000e-04
# Epoch 27/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7856 - loss: 0.3187 - val_accuracy: 0.5995 - val_loss: 0.6219 - learning_rate: 5.0000e-04
# Epoch 28/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7907 - loss: 0.3181 - val_accuracy: 0.5968 - val_loss: 0.6195 - learning_rate: 5.0000e-04
# Epoch 29/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7876 - loss: 0.3138 - val_accuracy: 0.5981 - val_loss: 0.6204 - learning_rate: 5.0000e-04
# Epoch 30/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7885 - loss: 0.3125 - val_accuracy: 0.5968 - val_loss: 0.6239 - learning_rate: 5.0000e-04
# Epoch 31/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7873 - loss: 0.3132 - val_accuracy: 0.5521 - val_loss: 0.6204 - learning_rate: 5.0000e-04
# Epoch 32/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.3113 - val_accuracy: 0.6008 - val_loss: 0.6200 - learning_rate: 5.0000e-04
# Epoch 33/100
# 210/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7857 - loss: 0.3115
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7920 - loss: 0.3114 - val_accuracy: 0.5981 - val_loss: 0.6214 - learning_rate: 5.0000e-04
# Epoch 34/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7963 - loss: 0.3065 - val_accuracy: 0.6035 - val_loss: 0.6175 - learning_rate: 2.5000e-04
# Epoch 35/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7947 - loss: 0.3068 - val_accuracy: 0.6022 - val_loss: 0.6281 - learning_rate: 2.5000e-04
# Epoch 36/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7873 - loss: 0.3071 - val_accuracy: 0.6062 - val_loss: 0.6257 - learning_rate: 2.5000e-04
# Epoch 37/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7885 - loss: 0.3079 - val_accuracy: 0.6049 - val_loss: 0.6242 - learning_rate: 2.5000e-04
# Epoch 38/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7917 - loss: 0.3074 - val_accuracy: 0.6157 - val_loss: 0.6212 - learning_rate: 2.5000e-04
# Epoch 39/100
# 203/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7876 - loss: 0.3079
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7935 - loss: 0.3062 - val_accuracy: 0.6049 - val_loss: 0.6253 - learning_rate: 2.5000e-04
# Epoch 40/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7947 - loss: 0.3017 - val_accuracy: 0.6049 - val_loss: 0.6221 - learning_rate: 1.2500e-04
# Epoch 41/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7975 - loss: 0.3011 - val_accuracy: 0.6008 - val_loss: 0.6226 - learning_rate: 1.2500e-04
# Epoch 42/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7959 - loss: 0.3016 - val_accuracy: 0.6008 - val_loss: 0.6250 - learning_rate: 1.2500e-04
# Epoch 43/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.3006 - val_accuracy: 0.6049 - val_loss: 0.6291 - learning_rate: 1.2500e-04
# Epoch 44/100
# 197/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - loss: 0.3010
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7933 - loss: 0.3008 - val_accuracy: 0.6022 - val_loss: 0.6285 - learning_rate: 1.2500e-04
# Epoch 45/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7999 - loss: 0.2981 - val_accuracy: 0.6022 - val_loss: 0.6291 - learning_rate: 6.2500e-05
# Epoch 46/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7973 - loss: 0.2983 - val_accuracy: 0.6022 - val_loss: 0.6322 - learning_rate: 6.2500e-05
# Epoch 47/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8005 - loss: 0.2991 - val_accuracy: 0.6062 - val_loss: 0.6306 - learning_rate: 6.2500e-05
# Epoch 48/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7973 - loss: 0.2972 - val_accuracy: 0.6022 - val_loss: 0.6318 - learning_rate: 6.2500e-05
# Epoch 49/100
# 209/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.3017
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7998 - loss: 0.2999 - val_accuracy: 0.6076 - val_loss: 0.6311 - learning_rate: 6.2500e-05
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 34.
#
# Training selesai dalam 39.25 detik
# Total epoch berjalan: 49
#
# ============================================================
# HASIL CNN + ACGAN - VALIDATION SET
# ============================================================
# Accuracy  : 0.6035
# Precision : 0.6454
# Recall    : 0.6035
# F1-Score  : 0.5709
#
# Confusion Matrix:
# [[120 247]
#  [ 46 326]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.72      0.33      0.45       367
#  Label 1 (After)       0.57      0.88      0.69       372
#
#         accuracy                           0.60       739
#        macro avg       0.65      0.60      0.57       739
#     weighted avg       0.65      0.60      0.57       739
#
# ============================================================
# HASIL CNN + ACGAN - TEST SET
# ============================================================
# Accuracy  : 0.5924
# Precision : 0.6294
# Recall    : 0.5924
# F1-Score  : 0.5599
#
# Confusion Matrix:
# [[118 251]
#  [ 51 321]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.32      0.44       369
#  Label 1 (After)       0.56      0.86      0.68       372
#
#         accuracy                           0.59       741
#        macro avg       0.63      0.59      0.56       741
#     weighted avg       0.63      0.59      0.56       741

# %%
# ============================================================
# TAHAP 5D: Ringkasan Baseline vs ACGAN
# ============================================================

import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

comparison_results = []

# ----------------------------
# Baseline Results
# ----------------------------

comparison_results.append({
    "Experiment": "Baseline",
    "Model": "SVM",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_svm),
    "Val Precision": precision_score(y_val, y_pred_val_svm, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_svm, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_svm, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_svm),
    "Test Precision": precision_score(y_test, y_pred_test_svm, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_svm, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_svm, average='weighted')
})

comparison_results.append({
    "Experiment": "Baseline",
    "Model": "Random Forest",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_rf),
    "Val Precision": precision_score(y_val, y_pred_val_rf, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_rf, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_rf, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_rf),
    "Test Precision": precision_score(y_test, y_pred_test_rf, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_rf, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_rf, average='weighted')
})

comparison_results.append({
    "Experiment": "Baseline",
    "Model": "CNN",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_cnn),
    "Val Precision": precision_score(y_val, y_pred_val_cnn, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_cnn, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_cnn, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_cnn),
    "Test Precision": precision_score(y_test, y_pred_test_cnn, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_cnn, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_cnn, average='weighted')
})

# ----------------------------
# ACGAN Results
# ----------------------------

comparison_results.append({
    "Experiment": "ACGAN Augmented",
    "Model": "SVM",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_svm_acgan),
    "Val Precision": precision_score(y_val, y_pred_val_svm_acgan, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_svm_acgan, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_svm_acgan, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_svm_acgan),
    "Test Precision": precision_score(y_test, y_pred_test_svm_acgan, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_svm_acgan, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_svm_acgan, average='weighted')
})

comparison_results.append({
    "Experiment": "ACGAN Augmented",
    "Model": "Random Forest",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_rf_acgan),
    "Val Precision": precision_score(y_val, y_pred_val_rf_acgan, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_rf_acgan, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_rf_acgan, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_rf_acgan),
    "Test Precision": precision_score(y_test, y_pred_test_rf_acgan, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_rf_acgan, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_rf_acgan, average='weighted')
})

comparison_results.append({
    "Experiment": "ACGAN Augmented",
    "Model": "CNN",
    "Val Accuracy": accuracy_score(y_val, y_pred_val_cnn_acgan),
    "Val Precision": precision_score(y_val, y_pred_val_cnn_acgan, average='weighted'),
    "Val Recall": recall_score(y_val, y_pred_val_cnn_acgan, average='weighted'),
    "Val F1": f1_score(y_val, y_pred_val_cnn_acgan, average='weighted'),
    "Test Accuracy": accuracy_score(y_test, y_pred_test_cnn_acgan),
    "Test Precision": precision_score(y_test, y_pred_test_cnn_acgan, average='weighted'),
    "Test Recall": recall_score(y_test, y_pred_test_cnn_acgan, average='weighted'),
    "Test F1": f1_score(y_test, y_pred_test_cnn_acgan, average='weighted')
})

df_comparison_results = pd.DataFrame(comparison_results)

print("=== Baseline vs ACGAN Augmented Results ===")
display(df_comparison_results.round(4))

# Simpan hasil ke CSV
df_comparison_results.to_csv("gamma_only_baseline_vs_acgan_results.csv", index=False)

print("Hasil perbandingan disimpan sebagai gamma_only_baseline_vs_acgan_results.csv")
# Out:
# === Baseline vs ACGAN Augmented Results ===
#         Experiment          Model  Val Accuracy  Val Precision  Val Recall  \
# 0         Baseline            SVM        0.5940         0.6587      0.5940
# 1         Baseline  Random Forest        0.6495         0.7271      0.6495
# 2         Baseline            CNN        0.5656         0.7144      0.5656
# 3  ACGAN Augmented            SVM        0.5656         0.6685      0.5656
# 4  ACGAN Augmented  Random Forest        0.6509         0.7303      0.6509
# 5  ACGAN Augmented            CNN        0.6035         0.6454      0.6035
#
#    Val F1  Test Accuracy  Test Precision  Test Recall  Test F1
# 0  0.5458         0.5749          0.6333       0.5749   0.5210
# 1  0.6155         0.6410          0.7339       0.6410   0.6006
# 2  0.4771         0.5682          0.7355       0.5682   0.4764
# 3  0.4903         0.5749          0.7161       0.5749   0.4934
# 4  0.6167         0.6424          0.7348       0.6424   0.6025
# 5  0.5709         0.5924          0.6294       0.5924   0.5599
# Hasil perbandingan disimpan sebagai gamma_only_baseline_vs_acgan_results.csv

# %%
# ============================================================
# TAHAP 5: Train Ulang SVM, RF, CNN dengan ACGAN Augmented
# Versi eksperimen: synthetic data dipakai untuk train, validation, dan test
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
import time

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv1D, MaxPooling1D, Flatten, Dense,
    Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ============================================================
# 1. FUNGSI UNTUK GENERATE SYNTHETIC DATA BERDASARKAN DISTRIBUSI LABEL
# ============================================================

def generate_synthetic_by_label_distribution(y_reference, generator, noise_dim):
    """
    Membuat synthetic data dengan jumlah label 0 dan label 1
    mengikuti distribusi label dari y_reference.
    """
    y_reference = np.array(y_reference).astype(int)

    n_label_0 = np.sum(y_reference == 0)
    n_label_1 = np.sum(y_reference == 1)

    # Generate synthetic label 0
    noise_0 = np.random.normal(0, 1, (n_label_0, noise_dim))
    labels_0 = np.zeros((n_label_0, 1), dtype=int)
    X_synth_0 = generator.predict([noise_0, labels_0], verbose=0)
    y_synth_0 = np.zeros(n_label_0, dtype=int)

    # Generate synthetic label 1
    noise_1 = np.random.normal(0, 1, (n_label_1, noise_dim))
    labels_1 = np.ones((n_label_1, 1), dtype=int)
    X_synth_1 = generator.predict([noise_1, labels_1], verbose=0)
    y_synth_1 = np.ones(n_label_1, dtype=int)

    X_synth = np.vstack([X_synth_0, X_synth_1])
    y_synth = np.concatenate([y_synth_0, y_synth_1])

    X_synth, y_synth = shuffle(X_synth, y_synth, random_state=42)

    return X_synth, y_synth


# ============================================================
# 2. BUAT SYNTHETIC DATA UNTUK TRAIN, VALIDATION, DAN TEST
# ============================================================

np.random.seed(42)
tf.random.set_seed(42)

# Train synthetic sudah pernah dibuat di Tahap 4:
# X_synth_scaled, y_synth
# Tapi untuk konsistensi, kita buat ulang berdasarkan distribusi y_train
X_synth_train_scaled, y_synth_train = generate_synthetic_by_label_distribution(
    y_train, generator, noise_dim
)

X_synth_val_scaled, y_synth_val = generate_synthetic_by_label_distribution(
    y_val, generator, noise_dim
)

X_synth_test_scaled, y_synth_test = generate_synthetic_by_label_distribution(
    y_test, generator, noise_dim
)

print("=== Synthetic Data per Split ===")
print(f"Train synthetic      : {X_synth_train_scaled.shape}, {y_synth_train.shape}")
print(f"Validation synthetic : {X_synth_val_scaled.shape}, {y_synth_val.shape}")
print(f"Test synthetic       : {X_synth_test_scaled.shape}, {y_synth_test.shape}")

print("\nDistribusi label synthetic train:")
print(pd.Series(y_synth_train).value_counts().sort_index())

print("\nDistribusi label synthetic validation:")
print(pd.Series(y_synth_val).value_counts().sort_index())

print("\nDistribusi label synthetic test:")
print(pd.Series(y_synth_test).value_counts().sort_index())


# ============================================================
# 3. GABUNGKAN REAL + SYNTHETIC UNTUK TRAIN, VALIDATION, DAN TEST
# ============================================================

# Scaled data untuk SVM dan CNN
X_train_mix_scaled = np.vstack([X_train_scaled, X_synth_train_scaled])
y_train_mix = np.concatenate([np.array(y_train), y_synth_train])

X_val_mix_scaled = np.vstack([X_val_scaled, X_synth_val_scaled])
y_val_mix = np.concatenate([np.array(y_val), y_synth_val])

X_test_mix_scaled = np.vstack([X_test_scaled, X_synth_test_scaled])
y_test_mix = np.concatenate([np.array(y_test), y_synth_test])

# Shuffle tiap split
X_train_mix_scaled, y_train_mix = shuffle(X_train_mix_scaled, y_train_mix, random_state=42)
X_val_mix_scaled, y_val_mix = shuffle(X_val_mix_scaled, y_val_mix, random_state=42)
X_test_mix_scaled, y_test_mix = shuffle(X_test_mix_scaled, y_test_mix, random_state=42)

print("\n=== Mixed Scaled Data, Real + Synthetic ===")
print(f"X_train_mix_scaled : {X_train_mix_scaled.shape}")
print(f"y_train_mix        : {y_train_mix.shape}")
print(f"X_val_mix_scaled   : {X_val_mix_scaled.shape}")
print(f"y_val_mix          : {y_val_mix.shape}")
print(f"X_test_mix_scaled  : {X_test_mix_scaled.shape}")
print(f"y_test_mix         : {y_test_mix.shape}")

# Unscaled data untuk Random Forest
X_synth_train_unscaled = scaler.inverse_transform(X_synth_train_scaled)
X_synth_val_unscaled = scaler.inverse_transform(X_synth_val_scaled)
X_synth_test_unscaled = scaler.inverse_transform(X_synth_test_scaled)

X_train_mix_unscaled = np.vstack([X_train_unscaled, X_synth_train_unscaled])
y_train_mix_rf = np.concatenate([np.array(y_train), y_synth_train])

X_val_mix_unscaled = np.vstack([X_val_unscaled, X_synth_val_unscaled])
y_val_mix_rf = np.concatenate([np.array(y_val), y_synth_val])

X_test_mix_unscaled = np.vstack([X_test_unscaled, X_synth_test_unscaled])
y_test_mix_rf = np.concatenate([np.array(y_test), y_synth_test])

X_train_mix_unscaled, y_train_mix_rf = shuffle(X_train_mix_unscaled, y_train_mix_rf, random_state=42)
X_val_mix_unscaled, y_val_mix_rf = shuffle(X_val_mix_unscaled, y_val_mix_rf, random_state=42)
X_test_mix_unscaled, y_test_mix_rf = shuffle(X_test_mix_unscaled, y_test_mix_rf, random_state=42)

# CNN reshape
X_train_mix_cnn = X_train_mix_scaled.reshape(-1, feature_dim, 1)
X_val_mix_cnn = X_val_mix_scaled.reshape(-1, feature_dim, 1)
X_test_mix_cnn = X_test_mix_scaled.reshape(-1, feature_dim, 1)

print("\n=== Data Siap untuk Model ===")
print(f"SVM train : {X_train_mix_scaled.shape}")
print(f"SVM val   : {X_val_mix_scaled.shape}")
print(f"SVM test  : {X_test_mix_scaled.shape}")

print(f"RF train  : {X_train_mix_unscaled.shape}")
print(f"RF val    : {X_val_mix_unscaled.shape}")
print(f"RF test   : {X_test_mix_unscaled.shape}")

print(f"CNN train : {X_train_mix_cnn.shape}")
print(f"CNN val   : {X_val_mix_cnn.shape}")
print(f"CNN test  : {X_test_mix_cnn.shape}")


# ============================================================
# 4. FUNGSI EVALUASI
# ============================================================

def evaluate_model(model_name, y_val_true, y_val_pred, y_test_true, y_test_pred):
    print("\n" + "="*70)
    print(f"HASIL {model_name} - VALIDATION SET, REAL + SYNTHETIC")
    print("="*70)
    print(f"Accuracy  : {accuracy_score(y_val_true, y_val_pred):.4f}")
    print(f"Precision : {precision_score(y_val_true, y_val_pred, average='weighted'):.4f}")
    print(f"Recall    : {recall_score(y_val_true, y_val_pred, average='weighted'):.4f}")
    print(f"F1-Score  : {f1_score(y_val_true, y_val_pred, average='weighted'):.4f}")
    print(f"\nConfusion Matrix:\n{confusion_matrix(y_val_true, y_val_pred)}")
    print(f"\n{classification_report(y_val_true, y_val_pred, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

    print("="*70)
    print(f"HASIL {model_name} - TEST SET, REAL + SYNTHETIC")
    print("="*70)
    print(f"Accuracy  : {accuracy_score(y_test_true, y_test_pred):.4f}")
    print(f"Precision : {precision_score(y_test_true, y_test_pred, average='weighted'):.4f}")
    print(f"Recall    : {recall_score(y_test_true, y_test_pred, average='weighted'):.4f}")
    print(f"F1-Score  : {f1_score(y_test_true, y_test_pred, average='weighted'):.4f}")
    print(f"\nConfusion Matrix:\n{confusion_matrix(y_test_true, y_test_pred)}")
    print(f"\n{classification_report(y_test_true, y_test_pred, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")


# ============================================================
# 5. TRAIN SVM DENGAN REAL + SYNTHETIC TRAIN
# EVALUASI PADA REAL + SYNTHETIC VALIDATION/TEST
# ============================================================

print("\n\nTraining SVM dengan train real + synthetic...")
start = time.time()

svm_mix_model = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    random_state=42
)

svm_mix_model.fit(X_train_mix_scaled, y_train_mix)

svm_train_time = time.time() - start
print(f"Training SVM selesai dalam {svm_train_time:.2f} detik")

y_pred_val_svm_mix = svm_mix_model.predict(X_val_mix_scaled)
y_pred_test_svm_mix = svm_mix_model.predict(X_test_mix_scaled)

evaluate_model(
    "SVM + ACGAN MIXED",
    y_val_mix, y_pred_val_svm_mix,
    y_test_mix, y_pred_test_svm_mix
)


# ============================================================
# 6. TRAIN RANDOM FOREST DENGAN REAL + SYNTHETIC TRAIN
# EVALUASI PADA REAL + SYNTHETIC VALIDATION/TEST
# ============================================================

print("\n\nTraining Random Forest dengan train real + synthetic...")
start = time.time()

rf_mix_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf_mix_model.fit(X_train_mix_unscaled, y_train_mix_rf)

rf_train_time = time.time() - start
print(f"Training Random Forest selesai dalam {rf_train_time:.2f} detik")

y_pred_val_rf_mix = rf_mix_model.predict(X_val_mix_unscaled)
y_pred_test_rf_mix = rf_mix_model.predict(X_test_mix_unscaled)

evaluate_model(
    "RANDOM FOREST + ACGAN MIXED",
    y_val_mix_rf, y_pred_val_rf_mix,
    y_test_mix_rf, y_pred_test_rf_mix
)

print("\nFeature Importance RF + ACGAN Mixed:")
feat_imp_rf_mix = sorted(
    zip(gamma_cols, rf_mix_model.feature_importances_),
    key=lambda x: x[1],
    reverse=True
)

for feat, imp in feat_imp_rf_mix:
    print(f"{feat:30s} : {imp:.4f}")


# ============================================================
# 7. TRAIN CNN DENGAN REAL + SYNTHETIC TRAIN
# EVALUASI PADA REAL + SYNTHETIC VALIDATION/TEST
# ============================================================

print("\n\nTraining CNN dengan train real + synthetic...")

tf.random.set_seed(42)

model_cnn_mix = Sequential([
    Input(shape=(feature_dim, 1)),

    Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Flatten(),

    Dense(64, activation='relu'),
    Dropout(0.5),

    Dense(32, activation='relu'),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

model_cnn_mix.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model_cnn_mix.summary()

early_stop_mix = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_mix = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

start = time.time()

history_cnn_mix = model_cnn_mix.fit(
    X_train_mix_cnn, y_train_mix,
    validation_data=(X_val_mix_cnn, y_val_mix),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_mix, reduce_lr_mix],
    verbose=1
)

cnn_train_time = time.time() - start
print(f"\nTraining CNN selesai dalam {cnn_train_time:.2f} detik")
print(f"Total epoch berjalan: {len(history_cnn_mix.history['loss'])}")

y_prob_val_cnn_mix = model_cnn_mix.predict(X_val_mix_cnn, verbose=0).flatten()
y_prob_test_cnn_mix = model_cnn_mix.predict(X_test_mix_cnn, verbose=0).flatten()

y_pred_val_cnn_mix = (y_prob_val_cnn_mix >= 0.5).astype(int)
y_pred_test_cnn_mix = (y_prob_test_cnn_mix >= 0.5).astype(int)

evaluate_model(
    "CNN + ACGAN MIXED",
    y_val_mix, y_pred_val_cnn_mix,
    y_test_mix, y_pred_test_cnn_mix
)


# ============================================================
# 8. RINGKASAN HASIL MIXED, REAL + SYNTHETIC DI SEMUA SPLIT
# ============================================================

mixed_results = []

mixed_results.append({
    "Experiment": "ACGAN Mixed Train-Val-Test",
    "Model": "SVM",
    "Val Accuracy": accuracy_score(y_val_mix, y_pred_val_svm_mix),
    "Val Precision": precision_score(y_val_mix, y_pred_val_svm_mix, average='weighted'),
    "Val Recall": recall_score(y_val_mix, y_pred_val_svm_mix, average='weighted'),
    "Val F1": f1_score(y_val_mix, y_pred_val_svm_mix, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix, y_pred_test_svm_mix),
    "Test Precision": precision_score(y_test_mix, y_pred_test_svm_mix, average='weighted'),
    "Test Recall": recall_score(y_test_mix, y_pred_test_svm_mix, average='weighted'),
    "Test F1": f1_score(y_test_mix, y_pred_test_svm_mix, average='weighted')
})

mixed_results.append({
    "Experiment": "ACGAN Mixed Train-Val-Test",
    "Model": "Random Forest",
    "Val Accuracy": accuracy_score(y_val_mix_rf, y_pred_val_rf_mix),
    "Val Precision": precision_score(y_val_mix_rf, y_pred_val_rf_mix, average='weighted'),
    "Val Recall": recall_score(y_val_mix_rf, y_pred_val_rf_mix, average='weighted'),
    "Val F1": f1_score(y_val_mix_rf, y_pred_val_rf_mix, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix_rf, y_pred_test_rf_mix),
    "Test Precision": precision_score(y_test_mix_rf, y_pred_test_rf_mix, average='weighted'),
    "Test Recall": recall_score(y_test_mix_rf, y_pred_test_rf_mix, average='weighted'),
    "Test F1": f1_score(y_test_mix_rf, y_pred_test_rf_mix, average='weighted')
})

mixed_results.append({
    "Experiment": "ACGAN Mixed Train-Val-Test",
    "Model": "CNN",
    "Val Accuracy": accuracy_score(y_val_mix, y_pred_val_cnn_mix),
    "Val Precision": precision_score(y_val_mix, y_pred_val_cnn_mix, average='weighted'),
    "Val Recall": recall_score(y_val_mix, y_pred_val_cnn_mix, average='weighted'),
    "Val F1": f1_score(y_val_mix, y_pred_val_cnn_mix, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix, y_pred_test_cnn_mix),
    "Test Precision": precision_score(y_test_mix, y_pred_test_cnn_mix, average='weighted'),
    "Test Recall": recall_score(y_test_mix, y_pred_test_cnn_mix, average='weighted'),
    "Test F1": f1_score(y_test_mix, y_pred_test_cnn_mix, average='weighted')
})

df_mixed_results = pd.DataFrame(mixed_results)

print("\n=== RINGKASAN HASIL ACGAN MIXED TRAIN-VALIDATION-TEST ===")
display(df_mixed_results.round(4))

df_mixed_results.to_csv("gamma_only_acgan_mixed_train_val_test_results.csv", index=False)

print("\nHasil disimpan sebagai gamma_only_acgan_mixed_train_val_test_results.csv")
# Out:
# === Synthetic Data per Split ===
# Train synthetic      : (3456, 8), (3456,)
# Validation synthetic : (739, 8), (739,)
# Test synthetic       : (741, 8), (741,)
#
# Distribusi label synthetic train:
# 0    1719
# 1    1737
# Name: count, dtype: int64
#
# Distribusi label synthetic validation:
# 0    367
# 1    372
# Name: count, dtype: int64
#
# Distribusi label synthetic test:
# 0    369
# 1    372
# Name: count, dtype: int64
#
# === Mixed Scaled Data, Real + Synthetic ===
# X_train_mix_scaled : (6912, 8)
# y_train_mix        : (6912,)
# X_val_mix_scaled   : (1478, 8)
# y_val_mix          : (1478,)
# X_test_mix_scaled  : (1482, 8)
# y_test_mix         : (1482,)
#
# === Data Siap untuk Model ===
# SVM train : (6912, 8)
# SVM val   : (1478, 8)
# SVM test  : (1482, 8)
# RF train  : (6912, 8)
# RF val    : (1478, 8)
# RF test   : (1482, 8)
# CNN train : (6912, 8, 1)
# CNN val   : (1478, 8, 1)
# CNN test  : (1482, 8, 1)
#
#
# Training SVM dengan train real + synthetic...
# Training SVM selesai dalam 1.07 detik
#
# ======================================================================
# HASIL SVM + ACGAN MIXED - VALIDATION SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.7815
# Precision : 0.8335
# Recall    : 0.7815
# F1-Score  : 0.7730
#
# Confusion Matrix:
# [[718  16]
#  [307 437]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.98      0.82       734
#  Label 1 (After)       0.96      0.59      0.73       744
#
#         accuracy                           0.78      1478
#        macro avg       0.83      0.78      0.77      1478
#     weighted avg       0.83      0.78      0.77      1478
#
# ======================================================================
# HASIL SVM + ACGAN MIXED - TEST SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.7881
# Precision : 0.8439
# Recall    : 0.7881
# F1-Score  : 0.7794
#
# Confusion Matrix:
# [[730   8]
#  [306 438]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.99      0.82       738
#  Label 1 (After)       0.98      0.59      0.74       744
#
#         accuracy                           0.79      1482
#        macro avg       0.84      0.79      0.78      1482
#     weighted avg       0.84      0.79      0.78      1482
#
#
#
# Training Random Forest dengan train real + synthetic...
# Training Random Forest selesai dalam 0.72 detik
#
# ======================================================================
# HASIL RANDOM FOREST + ACGAN MIXED - VALIDATION SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.8227
# Precision : 0.8532
# Recall    : 0.8227
# F1-Score  : 0.8186
#
# Confusion Matrix:
# [[494 240]
#  [ 22 722]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.96      0.67      0.79       734
#  Label 1 (After)       0.75      0.97      0.85       744
#
#         accuracy                           0.82      1478
#        macro avg       0.85      0.82      0.82      1478
#     weighted avg       0.85      0.82      0.82      1478
#
# ======================================================================
# HASIL RANDOM FOREST + ACGAN MIXED - TEST SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.8212
# Precision : 0.8556
# Recall    : 0.8212
# F1-Score  : 0.8166
#
# Confusion Matrix:
# [[490 248]
#  [ 17 727]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.66      0.79       738
#  Label 1 (After)       0.75      0.98      0.85       744
#
#         accuracy                           0.82      1482
#        macro avg       0.86      0.82      0.82      1482
#     weighted avg       0.86      0.82      0.82      1482
#
#
# Feature Importance RF + ACGAN Mixed:
# RAW_TP9_BP_Gamma               : 0.2327
# RAW_TP10_BP_Gamma              : 0.1722
# RAW_TP9_RP_Gamma               : 0.1339
# RAW_AF8_BP_Gamma               : 0.1160
# RAW_TP10_RP_Gamma              : 0.1142
# RAW_AF8_RP_Gamma               : 0.1042
# RAW_AF7_BP_Gamma               : 0.0635
# RAW_AF7_RP_Gamma               : 0.0633
#
#
# Training CNN dengan train real + synthetic...
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 8, 32)          │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 4, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 4, 64)          │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 4, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,089 (66.75 KB)
#  Trainable params: 16,897 (66.00 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7474 - loss: 0.4854 - val_accuracy: 0.7375 - val_loss: 0.4878 - learning_rate: 0.0010
# Epoch 2/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7682 - loss: 0.4026 - val_accuracy: 0.7652 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 3/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7760 - loss: 0.3787 - val_accuracy: 0.7808 - val_loss: 0.3805 - learning_rate: 0.0010
# Epoch 4/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7730 - loss: 0.3688 - val_accuracy: 0.7794 - val_loss: 0.3996 - learning_rate: 0.0010
# Epoch 5/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7781 - loss: 0.3566 - val_accuracy: 0.7781 - val_loss: 0.3813 - learning_rate: 0.0010
# Epoch 6/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7785 - loss: 0.3554 - val_accuracy: 0.7754 - val_loss: 0.4055 - learning_rate: 0.0010
# Epoch 7/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7752 - loss: 0.3462 - val_accuracy: 0.7801 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 8/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7821 - loss: 0.3353 - val_accuracy: 0.7747 - val_loss: 0.3561 - learning_rate: 0.0010
# Epoch 9/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7821 - loss: 0.3317 - val_accuracy: 0.7760 - val_loss: 0.3572 - learning_rate: 0.0010
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7755 - loss: 0.3330 - val_accuracy: 0.7747 - val_loss: 0.3304 - learning_rate: 0.0010
# Epoch 11/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7820 - loss: 0.3319 - val_accuracy: 0.7930 - val_loss: 0.3340 - learning_rate: 0.0010
# Epoch 12/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7814 - loss: 0.3316 - val_accuracy: 0.7794 - val_loss: 0.3281 - learning_rate: 0.0010
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7799 - loss: 0.3334 - val_accuracy: 0.7801 - val_loss: 0.3507 - learning_rate: 0.0010
# Epoch 14/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7827 - loss: 0.3344 - val_accuracy: 0.7794 - val_loss: 0.3279 - learning_rate: 0.0010
# Epoch 15/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7827 - loss: 0.3282 - val_accuracy: 0.7808 - val_loss: 0.3242 - learning_rate: 0.0010
# Epoch 16/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.3270 - val_accuracy: 0.8018 - val_loss: 0.3178 - learning_rate: 0.0010
# Epoch 17/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7839 - loss: 0.3246 - val_accuracy: 0.8024 - val_loss: 0.3206 - learning_rate: 0.0010
# Epoch 18/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7811 - loss: 0.3255 - val_accuracy: 0.7815 - val_loss: 0.3198 - learning_rate: 0.0010
# Epoch 19/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7878 - loss: 0.3214 - val_accuracy: 0.8018 - val_loss: 0.3235 - learning_rate: 0.0010
# Epoch 20/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.3277 - val_accuracy: 0.7997 - val_loss: 0.3238 - learning_rate: 0.0010
# Epoch 21/100
# 210/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7807 - loss: 0.3222
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7844 - loss: 0.3225 - val_accuracy: 0.8024 - val_loss: 0.3284 - learning_rate: 0.0010
# Epoch 22/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7924 - loss: 0.3216 - val_accuracy: 0.8011 - val_loss: 0.3191 - learning_rate: 5.0000e-04
# Epoch 23/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7860 - loss: 0.3208 - val_accuracy: 0.8011 - val_loss: 0.3187 - learning_rate: 5.0000e-04
# Epoch 24/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7794 - loss: 0.3176 - val_accuracy: 0.7991 - val_loss: 0.3192 - learning_rate: 5.0000e-04
# Epoch 25/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.3161 - val_accuracy: 0.7997 - val_loss: 0.3173 - learning_rate: 5.0000e-04
# Epoch 26/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7843 - loss: 0.3132 - val_accuracy: 0.8004 - val_loss: 0.3194 - learning_rate: 5.0000e-04
# Epoch 27/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7805 - loss: 0.3136 - val_accuracy: 0.7991 - val_loss: 0.3210 - learning_rate: 5.0000e-04
# Epoch 28/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7899 - loss: 0.3142 - val_accuracy: 0.7788 - val_loss: 0.3570 - learning_rate: 5.0000e-04
# Epoch 29/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7843 - loss: 0.3131 - val_accuracy: 0.7788 - val_loss: 0.3092 - learning_rate: 5.0000e-04
# Epoch 30/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7896 - loss: 0.3139 - val_accuracy: 0.7936 - val_loss: 0.3209 - learning_rate: 5.0000e-04
# Epoch 31/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7826 - loss: 0.3122 - val_accuracy: 0.7970 - val_loss: 0.3223 - learning_rate: 5.0000e-04
# Epoch 32/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7843 - loss: 0.3143 - val_accuracy: 0.7991 - val_loss: 0.3175 - learning_rate: 5.0000e-04
# Epoch 33/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.3098 - val_accuracy: 0.8004 - val_loss: 0.3186 - learning_rate: 5.0000e-04
# Epoch 34/100
# 203/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7824 - loss: 0.3096
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7854 - loss: 0.3093 - val_accuracy: 0.8004 - val_loss: 0.3124 - learning_rate: 5.0000e-04
# Epoch 35/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7901 - loss: 0.3058 - val_accuracy: 0.8004 - val_loss: 0.3145 - learning_rate: 2.5000e-04
# Epoch 36/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7905 - loss: 0.3068 - val_accuracy: 0.7991 - val_loss: 0.3197 - learning_rate: 2.5000e-04
# Epoch 37/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7882 - loss: 0.3072 - val_accuracy: 0.8085 - val_loss: 0.3117 - learning_rate: 2.5000e-04
# Epoch 38/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7852 - loss: 0.3046 - val_accuracy: 0.8038 - val_loss: 0.3108 - learning_rate: 2.5000e-04
# Epoch 39/100
# 207/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.3044
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7967 - loss: 0.3019 - val_accuracy: 0.8045 - val_loss: 0.3109 - learning_rate: 2.5000e-04
# Epoch 40/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7866 - loss: 0.3014 - val_accuracy: 0.8099 - val_loss: 0.3082 - learning_rate: 1.2500e-04
# Epoch 41/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7876 - loss: 0.3010 - val_accuracy: 0.8031 - val_loss: 0.3072 - learning_rate: 1.2500e-04
# Epoch 42/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7938 - loss: 0.2997 - val_accuracy: 0.8024 - val_loss: 0.3077 - learning_rate: 1.2500e-04
# Epoch 43/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7966 - loss: 0.3012 - val_accuracy: 0.8092 - val_loss: 0.3101 - learning_rate: 1.2500e-04
# Epoch 44/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.3007 - val_accuracy: 0.8072 - val_loss: 0.3087 - learning_rate: 1.2500e-04
# Epoch 45/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7954 - loss: 0.2985 - val_accuracy: 0.8024 - val_loss: 0.3097 - learning_rate: 1.2500e-04
# Epoch 46/100
# 208/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.3003
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7979 - loss: 0.3001 - val_accuracy: 0.8058 - val_loss: 0.3094 - learning_rate: 1.2500e-04
# Epoch 47/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7963 - loss: 0.2970 - val_accuracy: 0.8072 - val_loss: 0.3087 - learning_rate: 6.2500e-05
# Epoch 48/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7998 - loss: 0.2977 - val_accuracy: 0.8058 - val_loss: 0.3088 - learning_rate: 6.2500e-05
# Epoch 49/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.2975 - val_accuracy: 0.8051 - val_loss: 0.3085 - learning_rate: 6.2500e-05
# Epoch 50/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7986 - loss: 0.2977 - val_accuracy: 0.8078 - val_loss: 0.3087 - learning_rate: 6.2500e-05
# Epoch 51/100
# 201/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8103 - loss: 0.2984
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8019 - loss: 0.2963 - val_accuracy: 0.8085 - val_loss: 0.3107 - learning_rate: 6.2500e-05
# Epoch 52/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8025 - loss: 0.2953 - val_accuracy: 0.8072 - val_loss: 0.3104 - learning_rate: 3.1250e-05
# Epoch 53/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8079 - loss: 0.2966 - val_accuracy: 0.8065 - val_loss: 0.3101 - learning_rate: 3.1250e-05
# Epoch 54/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8025 - loss: 0.2957 - val_accuracy: 0.8072 - val_loss: 0.3095 - learning_rate: 3.1250e-05
# Epoch 55/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8019 - loss: 0.2966 - val_accuracy: 0.8058 - val_loss: 0.3095 - learning_rate: 3.1250e-05
# Epoch 56/100
# 208/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.2977
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8021 - loss: 0.2961 - val_accuracy: 0.8078 - val_loss: 0.3088 - learning_rate: 3.1250e-05
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 41.
#
# Training CNN selesai dalam 46.09 detik
# Total epoch berjalan: 56
#
# ======================================================================
# HASIL CNN + ACGAN MIXED - VALIDATION SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.8031
# Precision : 0.8255
# Recall    : 0.8031
# F1-Score  : 0.7994
#
# Confusion Matrix:
# [[491 243]
#  [ 48 696]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.91      0.67      0.77       734
#  Label 1 (After)       0.74      0.94      0.83       744
#
#         accuracy                           0.80      1478
#        macro avg       0.83      0.80      0.80      1478
#     weighted avg       0.83      0.80      0.80      1478
#
# ======================================================================
# HASIL CNN + ACGAN MIXED - TEST SET, REAL + SYNTHETIC
# ======================================================================
# Accuracy  : 0.7955
# Precision : 0.8188
# Recall    : 0.7955
# F1-Score  : 0.7916
#
# Confusion Matrix:
# [[486 252]
#  [ 51 693]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.91      0.66      0.76       738
#  Label 1 (After)       0.73      0.93      0.82       744
#
#         accuracy                           0.80      1482
#        macro avg       0.82      0.79      0.79      1482
#     weighted avg       0.82      0.80      0.79      1482
#
#
# === RINGKASAN HASIL ACGAN MIXED TRAIN-VALIDATION-TEST ===
#                    Experiment          Model  Val Accuracy  Val Precision  \
# 0  ACGAN Mixed Train-Val-Test            SVM        0.7815         0.8335
# 1  ACGAN Mixed Train-Val-Test  Random Forest        0.8227         0.8532
# 2  ACGAN Mixed Train-Val-Test            CNN        0.8031         0.8255
#
#    Val Recall  Val F1  Test Accuracy  Test Precision  Test Recall  Test F1
# 0      0.7815  0.7730         0.7881          0.8439       0.7881   0.7794
# 1      0.8227  0.8186         0.8212          0.8556       0.8212   0.8166
# 2      0.8031  0.7994         0.7955          0.8188       0.7955   0.7916
# Hasil disimpan sebagai gamma_only_acgan_mixed_train_val_test_results.csv

# %%
# ============================================================
# HYPERPARAMETER TUNING RANDOM FOREST
# ACGAN Mixed Train-Validation-Test
# ============================================================

import numpy as np
import pandas as pd
import time

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# ============================================================
# 1. Parameter Search Space
# ============================================================

rf_param_dist = {
    "n_estimators": [200, 300, 500, 700, 1000],
    "max_depth": [None, 5, 10, 15, 20, 30, 50],
    "min_samples_split": [2, 3, 5, 10],
    "min_samples_leaf": [1, 2, 3, 4],
    "max_features": ["sqrt", "log2", None],
    "bootstrap": [True, False],
    "class_weight": [None, "balanced"]
}

rf_base = RandomForestClassifier(
    random_state=42,
    n_jobs=-1
)

# ============================================================
# 2. Randomized Search
# ============================================================

print("Mulai tuning Random Forest...")
start = time.time()

rf_random_search = RandomizedSearchCV(
    estimator=rf_base,
    param_distributions=rf_param_dist,
    n_iter=60,
    scoring="accuracy",
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

rf_random_search.fit(X_train_mix_unscaled, y_train_mix_rf)

rf_tuning_time = time.time() - start

print("\nTuning Random Forest selesai.")
print(f"Waktu tuning: {rf_tuning_time:.2f} detik")
print("\nBest Parameters:")
print(rf_random_search.best_params_)
print(f"\nBest CV Accuracy: {rf_random_search.best_score_:.4f}")

# ============================================================
# 3. Evaluasi Best RF pada Validation dan Test Mixed
# ============================================================

best_rf_mix = rf_random_search.best_estimator_

y_pred_val_rf_tuned = best_rf_mix.predict(X_val_mix_unscaled)
y_pred_test_rf_tuned = best_rf_mix.predict(X_test_mix_unscaled)

print("\n" + "="*70)
print("HASIL TUNED RANDOM FOREST - VALIDATION SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_val_mix_rf, y_pred_val_rf_tuned):.4f}")
print(f"Precision : {precision_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val_mix_rf, y_pred_val_rf_tuned)}")
print(f"\n{classification_report(y_val_mix_rf, y_pred_val_rf_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

print("="*70)
print("HASIL TUNED RANDOM FOREST - TEST SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_test_mix_rf, y_pred_test_rf_tuned):.4f}")
print(f"Precision : {precision_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test_mix_rf, y_pred_test_rf_tuned)}")
print(f"\n{classification_report(y_test_mix_rf, y_pred_test_rf_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

# ============================================================
# 4. Feature Importance Tuned RF
# ============================================================

print("="*70)
print("FEATURE IMPORTANCE TUNED RANDOM FOREST")
print("="*70)

rf_tuned_importance = sorted(
    zip(gamma_cols, best_rf_mix.feature_importances_),
    key=lambda x: x[1],
    reverse=True
)

for feat, imp in rf_tuned_importance:
    print(f"{feat:30s} : {imp:.4f}")
# Out:
# Mulai tuning Random Forest...
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=  13.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   5.3s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   5.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  12.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  40.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  10.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   5.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=700; total time=   8.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  13.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   8.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1000; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   6.3s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   9.5s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=  26.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=  27.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   6.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   5.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=   8.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   9.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  19.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   5.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   5.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s[CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=  13.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   5.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  14.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  12.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  42.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   5.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  10.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  10.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=700; total time=   8.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  13.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  14.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   8.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1000; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   5.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   5.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   3.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=  25.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   9.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   6.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=   8.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   9.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  20.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   5.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   5.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=1000; total time=  27.4s[CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   5.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   5.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  46.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  10.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=   9.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=700; total time=   8.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=700; total time=   7.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   8.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1000; total time=   8.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1000; total time=   9.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   5.3s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   6.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=  27.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   9.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   8.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   6.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   6.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   9.9s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  20.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=1000; total time=  27.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  11.6s[CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=  15.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=  12.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  13.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  45.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  38.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=700; total time=   8.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  14.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  16.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  14.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1000; total time=   8.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   7.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   6.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   6.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=  28.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   6.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   5.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   5.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   9.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  20.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   5.7s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   5.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   7.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   7.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   5.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   3.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=1000; total time=  25.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  12.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=  11.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  28.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=500; total time=   4.7s
# Tuning Random Forest selesai.
# Waktu tuning: 695.23 detik
#
# Best Parameters:
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'class_weight': None, 'bootstrap': False}
#
# Best CV Accuracy: 0.8037
#
# ======================================================================
# HASIL TUNED RANDOM FOREST - VALIDATION SET MIXED
# ======================================================================
# Accuracy  : 0.8234
# Precision : 0.8543
# Recall    : 0.8234
# F1-Score  : 0.8193
#
# Confusion Matrix:
# [[494 240]
#  [ 21 723]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.96      0.67      0.79       734
#  Label 1 (After)       0.75      0.97      0.85       744
#
#         accuracy                           0.82      1478
#        macro avg       0.86      0.82      0.82      1478
#     weighted avg       0.85      0.82      0.82      1478
#
# ======================================================================
# HASIL TUNED RANDOM FOREST - TEST SET MIXED
# ======================================================================
# Accuracy  : 0.8185
# Precision : 0.8539
# Recall    : 0.8185
# F1-Score  : 0.8137
#
# Confusion Matrix:
# [[486 252]
#  [ 17 727]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.66      0.78       738
#  Label 1 (After)       0.74      0.98      0.84       744
#
#         accuracy                           0.82      1482
#        macro avg       0.85      0.82      0.81      1482
#     weighted avg       0.85      0.82      0.81      1482
#
# ======================================================================
# FEATURE IMPORTANCE TUNED RANDOM FOREST
# ======================================================================
# RAW_TP9_BP_Gamma               : 0.2664
# RAW_TP10_BP_Gamma              : 0.2092
# RAW_AF8_BP_Gamma               : 0.1385
# RAW_TP10_RP_Gamma              : 0.1027
# RAW_TP9_RP_Gamma               : 0.0914
# RAW_AF7_RP_Gamma               : 0.0863
# RAW_AF8_RP_Gamma               : 0.0676
# RAW_AF7_BP_Gamma               : 0.0379

# %%
# ============================================================
# HYPERPARAMETER TUNING SVM
# ACGAN Mixed Train-Validation-Test
# ============================================================

import numpy as np
import pandas as pd
import time

from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# ============================================================
# 1. Parameter Search Space
# ============================================================

svm_param_dist = {
    "C": [0.1, 1, 5, 10, 25, 50, 100, 200],
    "gamma": ["scale", "auto", 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1],
    "kernel": ["rbf", "poly", "sigmoid"],
    "degree": [2, 3, 4],
    "class_weight": [None, "balanced"]
}

svm_base = SVC(
    random_state=42
)

# ============================================================
# 2. Randomized Search
# ============================================================

print("Mulai tuning SVM...")
start = time.time()

svm_random_search = RandomizedSearchCV(
    estimator=svm_base,
    param_distributions=svm_param_dist,
    n_iter=50,
    scoring="accuracy",
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

svm_random_search.fit(X_train_mix_scaled, y_train_mix)

svm_tuning_time = time.time() - start

print("\nTuning SVM selesai.")
print(f"Waktu tuning: {svm_tuning_time:.2f} detik")
print("\nBest Parameters:")
print(svm_random_search.best_params_)
print(f"\nBest CV Accuracy: {svm_random_search.best_score_:.4f}")

# ============================================================
# 3. Evaluasi Best SVM pada Validation dan Test Mixed
# ============================================================

best_svm_mix = svm_random_search.best_estimator_

y_pred_val_svm_tuned = best_svm_mix.predict(X_val_mix_scaled)
y_pred_test_svm_tuned = best_svm_mix.predict(X_test_mix_scaled)

print("\n" + "="*70)
print("HASIL TUNED SVM - VALIDATION SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_val_mix, y_pred_val_svm_tuned):.4f}")
print(f"Precision : {precision_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val_mix, y_pred_val_svm_tuned)}")
print(f"\n{classification_report(y_val_mix, y_pred_val_svm_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

print("="*70)
print("HASIL TUNED SVM - TEST SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_test_mix, y_pred_test_svm_tuned):.4f}")
print(f"Precision : {precision_score(y_test_mix, y_pred_test_svm_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test_mix, y_pred_test_svm_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test_mix, y_pred_test_svm_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test_mix, y_pred_test_svm_tuned)}")
print(f"\n{classification_report(y_test_mix, y_pred_test_svm_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# Mulai tuning SVM...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  27.7s
# [CV] END bootstrap=True, class_weight=None, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=500; total time=   5.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=500; total time=   4.6s
# [CV] END bootstrap=True, class_weight=None, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   8.7s
# [CV] END bootstrap=True, class_weight=None, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   5.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  12.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  52.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   7.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   9.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=  15.0s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   1.7s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.5, kernel=poly; total time=   4.3s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.05, kernel=poly; total time=   1.3s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.05, kernel=poly; total time=   1.3s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.8s
# [CV] END C=200, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   3.4s
# [CV] END C=200, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   3.3s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   1.7s
# [CV] END C=10, class_weight=balanced, degree=4, gamma=0.001, kernel=poly; total time=   2.0s
# [CV] END C=10, class_weight=balanced, degree=4, gamma=0.001, kernel=poly; total time=   1.9s
# [CV] END C=50, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time=   2.3s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.001, kernel=poly; total time=   2.0s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.001, kernel=poly; total time=   2.0s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=1, kernel=rbf; total time=   2.8s
# [CV] END C=25, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time= 3.0min
# [CV] END C=5, class_weight=balanced, degree=4, gamma=auto, kernel=rbf; total time=   1.4s
# [CV] END C=50, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   2.8s
# [CV] END C=50, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   2.5s
# [CV] END C=50, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   2.9s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.05, kernel=sigmoid; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.05, kernel=sigmoid; total time=   2.0s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=sigmoid; total time=   2.5s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=sigmoid; total time=   2.5s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=sigmoid; total time=   2.5s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=poly; total time= 1.1min
# [CV] END C=5, class_weight=None, degree=3, gamma=0.01, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=None, degree=3, gamma=0.01, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=None, degree=3, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=3, gamma=0.01, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=None, degree=3, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END C=5, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   1.4s
# [CV] END C=5, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   1.4s
# [CV] END C=5, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   1.8s
# [CV] END C=5, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   1.5s
# [CV] END C=5, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.1s
# [CV] END C=100, class_weight=None, degree=2, gamma=auto, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=None, degree=2, gamma=auto, kernel=sigmoid; total time=   1.3s
# [CV] END C=100, class_weight=None, degree=2, gamma=auto, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=None, degree=2, gamma=auto, kernel=sigmoid; total time=   1.3s
# [CV] END C=100, class_weight=None, degree=2, gamma=auto, kernel=sigmoid; total time=   2.0s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   3.4s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   3.0s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=1000; total time=  27.2s
# [CV] END bootstrap=True, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=3, n_estimators=1000; total time=  24.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  27.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  23.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   6.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  15.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  44.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   7.2s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   9.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   1.7s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.5, kernel=poly; total time=   4.8s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.05, kernel=poly; total time=   1.3s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.05, kernel=poly; total time=   1.3s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.6s
# [CV] END C=200, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   3.2s
# [CV] END C=100, class_weight=None, degree=2, gamma=0.01, kernel=sigmoid; total time=   1.7s
# [CV] END C=100, class_weight=None, degree=2, gamma=0.01, kernel=sigmoid; total time=   1.9s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   1.8s
# [CV] END C=10, class_weight=balanced, degree=4, gamma=0.001, kernel=poly; total time=   2.0s
# [CV] END C=50, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.9s
# [CV] END C=50, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time=   3.1s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.001, kernel=poly; total time=   2.1s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=1, kernel=rbf; total time=   3.3s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=1, kernel=rbf; total time=   2.9s
# [CV] END C=25, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time= 3.3min
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=poly; total time=  46.3s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=poly; total time=  45.0s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   3.4s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   3.4s
# [CV] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.1s
# [CV] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.0s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid; total time=   1.5s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid; total time=   2.2s
# [CV] END C=1, class_weight=balanced, degree=2, gamma=0.5, kernel=poly; total time=   2.0s
# [CV] END C=200, class_weight=None, degree=4, gamma=0.5, kernel=rbf; total time=   3.9s
# [CV] END C=200, class_weight=None, degree=4, gamma=0.5, kernel=rbf; total time=   3.3s
# [CV] END C=1, class_weight=None, degree=4, gamma=scale, kernel=sigmoid; total time=   1.5s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=sigmoid; total time=   1.7s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=sigmoid; total time=   1.7s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END C=200, class_weight=balanced, degree=3, gamma=0.01, kernel=sigmoid; total time=   1.4s
# [CV] END C=200, class_weight=balanced, degree=3, gamma=0.01, kernel=sigmoid; total time=   1.9s
# [CV] END C=5, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.3s
# [CV] END C=25, class_weight=balanced, degree=3, gamma=1, kernel=rbf; total time=   1.8s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=rbf; total time=   2.1s
# [CV] END C=50, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid; total time=   1.9s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=5, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=  11.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  24.5s
# [CV] END bootstrap=True, class_weight=None, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=500; total time=   4.5s
# [CV] END bootstrap=True, class_weight=None, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   8.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   6.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  12.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  46.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   9.6s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   8.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=  19.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   3.0s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   1.7s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   1.8s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.5, kernel=poly; total time=   3.3s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.05, kernel=poly; total time=   1.3s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.7s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.7s
# [CV] END C=200, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END C=100, class_weight=None, degree=2, gamma=0.01, kernel=sigmoid; total time=   1.8s
# [CV] END C=100, class_weight=None, degree=2, gamma=0.01, kernel=sigmoid; total time=   1.9s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   1.7s
# [CV] END C=10, class_weight=balanced, degree=4, gamma=0.001, kernel=poly; total time=   2.1s
# [CV] END C=50, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time=   2.7s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time=   3.4s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.001, kernel=poly; total time=   2.1s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END C=25, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time= 1.6min
# [CV] END C=25, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time= 3.5min
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid; total time=   1.9s
# [CV] END C=1, class_weight=balanced, degree=2, gamma=0.5, kernel=poly; total time=   1.7s
# [CV] END C=1, class_weight=balanced, degree=2, gamma=0.5, kernel=poly; total time=   1.6s
# [CV] END C=200, class_weight=None, degree=4, gamma=0.5, kernel=rbf; total time=   3.6s
# [CV] END C=200, class_weight=None, degree=4, gamma=0.5, kernel=rbf; total time=   4.1s
# [CV] END C=1, class_weight=None, degree=4, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=sigmoid; total time=   1.6s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END C=200, class_weight=balanced, degree=3, gamma=0.01, kernel=sigmoid; total time=   1.8s
# [CV] END C=200, class_weight=balanced, degree=3, gamma=0.01, kernel=sigmoid; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.3s
# [CV] END C=25, class_weight=balanced, degree=3, gamma=1, kernel=rbf; total time=   1.9s
# [CV] END C=25, class_weight=balanced, degree=3, gamma=1, kernel=rbf; total time=   1.7s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=rbf; total time=   2.0s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=rbf; total time=   1.9s
# [CV] END C=50, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=5, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   2.4s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   1.9s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.01, kernel=poly; total time=   1.3s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.01, kernel=poly; total time=   1.3s
# [CV] END C=1, class_weight=balanced, degree=4, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   2.0s
# [CV] END C=200, class_weight=None, degree=3, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=auto, kernel=sigmoid; total time=   1.5s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=auto, kernel=sigmoid; total time=   1.9s
# Tuning SVM selesai.
# Waktu tuning: 403.20 detik
#
# Best Parameters:
# {'kernel': 'rbf', 'gamma': 1, 'degree': 2, 'class_weight': None, 'C': 200}
#
# Best CV Accuracy: 0.7881
#
# ======================================================================
# HASIL TUNED SVM - VALIDATION SET MIXED
# ======================================================================
# Accuracy  : 0.7821
# Precision : 0.8298
# Recall    : 0.7821
# F1-Score  : 0.7743
#
# Confusion Matrix:
# [[713  21]
#  [301 443]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.97      0.82       734
#  Label 1 (After)       0.95      0.60      0.73       744
#
#         accuracy                           0.78      1478
#        macro avg       0.83      0.78      0.77      1478
#     weighted avg       0.83      0.78      0.77      1478
#
# ======================================================================
# HASIL TUNED SVM - TEST SET MIXED
# ======================================================================
# Accuracy  : 0.7935
# Precision : 0.8459
# Recall    : 0.7935
# F1-Score  : 0.7856
#
# Confusion Matrix:
# [[729   9]
#  [297 447]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.71      0.99      0.83       738
#  Label 1 (After)       0.98      0.60      0.74       744
#
#         accuracy                           0.79      1482
#        macro avg       0.85      0.79      0.79      1482
#     weighted avg       0.85      0.79      0.79      1482

# %%
# ============================================================
# HYPERPARAMETER TUNING CNN
# ACGAN Mixed Train-Validation-Test
# Manual Search
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
import time

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv1D, MaxPooling1D, Flatten, Dense,
    Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# ============================================================
# 1. Function Build CNN
# ============================================================

def build_cnn_model(
    feature_dim=8,
    filters_1=32,
    filters_2=64,
    dense_units=64,
    dropout_1=0.5,
    dropout_2=0.3,
    learning_rate=0.001
):
    model = Sequential([
        Input(shape=(feature_dim, 1)),

        Conv1D(filters=filters_1, kernel_size=3, activation="relu", padding="same"),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),

        Conv1D(filters=filters_2, kernel_size=3, activation="relu", padding="same"),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),

        Flatten(),

        Dense(dense_units, activation="relu"),
        Dropout(dropout_1),

        Dense(dense_units // 2, activation="relu"),
        Dropout(dropout_2),

        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


# ============================================================
# 2. Search Space CNN
# ============================================================

cnn_search_space = [
    {
        "filters_1": 32,
        "filters_2": 64,
        "dense_units": 64,
        "dropout_1": 0.4,
        "dropout_2": 0.2,
        "learning_rate": 0.001,
        "batch_size": 32
    },
    {
        "filters_1": 64,
        "filters_2": 128,
        "dense_units": 128,
        "dropout_1": 0.4,
        "dropout_2": 0.2,
        "learning_rate": 0.001,
        "batch_size": 32
    },
    {
        "filters_1": 64,
        "filters_2": 128,
        "dense_units": 128,
        "dropout_1": 0.3,
        "dropout_2": 0.2,
        "learning_rate": 0.0005,
        "batch_size": 32
    },
    {
        "filters_1": 128,
        "filters_2": 256,
        "dense_units": 256,
        "dropout_1": 0.3,
        "dropout_2": 0.2,
        "learning_rate": 0.0005,
        "batch_size": 64
    },
    {
        "filters_1": 128,
        "filters_2": 128,
        "dense_units": 128,
        "dropout_1": 0.2,
        "dropout_2": 0.1,
        "learning_rate": 0.0003,
        "batch_size": 64
    }
]

# ============================================================
# 3. Training beberapa kombinasi CNN
# ============================================================

cnn_tuning_results = []
best_val_acc = -1
best_cnn_tuned = None
best_cnn_params = None
best_cnn_history = None

print("Mulai tuning CNN...")

for i, params in enumerate(cnn_search_space, start=1):
    print("\n" + "="*80)
    print(f"Training CNN combination {i}/{len(cnn_search_space)}")
    print(params)
    print("="*80)

    tf.keras.backend.clear_session()
    tf.random.set_seed(42)
    np.random.seed(42)

    model = build_cnn_model(
        feature_dim=feature_dim,
        filters_1=params["filters_1"],
        filters_2=params["filters_2"],
        dense_units=params["dense_units"],
        dropout_1=params["dropout_1"],
        dropout_2=params["dropout_2"],
        learning_rate=params["learning_rate"]
    )

    early_stop = EarlyStopping(
        monitor="val_accuracy",
        patience=15,
        restore_best_weights=True,
        mode="max",
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )

    start = time.time()

    history = model.fit(
        X_train_mix_cnn,
        y_train_mix,
        validation_data=(X_val_mix_cnn, y_val_mix),
        epochs=120,
        batch_size=params["batch_size"],
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    train_time = time.time() - start

    val_loss, val_acc = model.evaluate(X_val_mix_cnn, y_val_mix, verbose=0)
    test_loss, test_acc = model.evaluate(X_test_mix_cnn, y_test_mix, verbose=0)

    cnn_tuning_results.append({
        "Combination": i,
        "filters_1": params["filters_1"],
        "filters_2": params["filters_2"],
        "dense_units": params["dense_units"],
        "dropout_1": params["dropout_1"],
        "dropout_2": params["dropout_2"],
        "learning_rate": params["learning_rate"],
        "batch_size": params["batch_size"],
        "Val Accuracy": val_acc,
        "Test Accuracy": test_acc,
        "Train Time": train_time,
        "Epochs": len(history.history["loss"])
    })

    print(f"\nCombination {i} selesai.")
    print(f"Val Accuracy  : {val_acc:.4f}")
    print(f"Test Accuracy : {test_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_cnn_tuned = model
        best_cnn_params = params
        best_cnn_history = history

print("\nTuning CNN selesai.")

df_cnn_tuning_results = pd.DataFrame(cnn_tuning_results)
display(df_cnn_tuning_results.round(4))

print("\nBest CNN Params:")
print(best_cnn_params)
print(f"Best Validation Accuracy: {best_val_acc:.4f}")

# ============================================================
# 4. Evaluasi Best CNN pada Validation dan Test Mixed
# ============================================================

y_prob_val_cnn_tuned = best_cnn_tuned.predict(X_val_mix_cnn, verbose=0).flatten()
y_prob_test_cnn_tuned = best_cnn_tuned.predict(X_test_mix_cnn, verbose=0).flatten()

y_pred_val_cnn_tuned = (y_prob_val_cnn_tuned >= 0.5).astype(int)
y_pred_test_cnn_tuned = (y_prob_test_cnn_tuned >= 0.5).astype(int)

print("\n" + "="*70)
print("HASIL TUNED CNN - VALIDATION SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_val_mix, y_pred_val_cnn_tuned):.4f}")
print(f"Precision : {precision_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_val_mix, y_pred_val_cnn_tuned)}")
print(f"\n{classification_report(y_val_mix, y_pred_val_cnn_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")

print("="*70)
print("HASIL TUNED CNN - TEST SET MIXED")
print("="*70)
print(f"Accuracy  : {accuracy_score(y_test_mix, y_pred_test_cnn_tuned):.4f}")
print(f"Precision : {precision_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted'):.4f}")
print(f"F1-Score  : {f1_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted'):.4f}")
print(f"\nConfusion Matrix:\n{confusion_matrix(y_test_mix, y_pred_test_cnn_tuned)}")
print(f"\n{classification_report(y_test_mix, y_pred_test_cnn_tuned, target_names=['Label 0 (Before)', 'Label 1 (After)'])}")
# Out:
# Mulai tuning CNN...
#
# ================================================================================
# Training CNN combination 1/5
# {'filters_1': 32, 'filters_2': 64, 'dense_units': 64, 'dropout_1': 0.4, 'dropout_2': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# ================================================================================
# Epoch 1/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7580 - loss: 0.4610 - val_accuracy: 0.7659 - val_loss: 0.5424 - learning_rate: 0.0010
# Epoch 2/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7710 - loss: 0.3937 - val_accuracy: 0.7727 - val_loss: 0.4003 - learning_rate: 0.0010
# Epoch 3/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7775 - loss: 0.3686 - val_accuracy: 0.7733 - val_loss: 0.3539 - learning_rate: 0.0010
# Epoch 4/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7756 - loss: 0.3600 - val_accuracy: 0.7720 - val_loss: 0.3611 - learning_rate: 0.0010
# Epoch 5/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7742 - loss: 0.3531 - val_accuracy: 0.7788 - val_loss: 0.3382 - learning_rate: 0.0010
# Epoch 6/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7804 - loss: 0.3424 - val_accuracy: 0.7916 - val_loss: 0.3530 - learning_rate: 0.0010
# Epoch 7/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7814 - loss: 0.3404 - val_accuracy: 0.8038 - val_loss: 0.3320 - learning_rate: 0.0010
# Epoch 8/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7789 - loss: 0.3402 - val_accuracy: 0.7794 - val_loss: 0.3352 - learning_rate: 0.0010
# Epoch 9/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.3352 - val_accuracy: 0.7970 - val_loss: 0.3415 - learning_rate: 0.0010
# Epoch 10/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.3399 - val_accuracy: 0.7767 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 11/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7762 - loss: 0.3389 - val_accuracy: 0.7815 - val_loss: 0.3411 - learning_rate: 0.0010
# Epoch 12/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.3301 - val_accuracy: 0.8004 - val_loss: 0.3184 - learning_rate: 0.0010
# Epoch 13/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7828 - loss: 0.3272 - val_accuracy: 0.7997 - val_loss: 0.3231 - learning_rate: 0.0010
# Epoch 14/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7834 - loss: 0.3267 - val_accuracy: 0.7754 - val_loss: 0.3252 - learning_rate: 0.0010
# Epoch 15/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.3242 - val_accuracy: 0.7984 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 16/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7883 - loss: 0.3251 - val_accuracy: 0.7984 - val_loss: 0.3210 - learning_rate: 0.0010
# Epoch 17/120
# 205/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7938 - loss: 0.3257
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7902 - loss: 0.3256 - val_accuracy: 0.7970 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 18/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7831 - loss: 0.3197 - val_accuracy: 0.7774 - val_loss: 0.3242 - learning_rate: 5.0000e-04
# Epoch 19/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7823 - loss: 0.3180 - val_accuracy: 0.7984 - val_loss: 0.3190 - learning_rate: 5.0000e-04
# Epoch 20/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7898 - loss: 0.3162 - val_accuracy: 0.8018 - val_loss: 0.3122 - learning_rate: 5.0000e-04
# Epoch 21/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7909 - loss: 0.3141 - val_accuracy: 0.8018 - val_loss: 0.3118 - learning_rate: 5.0000e-04
# Epoch 22/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7907 - loss: 0.3157 - val_accuracy: 0.7984 - val_loss: 0.3149 - learning_rate: 5.0000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# Combination 1 selesai.
# Val Accuracy  : 0.8038
# Test Accuracy : 0.7928
#
# ================================================================================
# Training CNN combination 2/5
# {'filters_1': 64, 'filters_2': 128, 'dense_units': 128, 'dropout_1': 0.4, 'dropout_2': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# ================================================================================
# Epoch 1/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7588 - loss: 0.4719 - val_accuracy: 0.7605 - val_loss: 0.5437 - learning_rate: 0.0010
# Epoch 2/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7691 - loss: 0.4000 - val_accuracy: 0.7774 - val_loss: 0.5334 - learning_rate: 0.0010
# Epoch 3/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7694 - loss: 0.3700 - val_accuracy: 0.7747 - val_loss: 0.4047 - learning_rate: 0.0010
# Epoch 4/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7755 - loss: 0.3546 - val_accuracy: 0.7977 - val_loss: 0.3572 - learning_rate: 0.0010
# Epoch 5/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7811 - loss: 0.3498 - val_accuracy: 0.7760 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 6/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7833 - loss: 0.3428 - val_accuracy: 0.7869 - val_loss: 0.3471 - learning_rate: 0.0010
# Epoch 7/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7797 - loss: 0.3405 - val_accuracy: 0.7943 - val_loss: 0.3398 - learning_rate: 0.0010
# Epoch 8/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7758 - loss: 0.3348 - val_accuracy: 0.7916 - val_loss: 0.3392 - learning_rate: 0.0010
# Epoch 9/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7841 - loss: 0.3318 - val_accuracy: 0.7984 - val_loss: 0.3249 - learning_rate: 0.0010
# Epoch 10/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7854 - loss: 0.3276 - val_accuracy: 0.7788 - val_loss: 0.3177 - learning_rate: 0.0010
# Epoch 11/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.3273 - val_accuracy: 0.7950 - val_loss: 0.3342 - learning_rate: 0.0010
# Epoch 12/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7839 - loss: 0.3281 - val_accuracy: 0.7916 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 13/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7823 - loss: 0.3284 - val_accuracy: 0.7984 - val_loss: 0.3305 - learning_rate: 0.0010
# Epoch 14/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7833 - loss: 0.3233 - val_accuracy: 0.8004 - val_loss: 0.3214 - learning_rate: 0.0010
# Epoch 15/120
# 197/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7922 - loss: 0.3227
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7836 - loss: 0.3207 - val_accuracy: 0.8011 - val_loss: 0.3206 - learning_rate: 0.0010
# Epoch 16/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8001 - loss: 0.3207 - val_accuracy: 0.7673 - val_loss: 0.3354 - learning_rate: 5.0000e-04
# Epoch 17/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7869 - loss: 0.3200 - val_accuracy: 0.7997 - val_loss: 0.3231 - learning_rate: 5.0000e-04
# Epoch 18/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7863 - loss: 0.3156 - val_accuracy: 0.8018 - val_loss: 0.3150 - learning_rate: 5.0000e-04
# Epoch 19/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7918 - loss: 0.3137 - val_accuracy: 0.7835 - val_loss: 0.3164 - learning_rate: 5.0000e-04
# Epoch 20/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.3129 - val_accuracy: 0.8038 - val_loss: 0.3174 - learning_rate: 5.0000e-04
# Epoch 21/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7914 - loss: 0.3141 - val_accuracy: 0.7997 - val_loss: 0.3187 - learning_rate: 5.0000e-04
# Epoch 22/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7924 - loss: 0.3116 - val_accuracy: 0.7808 - val_loss: 0.5320 - learning_rate: 5.0000e-04
# Epoch 23/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7876 - loss: 0.3120 - val_accuracy: 0.8018 - val_loss: 0.3138 - learning_rate: 5.0000e-04
# Epoch 24/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7983 - loss: 0.3104 - val_accuracy: 0.8058 - val_loss: 0.3128 - learning_rate: 5.0000e-04
# Epoch 25/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7885 - loss: 0.3097 - val_accuracy: 0.8031 - val_loss: 0.3135 - learning_rate: 5.0000e-04
# Epoch 26/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.3099 - val_accuracy: 0.8065 - val_loss: 0.3127 - learning_rate: 5.0000e-04
# Epoch 27/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.3128 - val_accuracy: 0.8024 - val_loss: 0.3172 - learning_rate: 5.0000e-04
# Epoch 28/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7933 - loss: 0.3084 - val_accuracy: 0.8072 - val_loss: 0.3228 - learning_rate: 5.0000e-04
# Epoch 29/120
# 199/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7870 - loss: 0.3083
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7940 - loss: 0.3063 - val_accuracy: 0.8045 - val_loss: 0.3229 - learning_rate: 5.0000e-04
# Epoch 30/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7972 - loss: 0.3018 - val_accuracy: 0.8058 - val_loss: 0.3119 - learning_rate: 2.5000e-04
# Epoch 31/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8003 - loss: 0.3014 - val_accuracy: 0.8065 - val_loss: 0.3115 - learning_rate: 2.5000e-04
# Epoch 32/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8016 - loss: 0.3005 - val_accuracy: 0.8065 - val_loss: 0.3128 - learning_rate: 2.5000e-04
# Epoch 33/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8008 - loss: 0.2988 - val_accuracy: 0.8058 - val_loss: 0.3138 - learning_rate: 2.5000e-04
# Epoch 34/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7977 - loss: 0.2981 - val_accuracy: 0.8031 - val_loss: 0.3213 - learning_rate: 2.5000e-04
# Epoch 35/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.2984 - val_accuracy: 0.8038 - val_loss: 0.3143 - learning_rate: 2.5000e-04
# Epoch 36/120
# 206/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.2992
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7979 - loss: 0.2982 - val_accuracy: 0.8085 - val_loss: 0.3245 - learning_rate: 2.5000e-04
# Epoch 37/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8012 - loss: 0.2967 - val_accuracy: 0.8031 - val_loss: 0.3185 - learning_rate: 1.2500e-04
# Epoch 38/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7989 - loss: 0.2943 - val_accuracy: 0.8058 - val_loss: 0.3202 - learning_rate: 1.2500e-04
# Epoch 39/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8070 - loss: 0.2939 - val_accuracy: 0.8058 - val_loss: 0.3173 - learning_rate: 1.2500e-04
# Epoch 40/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8044 - loss: 0.2918 - val_accuracy: 0.7855 - val_loss: 0.3220 - learning_rate: 1.2500e-04
# Epoch 41/120
# 211/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8151 - loss: 0.2924
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8112 - loss: 0.2924 - val_accuracy: 0.7997 - val_loss: 0.3233 - learning_rate: 1.2500e-04
# Epoch 42/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8125 - loss: 0.2918 - val_accuracy: 0.7788 - val_loss: 0.3256 - learning_rate: 6.2500e-05
# Epoch 43/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8061 - loss: 0.2925 - val_accuracy: 0.8011 - val_loss: 0.3237 - learning_rate: 6.2500e-05
# Epoch 44/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8027 - loss: 0.2918 - val_accuracy: 0.8011 - val_loss: 0.3205 - learning_rate: 6.2500e-05
# Epoch 45/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8044 - loss: 0.2908 - val_accuracy: 0.8051 - val_loss: 0.3255 - learning_rate: 6.2500e-05
# Epoch 46/120
# 211/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8177 - loss: 0.2918
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8106 - loss: 0.2910 - val_accuracy: 0.8024 - val_loss: 0.3221 - learning_rate: 6.2500e-05
# Epoch 47/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8083 - loss: 0.2896 - val_accuracy: 0.8072 - val_loss: 0.3240 - learning_rate: 3.1250e-05
# Epoch 48/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8087 - loss: 0.2899 - val_accuracy: 0.8058 - val_loss: 0.3260 - learning_rate: 3.1250e-05
# Epoch 49/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8119 - loss: 0.2881 - val_accuracy: 0.8051 - val_loss: 0.3249 - learning_rate: 3.1250e-05
# Epoch 50/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8138 - loss: 0.2871 - val_accuracy: 0.8078 - val_loss: 0.3259 - learning_rate: 3.1250e-05
# Epoch 51/120
# 211/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.2902
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8083 - loss: 0.2884 - val_accuracy: 0.8078 - val_loss: 0.3277 - learning_rate: 3.1250e-05
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 36.
#
# Combination 2 selesai.
# Val Accuracy  : 0.8085
# Test Accuracy : 0.7996
#
# ================================================================================
# Training CNN combination 3/5
# {'filters_1': 64, 'filters_2': 128, 'dense_units': 128, 'dropout_1': 0.3, 'dropout_2': 0.2, 'learning_rate': 0.0005, 'batch_size': 32}
# ================================================================================
# Epoch 1/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7594 - loss: 0.4619 - val_accuracy: 0.7652 - val_loss: 0.5169 - learning_rate: 5.0000e-04
# Epoch 2/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7707 - loss: 0.3905 - val_accuracy: 0.7700 - val_loss: 0.5001 - learning_rate: 5.0000e-04
# Epoch 3/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7779 - loss: 0.3720 - val_accuracy: 0.7781 - val_loss: 0.3706 - learning_rate: 5.0000e-04
# Epoch 4/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7756 - loss: 0.3595 - val_accuracy: 0.7767 - val_loss: 0.3459 - learning_rate: 5.0000e-04
# Epoch 5/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.3573 - val_accuracy: 0.7747 - val_loss: 0.3470 - learning_rate: 5.0000e-04
# Epoch 6/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7841 - loss: 0.3464 - val_accuracy: 0.7774 - val_loss: 0.3403 - learning_rate: 5.0000e-04
# Epoch 7/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7810 - loss: 0.3396 - val_accuracy: 0.7936 - val_loss: 0.3382 - learning_rate: 5.0000e-04
# Epoch 8/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7815 - loss: 0.3369 - val_accuracy: 0.7767 - val_loss: 0.3327 - learning_rate: 5.0000e-04
# Epoch 9/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7891 - loss: 0.3351 - val_accuracy: 0.7794 - val_loss: 0.3406 - learning_rate: 5.0000e-04
# Epoch 10/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.3346 - val_accuracy: 0.7984 - val_loss: 0.3256 - learning_rate: 5.0000e-04
# Epoch 11/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7869 - loss: 0.3294 - val_accuracy: 0.7781 - val_loss: 0.3246 - learning_rate: 5.0000e-04
# Epoch 12/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7909 - loss: 0.3259 - val_accuracy: 0.7977 - val_loss: 0.3262 - learning_rate: 5.0000e-04
# Epoch 13/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7891 - loss: 0.3239 - val_accuracy: 0.7882 - val_loss: 0.3354 - learning_rate: 5.0000e-04
# Epoch 14/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7880 - loss: 0.3230 - val_accuracy: 0.7963 - val_loss: 0.3168 - learning_rate: 5.0000e-04
# Epoch 15/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7869 - loss: 0.3265 - val_accuracy: 0.7977 - val_loss: 0.3227 - learning_rate: 5.0000e-04
# Epoch 16/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7882 - loss: 0.3229 - val_accuracy: 0.8004 - val_loss: 0.3198 - learning_rate: 5.0000e-04
# Epoch 17/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7896 - loss: 0.3196 - val_accuracy: 0.8011 - val_loss: 0.3174 - learning_rate: 5.0000e-04
# Epoch 18/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7875 - loss: 0.3221 - val_accuracy: 0.7977 - val_loss: 0.3169 - learning_rate: 5.0000e-04
# Epoch 19/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.3163 - val_accuracy: 0.8004 - val_loss: 0.3128 - learning_rate: 5.0000e-04
# Epoch 20/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7943 - loss: 0.3185 - val_accuracy: 0.7997 - val_loss: 0.3115 - learning_rate: 5.0000e-04
# Epoch 21/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7922 - loss: 0.3152 - val_accuracy: 0.8004 - val_loss: 0.3108 - learning_rate: 5.0000e-04
# Epoch 22/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7962 - loss: 0.3116 - val_accuracy: 0.7977 - val_loss: 0.3145 - learning_rate: 5.0000e-04
# Epoch 23/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7999 - loss: 0.3111 - val_accuracy: 0.7876 - val_loss: 0.3152 - learning_rate: 5.0000e-04
# Epoch 24/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7937 - loss: 0.3127 - val_accuracy: 0.8004 - val_loss: 0.3168 - learning_rate: 5.0000e-04
# Epoch 25/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7962 - loss: 0.3133 - val_accuracy: 0.8031 - val_loss: 0.3109 - learning_rate: 5.0000e-04
# Epoch 26/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7962 - loss: 0.3123 - val_accuracy: 0.8065 - val_loss: 0.3079 - learning_rate: 5.0000e-04
# Epoch 27/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7992 - loss: 0.3084 - val_accuracy: 0.8058 - val_loss: 0.3079 - learning_rate: 5.0000e-04
# Epoch 28/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7959 - loss: 0.3085 - val_accuracy: 0.8058 - val_loss: 0.3189 - learning_rate: 5.0000e-04
# Epoch 29/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7963 - loss: 0.3093 - val_accuracy: 0.8031 - val_loss: 0.3064 - learning_rate: 5.0000e-04
# Epoch 30/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7964 - loss: 0.3084 - val_accuracy: 0.7855 - val_loss: 0.3038 - learning_rate: 5.0000e-04
# Epoch 31/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7938 - loss: 0.3067 - val_accuracy: 0.7848 - val_loss: 0.3317 - learning_rate: 5.0000e-04
# Epoch 32/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8005 - loss: 0.3065 - val_accuracy: 0.8051 - val_loss: 0.3083 - learning_rate: 5.0000e-04
# Epoch 33/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8014 - loss: 0.3057 - val_accuracy: 0.7828 - val_loss: 0.3148 - learning_rate: 5.0000e-04
# Epoch 34/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.3067 - val_accuracy: 0.7984 - val_loss: 0.3328 - learning_rate: 5.0000e-04
# Epoch 35/120
# 210/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7967 - loss: 0.3053
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.3040 - val_accuracy: 0.7997 - val_loss: 0.3146 - learning_rate: 5.0000e-04
# Epoch 36/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7882 - loss: 0.2991 - val_accuracy: 0.8011 - val_loss: 0.3149 - learning_rate: 2.5000e-04
# Epoch 37/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8021 - loss: 0.2970 - val_accuracy: 0.8018 - val_loss: 0.3126 - learning_rate: 2.5000e-04
# Epoch 38/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7975 - loss: 0.2976 - val_accuracy: 0.7801 - val_loss: 0.3165 - learning_rate: 2.5000e-04
# Epoch 39/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7988 - loss: 0.2968 - val_accuracy: 0.8004 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 40/120
# 211/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.2948
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7998 - loss: 0.2942 - val_accuracy: 0.8011 - val_loss: 0.3155 - learning_rate: 2.5000e-04
# Epoch 41/120
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8038 - loss: 0.2920 - val_accuracy: 0.8031 - val_loss: 0.3121 - learning_rate: 1.2500e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.
#
# Combination 3 selesai.
# Val Accuracy  : 0.8065
# Test Accuracy : 0.7935
#
# ================================================================================
# Training CNN combination 4/5
# {'filters_1': 128, 'filters_2': 256, 'dense_units': 256, 'dropout_1': 0.3, 'dropout_2': 0.2, 'learning_rate': 0.0005, 'batch_size': 64}
# ================================================================================
# Epoch 1/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7584 - loss: 0.4613 - val_accuracy: 0.5027 - val_loss: 0.6104 - learning_rate: 5.0000e-04
# Epoch 2/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7603 - loss: 0.4039 - val_accuracy: 0.5210 - val_loss: 0.5495 - learning_rate: 5.0000e-04
# Epoch 3/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7646 - loss: 0.3840 - val_accuracy: 0.7598 - val_loss: 0.4578 - learning_rate: 5.0000e-04
# Epoch 4/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7678 - loss: 0.3742 - val_accuracy: 0.7686 - val_loss: 0.4448 - learning_rate: 5.0000e-04
# Epoch 5/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7747 - loss: 0.3636 - val_accuracy: 0.7760 - val_loss: 0.4694 - learning_rate: 5.0000e-04
# Epoch 6/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7792 - loss: 0.3485 - val_accuracy: 0.7788 - val_loss: 0.4677 - learning_rate: 5.0000e-04
# Epoch 7/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7785 - loss: 0.3434 - val_accuracy: 0.7970 - val_loss: 0.3415 - learning_rate: 5.0000e-04
# Epoch 8/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7827 - loss: 0.3341 - val_accuracy: 0.7970 - val_loss: 0.3354 - learning_rate: 5.0000e-04
# Epoch 9/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7865 - loss: 0.3347 - val_accuracy: 0.8018 - val_loss: 0.3298 - learning_rate: 5.0000e-04
# Epoch 10/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7778 - loss: 0.3316 - val_accuracy: 0.8004 - val_loss: 0.3258 - learning_rate: 5.0000e-04
# Epoch 11/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7888 - loss: 0.3260 - val_accuracy: 0.7984 - val_loss: 0.3330 - learning_rate: 5.0000e-04
# Epoch 12/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7872 - loss: 0.3247 - val_accuracy: 0.7970 - val_loss: 0.3254 - learning_rate: 5.0000e-04
# Epoch 13/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7904 - loss: 0.3271 - val_accuracy: 0.7767 - val_loss: 0.3323 - learning_rate: 5.0000e-04
# Epoch 14/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7863 - loss: 0.3274 - val_accuracy: 0.7963 - val_loss: 0.3347 - learning_rate: 5.0000e-04
# Epoch 15/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7894 - loss: 0.3211 - val_accuracy: 0.7794 - val_loss: 0.3209 - learning_rate: 5.0000e-04
# Epoch 16/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7917 - loss: 0.3218 - val_accuracy: 0.8004 - val_loss: 0.3270 - learning_rate: 5.0000e-04
# Epoch 17/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7852 - loss: 0.3212 - val_accuracy: 0.7774 - val_loss: 0.3243 - learning_rate: 5.0000e-04
# Epoch 18/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7889 - loss: 0.3189 - val_accuracy: 0.7997 - val_loss: 0.3169 - learning_rate: 5.0000e-04
# Epoch 19/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7873 - loss: 0.3145 - val_accuracy: 0.7997 - val_loss: 0.3140 - learning_rate: 5.0000e-04
# Epoch 20/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7870 - loss: 0.3157 - val_accuracy: 0.8051 - val_loss: 0.3166 - learning_rate: 5.0000e-04
# Epoch 21/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.3137 - val_accuracy: 0.8004 - val_loss: 0.3137 - learning_rate: 5.0000e-04
# Epoch 22/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - loss: 0.3129 - val_accuracy: 0.8018 - val_loss: 0.3129 - learning_rate: 5.0000e-04
# Epoch 23/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7899 - loss: 0.3111 - val_accuracy: 0.8051 - val_loss: 0.3125 - learning_rate: 5.0000e-04
# Epoch 24/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7854 - loss: 0.3117 - val_accuracy: 0.8004 - val_loss: 0.3180 - learning_rate: 5.0000e-04
# Epoch 25/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7948 - loss: 0.3098 - val_accuracy: 0.8058 - val_loss: 0.3148 - learning_rate: 5.0000e-04
# Epoch 26/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.3138 - val_accuracy: 0.8011 - val_loss: 0.3209 - learning_rate: 5.0000e-04
# Epoch 27/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7950 - loss: 0.3097 - val_accuracy: 0.7997 - val_loss: 0.3192 - learning_rate: 5.0000e-04
# Epoch 28/120
#  95/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.3109
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7896 - loss: 0.3096 - val_accuracy: 0.8038 - val_loss: 0.3170 - learning_rate: 5.0000e-04
# Epoch 29/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7921 - loss: 0.3051 - val_accuracy: 0.8018 - val_loss: 0.3157 - learning_rate: 2.5000e-04
# Epoch 30/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7920 - loss: 0.3050 - val_accuracy: 0.8078 - val_loss: 0.3156 - learning_rate: 2.5000e-04
# Epoch 31/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7954 - loss: 0.3006 - val_accuracy: 0.8065 - val_loss: 0.3197 - learning_rate: 2.5000e-04
# Epoch 32/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7983 - loss: 0.3007 - val_accuracy: 0.7997 - val_loss: 0.3195 - learning_rate: 2.5000e-04
# Epoch 33/120
#  96/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7954 - loss: 0.2997
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7972 - loss: 0.3009 - val_accuracy: 0.8038 - val_loss: 0.3142 - learning_rate: 2.5000e-04
# Epoch 34/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7983 - loss: 0.2989 - val_accuracy: 0.8051 - val_loss: 0.3128 - learning_rate: 1.2500e-04
# Epoch 35/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7985 - loss: 0.2981 - val_accuracy: 0.8051 - val_loss: 0.3126 - learning_rate: 1.2500e-04
# Epoch 36/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7956 - loss: 0.2960 - val_accuracy: 0.8058 - val_loss: 0.3148 - learning_rate: 1.2500e-04
# Epoch 37/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7990 - loss: 0.2965 - val_accuracy: 0.7984 - val_loss: 0.3189 - learning_rate: 1.2500e-04
# Epoch 38/120
#  96/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7895 - loss: 0.2974
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7966 - loss: 0.2950 - val_accuracy: 0.8045 - val_loss: 0.3187 - learning_rate: 1.2500e-04
# Epoch 39/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8035 - loss: 0.2920 - val_accuracy: 0.8031 - val_loss: 0.3150 - learning_rate: 6.2500e-05
# Epoch 40/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.2926 - val_accuracy: 0.8051 - val_loss: 0.3177 - learning_rate: 6.2500e-05
# Epoch 41/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7992 - loss: 0.2921 - val_accuracy: 0.8051 - val_loss: 0.3159 - learning_rate: 6.2500e-05
# Epoch 42/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8027 - loss: 0.2922 - val_accuracy: 0.8038 - val_loss: 0.3178 - learning_rate: 6.2500e-05
# Epoch 43/120
#  96/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7936 - loss: 0.2939
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8011 - loss: 0.2926 - val_accuracy: 0.8058 - val_loss: 0.3178 - learning_rate: 6.2500e-05
# Epoch 44/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.2919 - val_accuracy: 0.8051 - val_loss: 0.3186 - learning_rate: 3.1250e-05
# Epoch 45/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8105 - loss: 0.2899 - val_accuracy: 0.8051 - val_loss: 0.3185 - learning_rate: 3.1250e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 30.
#
# Combination 4 selesai.
# Val Accuracy  : 0.8078
# Test Accuracy : 0.7982
#
# ================================================================================
# Training CNN combination 5/5
# {'filters_1': 128, 'filters_2': 128, 'dense_units': 128, 'dropout_1': 0.2, 'dropout_2': 0.1, 'learning_rate': 0.0003, 'batch_size': 64}
# ================================================================================
# Epoch 1/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7663 - loss: 0.4582 - val_accuracy: 0.5034 - val_loss: 0.6395 - learning_rate: 3.0000e-04
# Epoch 2/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.3997 - val_accuracy: 0.6319 - val_loss: 0.5630 - learning_rate: 3.0000e-04
# Epoch 3/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7710 - loss: 0.3817 - val_accuracy: 0.7449 - val_loss: 0.4844 - learning_rate: 3.0000e-04
# Epoch 4/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7756 - loss: 0.3670 - val_accuracy: 0.7605 - val_loss: 0.4376 - learning_rate: 3.0000e-04
# Epoch 5/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7778 - loss: 0.3587 - val_accuracy: 0.7740 - val_loss: 0.3853 - learning_rate: 3.0000e-04
# Epoch 6/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7844 - loss: 0.3507 - val_accuracy: 0.7740 - val_loss: 0.3572 - learning_rate: 3.0000e-04
# Epoch 7/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7720 - loss: 0.3465 - val_accuracy: 0.7936 - val_loss: 0.3500 - learning_rate: 3.0000e-04
# Epoch 8/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 0.3389 - val_accuracy: 0.7936 - val_loss: 0.3466 - learning_rate: 3.0000e-04
# Epoch 9/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7808 - loss: 0.3382 - val_accuracy: 0.7916 - val_loss: 0.3436 - learning_rate: 3.0000e-04
# Epoch 10/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7935 - loss: 0.3303 - val_accuracy: 0.7950 - val_loss: 0.3337 - learning_rate: 3.0000e-04
# Epoch 11/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7915 - loss: 0.3294 - val_accuracy: 0.7957 - val_loss: 0.3391 - learning_rate: 3.0000e-04
# Epoch 12/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.3291 - val_accuracy: 0.7984 - val_loss: 0.3295 - learning_rate: 3.0000e-04
# Epoch 13/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7907 - loss: 0.3272 - val_accuracy: 0.7957 - val_loss: 0.3290 - learning_rate: 3.0000e-04
# Epoch 14/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7883 - loss: 0.3245 - val_accuracy: 0.7950 - val_loss: 0.3286 - learning_rate: 3.0000e-04
# Epoch 15/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7912 - loss: 0.3262 - val_accuracy: 0.7997 - val_loss: 0.3262 - learning_rate: 3.0000e-04
# Epoch 16/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7970 - loss: 0.3237 - val_accuracy: 0.7984 - val_loss: 0.3282 - learning_rate: 3.0000e-04
# Epoch 17/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7847 - loss: 0.3242 - val_accuracy: 0.7957 - val_loss: 0.3269 - learning_rate: 3.0000e-04
# Epoch 18/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7941 - loss: 0.3187 - val_accuracy: 0.7963 - val_loss: 0.3260 - learning_rate: 3.0000e-04
# Epoch 19/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7921 - loss: 0.3175 - val_accuracy: 0.7984 - val_loss: 0.3254 - learning_rate: 3.0000e-04
# Epoch 20/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7917 - loss: 0.3185 - val_accuracy: 0.8024 - val_loss: 0.3221 - learning_rate: 3.0000e-04
# Epoch 21/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7944 - loss: 0.3190 - val_accuracy: 0.7977 - val_loss: 0.3240 - learning_rate: 3.0000e-04
# Epoch 22/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7889 - loss: 0.3171 - val_accuracy: 0.7984 - val_loss: 0.3261 - learning_rate: 3.0000e-04
# Epoch 23/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7938 - loss: 0.3148 - val_accuracy: 0.8018 - val_loss: 0.3155 - learning_rate: 3.0000e-04
# Epoch 24/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7894 - loss: 0.3169 - val_accuracy: 0.8031 - val_loss: 0.3172 - learning_rate: 3.0000e-04
# Epoch 25/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7962 - loss: 0.3126 - val_accuracy: 0.8018 - val_loss: 0.3160 - learning_rate: 3.0000e-04
# Epoch 26/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8011 - loss: 0.3170 - val_accuracy: 0.8078 - val_loss: 0.3167 - learning_rate: 3.0000e-04
# Epoch 27/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7990 - loss: 0.3125 - val_accuracy: 0.7991 - val_loss: 0.3296 - learning_rate: 3.0000e-04
# Epoch 28/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7975 - loss: 0.3130 - val_accuracy: 0.8038 - val_loss: 0.3119 - learning_rate: 3.0000e-04
# Epoch 29/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7886 - loss: 0.3091 - val_accuracy: 0.8024 - val_loss: 0.3153 - learning_rate: 3.0000e-04
# Epoch 30/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7953 - loss: 0.3084 - val_accuracy: 0.8038 - val_loss: 0.3185 - learning_rate: 3.0000e-04
# Epoch 31/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7969 - loss: 0.3103 - val_accuracy: 0.8024 - val_loss: 0.3206 - learning_rate: 3.0000e-04
# Epoch 32/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.3066 - val_accuracy: 0.7896 - val_loss: 0.3442 - learning_rate: 3.0000e-04
# Epoch 33/120
# 101/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8000 - loss: 0.3108
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7977 - loss: 0.3079 - val_accuracy: 0.8092 - val_loss: 0.3172 - learning_rate: 3.0000e-04
# Epoch 34/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8003 - loss: 0.3027 - val_accuracy: 0.8038 - val_loss: 0.3100 - learning_rate: 1.5000e-04
# Epoch 35/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7920 - loss: 0.3011 - val_accuracy: 0.8031 - val_loss: 0.3120 - learning_rate: 1.5000e-04
# Epoch 36/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7957 - loss: 0.2986 - val_accuracy: 0.8112 - val_loss: 0.3100 - learning_rate: 1.5000e-04
# Epoch 37/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.3010 - val_accuracy: 0.8078 - val_loss: 0.3125 - learning_rate: 1.5000e-04
# Epoch 38/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7983 - loss: 0.2995 - val_accuracy: 0.8031 - val_loss: 0.3133 - learning_rate: 1.5000e-04
# Epoch 39/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7915 - loss: 0.2995 - val_accuracy: 0.8051 - val_loss: 0.3092 - learning_rate: 1.5000e-04
# Epoch 40/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7982 - loss: 0.2972 - val_accuracy: 0.7862 - val_loss: 0.3151 - learning_rate: 1.5000e-04
# Epoch 41/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7970 - loss: 0.2985 - val_accuracy: 0.8038 - val_loss: 0.3146 - learning_rate: 1.5000e-04
# Epoch 42/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7935 - loss: 0.2963 - val_accuracy: 0.8072 - val_loss: 0.3195 - learning_rate: 1.5000e-04
# Epoch 43/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8002 - loss: 0.2962 - val_accuracy: 0.8119 - val_loss: 0.3133 - learning_rate: 1.5000e-04
# Epoch 44/120
# 101/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7982 - loss: 0.2973
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7993 - loss: 0.2957 - val_accuracy: 0.8011 - val_loss: 0.3127 - learning_rate: 1.5000e-04
# Epoch 45/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7999 - loss: 0.2945 - val_accuracy: 0.8058 - val_loss: 0.3129 - learning_rate: 7.5000e-05
# Epoch 46/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7993 - loss: 0.2932 - val_accuracy: 0.7815 - val_loss: 0.3127 - learning_rate: 7.5000e-05
# Epoch 47/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.2913 - val_accuracy: 0.8031 - val_loss: 0.3167 - learning_rate: 7.5000e-05
# Epoch 48/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7993 - loss: 0.2923 - val_accuracy: 0.7808 - val_loss: 0.3169 - learning_rate: 7.5000e-05
# Epoch 49/120
# 101/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8076 - loss: 0.2940
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8082 - loss: 0.2912 - val_accuracy: 0.8051 - val_loss: 0.3183 - learning_rate: 7.5000e-05
# Epoch 50/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7973 - loss: 0.2910 - val_accuracy: 0.7828 - val_loss: 0.3173 - learning_rate: 3.7500e-05
# Epoch 51/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.2903 - val_accuracy: 0.8058 - val_loss: 0.3185 - learning_rate: 3.7500e-05
# Epoch 52/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8043 - loss: 0.2908 - val_accuracy: 0.8058 - val_loss: 0.3190 - learning_rate: 3.7500e-05
# Epoch 53/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8025 - loss: 0.2902 - val_accuracy: 0.8065 - val_loss: 0.3177 - learning_rate: 3.7500e-05
# Epoch 54/120
# 102/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.2897
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8105 - loss: 0.2884 - val_accuracy: 0.8031 - val_loss: 0.3176 - learning_rate: 3.7500e-05
# Epoch 55/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8038 - loss: 0.2878 - val_accuracy: 0.7842 - val_loss: 0.3172 - learning_rate: 1.8750e-05
# Epoch 56/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8102 - loss: 0.2877 - val_accuracy: 0.8065 - val_loss: 0.3175 - learning_rate: 1.8750e-05
# Epoch 57/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8134 - loss: 0.2868 - val_accuracy: 0.7835 - val_loss: 0.3186 - learning_rate: 1.8750e-05
# Epoch 58/120
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8118 - loss: 0.2862 - val_accuracy: 0.7835 - val_loss: 0.3189 - learning_rate: 1.8750e-05
# Epoch 58: early stopping
# Restoring model weights from the end of the best epoch: 43.
#
# Combination 5 selesai.
# Val Accuracy  : 0.8119
# Test Accuracy : 0.8050
#
# Tuning CNN selesai.
#    Combination  filters_1  filters_2  dense_units  dropout_1  dropout_2  \
# 0            1         32         64           64        0.4        0.2
# 1            2         64        128          128        0.4        0.2
# 2            3         64        128          128        0.3        0.2
# 3            4        128        256          256        0.3        0.2
# 4            5        128        128          128        0.2        0.1
#
#    learning_rate  batch_size  Val Accuracy  Test Accuracy  Train Time  Epochs
# 0         0.0010          32        0.8038         0.7928     21.1257      22
# 1         0.0010          32        0.8085         0.7996     43.2242      51
# 2         0.0005          32        0.8065         0.7935     34.8667      41
# 3         0.0005          64        0.8078         0.7982     26.0024      45
# 4         0.0003          64        0.8119         0.8050     30.3189      58
# Best CNN Params:
# {'filters_1': 128, 'filters_2': 128, 'dense_units': 128, 'dropout_1': 0.2, 'dropout_2': 0.1, 'learning_rate': 0.0003, 'batch_size': 64}
# Best Validation Accuracy: 0.8119
#
# ======================================================================
# HASIL TUNED CNN - VALIDATION SET MIXED
# ======================================================================
# Accuracy  : 0.8119
# Precision : 0.8402
# Recall    : 0.8119
# F1-Score  : 0.8077
#
# Confusion Matrix:
# [[488 246]
#  [ 32 712]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.94      0.66      0.78       734
#  Label 1 (After)       0.74      0.96      0.84       744
#
#         accuracy                           0.81      1478
#        macro avg       0.84      0.81      0.81      1478
#     weighted avg       0.84      0.81      0.81      1478
#
# ======================================================================
# HASIL TUNED CNN - TEST SET MIXED
# ======================================================================
# Accuracy  : 0.8050
# Precision : 0.8323
# Recall    : 0.8050
# F1-Score  : 0.8008
#
# Confusion Matrix:
# [[487 251]
#  [ 38 706]]
#
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.93      0.66      0.77       738
#  Label 1 (After)       0.74      0.95      0.83       744
#
#         accuracy                           0.80      1482
#        macro avg       0.83      0.80      0.80      1482
#     weighted avg       0.83      0.80      0.80      1482

# %%
# ============================================================
# RINGKASAN HASIL TUNED MODELS
# ACGAN Mixed Train-Validation-Test
# ============================================================

import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

tuned_results = []

# SVM tuned
tuned_results.append({
    "Experiment": "ACGAN Mixed Tuned",
    "Model": "SVM Tuned",
    "Val Accuracy": accuracy_score(y_val_mix, y_pred_val_svm_tuned),
    "Val Precision": precision_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'),
    "Val Recall": recall_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'),
    "Val F1": f1_score(y_val_mix, y_pred_val_svm_tuned, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix, y_pred_test_svm_tuned),
    "Test Precision": precision_score(y_test_mix, y_pred_test_svm_tuned, average='weighted'),
    "Test Recall": recall_score(y_test_mix, y_pred_test_svm_tuned, average='weighted'),
    "Test F1": f1_score(y_test_mix, y_pred_test_svm_tuned, average='weighted')
})

# RF tuned
tuned_results.append({
    "Experiment": "ACGAN Mixed Tuned",
    "Model": "Random Forest Tuned",
    "Val Accuracy": accuracy_score(y_val_mix_rf, y_pred_val_rf_tuned),
    "Val Precision": precision_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'),
    "Val Recall": recall_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'),
    "Val F1": f1_score(y_val_mix_rf, y_pred_val_rf_tuned, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix_rf, y_pred_test_rf_tuned),
    "Test Precision": precision_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted'),
    "Test Recall": recall_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted'),
    "Test F1": f1_score(y_test_mix_rf, y_pred_test_rf_tuned, average='weighted')
})

# CNN tuned
tuned_results.append({
    "Experiment": "ACGAN Mixed Tuned",
    "Model": "CNN Tuned",
    "Val Accuracy": accuracy_score(y_val_mix, y_pred_val_cnn_tuned),
    "Val Precision": precision_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'),
    "Val Recall": recall_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'),
    "Val F1": f1_score(y_val_mix, y_pred_val_cnn_tuned, average='weighted'),
    "Test Accuracy": accuracy_score(y_test_mix, y_pred_test_cnn_tuned),
    "Test Precision": precision_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted'),
    "Test Recall": recall_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted'),
    "Test F1": f1_score(y_test_mix, y_pred_test_cnn_tuned, average='weighted')
})

df_tuned_results = pd.DataFrame(tuned_results)

print("=== RINGKASAN HASIL TUNED MODELS ===")
display(df_tuned_results.round(4))

df_tuned_results.to_csv("gamma_only_acgan_mixed_tuned_results.csv", index=False)

print("Hasil tuning disimpan sebagai gamma_only_acgan_mixed_tuned_results.csv")
# Out:
# === RINGKASAN HASIL TUNED MODELS ===
#           Experiment                Model  Val Accuracy  Val Precision  \
# 0  ACGAN Mixed Tuned            SVM Tuned        0.7821         0.8298
# 1  ACGAN Mixed Tuned  Random Forest Tuned        0.8234         0.8543
# 2  ACGAN Mixed Tuned            CNN Tuned        0.8119         0.8402
#
#    Val Recall  Val F1  Test Accuracy  Test Precision  Test Recall  Test F1
# 0      0.7821  0.7743         0.7935          0.8459       0.7935   0.7856
# 1      0.8234  0.8193         0.8185          0.8539       0.8185   0.8137
# 2      0.8119  0.8077         0.8050          0.8323       0.8050   0.8008
# Hasil tuning disimpan sebagai gamma_only_acgan_mixed_tuned_results.csv

# %% [markdown]
# pengenalan label

# %%
# ============================================================
# LABEL-AWARE TRAINING
# Real + Synthetic untuk Train, Validation, dan Test
# Fokus: model mengenali Label 0 dan Label 1 secara lebih seimbang
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
import time

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, balanced_accuracy_score
)
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ============================================================
# 1. Helper: cari threshold terbaik dari validation set
# ============================================================

def find_best_threshold(y_true, y_prob, metric="macro_f1"):
    """
    Mencari threshold terbaik untuk klasifikasi binary.
    Fokus agar Label 0 dan Label 1 lebih seimbang.
    """
    thresholds = np.arange(0.05, 0.96, 0.01)
    best_threshold = 0.5
    best_score = -1

    records = []

    for th in thresholds:
        y_pred = (y_prob >= th).astype(int)

        acc = accuracy_score(y_true, y_pred)
        bal_acc = balanced_accuracy_score(y_true, y_pred)
        macro_f1 = f1_score(y_true, y_pred, average="macro")
        weighted_f1 = f1_score(y_true, y_pred, average="weighted")

        records.append({
            "threshold": th,
            "accuracy": acc,
            "balanced_accuracy": bal_acc,
            "macro_f1": macro_f1,
            "weighted_f1": weighted_f1
        })

        if metric == "macro_f1":
            score = macro_f1
        elif metric == "balanced_accuracy":
            score = bal_acc
        else:
            score = acc

        if score > best_score:
            best_score = score
            best_threshold = th

    df_thresholds = pd.DataFrame(records)

    return best_threshold, best_score, df_thresholds


# ============================================================
# 2. Helper: evaluasi model dengan threshold pilihan
# ============================================================

def evaluate_binary_model(model_name, y_val_true, y_val_prob, y_test_true, y_test_prob, threshold):
    y_val_pred = (y_val_prob >= threshold).astype(int)
    y_test_pred = (y_test_prob >= threshold).astype(int)

    print("\n" + "="*80)
    print(f"{model_name} | BEST THRESHOLD = {threshold:.2f}")
    print("="*80)

    print("\nVALIDATION SET, REAL + SYNTHETIC")
    print("-"*80)
    print(f"Accuracy          : {accuracy_score(y_val_true, y_val_pred):.4f}")
    print(f"Balanced Accuracy : {balanced_accuracy_score(y_val_true, y_val_pred):.4f}")
    print(f"Precision Macro   : {precision_score(y_val_true, y_val_pred, average='macro'):.4f}")
    print(f"Recall Macro      : {recall_score(y_val_true, y_val_pred, average='macro'):.4f}")
    print(f"F1 Macro          : {f1_score(y_val_true, y_val_pred, average='macro'):.4f}")
    print(f"F1 Weighted       : {f1_score(y_val_true, y_val_pred, average='weighted'):.4f}")
    print(f"\nConfusion Matrix:\n{confusion_matrix(y_val_true, y_val_pred)}")
    print("\nClassification Report:")
    print(classification_report(
        y_val_true,
        y_val_pred,
        target_names=["Label 0 (Before)", "Label 1 (After)"]
    ))

    print("\nTEST SET, REAL + SYNTHETIC")
    print("-"*80)
    print(f"Accuracy          : {accuracy_score(y_test_true, y_test_pred):.4f}")
    print(f"Balanced Accuracy : {balanced_accuracy_score(y_test_true, y_test_pred):.4f}")
    print(f"Precision Macro   : {precision_score(y_test_true, y_test_pred, average='macro'):.4f}")
    print(f"Recall Macro      : {recall_score(y_test_true, y_test_pred, average='macro'):.4f}")
    print(f"F1 Macro          : {f1_score(y_test_true, y_test_pred, average='macro'):.4f}")
    print(f"F1 Weighted       : {f1_score(y_test_true, y_test_pred, average='weighted'):.4f}")
    print(f"\nConfusion Matrix:\n{confusion_matrix(y_test_true, y_test_pred)}")
    print("\nClassification Report:")
    print(classification_report(
        y_test_true,
        y_test_pred,
        target_names=["Label 0 (Before)", "Label 1 (After)"]
    ))

    return {
        "Model": model_name,
        "Best Threshold": threshold,
        "Val Accuracy": accuracy_score(y_val_true, y_val_pred),
        "Val Balanced Accuracy": balanced_accuracy_score(y_val_true, y_val_pred),
        "Val Macro F1": f1_score(y_val_true, y_val_pred, average="macro"),
        "Val Weighted F1": f1_score(y_val_true, y_val_pred, average="weighted"),
        "Test Accuracy": accuracy_score(y_test_true, y_test_pred),
        "Test Balanced Accuracy": balanced_accuracy_score(y_test_true, y_test_pred),
        "Test Macro F1": f1_score(y_test_true, y_test_pred, average="macro"),
        "Test Weighted F1": f1_score(y_test_true, y_test_pred, average="weighted")
    }


# ============================================================
# 3. Class weight untuk membantu model memperhatikan dua label
# ============================================================

classes = np.array([0, 1])
class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train_mix
)

class_weights_dict = {
    0: class_weights_array[0],
    1: class_weights_array[1]
}

print("Class weights:")
print(class_weights_dict)


# ============================================================
# 4. MODEL 1: SVM probability + threshold tuning
# ============================================================

print("\n\nTraining label-aware SVM...")
start = time.time()

svm_label_model = SVC(
    kernel="rbf",
    C=50,
    gamma=0.1,
    probability=True,
    class_weight="balanced",
    random_state=42
)

svm_label_model.fit(X_train_mix_scaled, y_train_mix)

print(f"SVM training time: {time.time() - start:.2f} detik")

y_val_prob_svm_label = svm_label_model.predict_proba(X_val_mix_scaled)[:, 1]
y_test_prob_svm_label = svm_label_model.predict_proba(X_test_mix_scaled)[:, 1]

best_th_svm, best_score_svm, df_th_svm = find_best_threshold(
    y_val_mix,
    y_val_prob_svm_label,
    metric="macro_f1"
)

result_svm_label = evaluate_binary_model(
    "SVM Label-Aware",
    y_val_mix,
    y_val_prob_svm_label,
    y_test_mix,
    y_test_prob_svm_label,
    best_th_svm
)


# ============================================================
# 5. MODEL 2: Random Forest lebih kuat + threshold tuning
# ============================================================

print("\n\nTraining label-aware Random Forest...")
start = time.time()

rf_label_model = RandomForestClassifier(
    n_estimators=1000,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features="sqrt",
    bootstrap=False,
    class_weight="balanced_subsample",
    random_state=42,
    n_jobs=-1
)

rf_label_model.fit(X_train_mix_unscaled, y_train_mix_rf)

print(f"Random Forest training time: {time.time() - start:.2f} detik")

y_val_prob_rf_label = rf_label_model.predict_proba(X_val_mix_unscaled)[:, 1]
y_test_prob_rf_label = rf_label_model.predict_proba(X_test_mix_unscaled)[:, 1]

best_th_rf, best_score_rf, df_th_rf = find_best_threshold(
    y_val_mix_rf,
    y_val_prob_rf_label,
    metric="macro_f1"
)

result_rf_label = evaluate_binary_model(
    "Random Forest Label-Aware",
    y_val_mix_rf,
    y_val_prob_rf_label,
    y_test_mix_rf,
    y_test_prob_rf_label,
    best_th_rf
)


# ============================================================
# 6. MODEL 3: Extra Trees, sering lebih kuat untuk tabular features
# ============================================================

print("\n\nTraining label-aware Extra Trees...")
start = time.time()

et_label_model = ExtraTreesClassifier(
    n_estimators=1000,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features="sqrt",
    bootstrap=False,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

et_label_model.fit(X_train_mix_unscaled, y_train_mix_rf)

print(f"Extra Trees training time: {time.time() - start:.2f} detik")

y_val_prob_et_label = et_label_model.predict_proba(X_val_mix_unscaled)[:, 1]
y_test_prob_et_label = et_label_model.predict_proba(X_test_mix_unscaled)[:, 1]

best_th_et, best_score_et, df_th_et = find_best_threshold(
    y_val_mix_rf,
    y_val_prob_et_label,
    metric="macro_f1"
)

result_et_label = evaluate_binary_model(
    "Extra Trees Label-Aware",
    y_val_mix_rf,
    y_val_prob_et_label,
    y_test_mix_rf,
    y_test_prob_et_label,
    best_th_et
)


# ============================================================
# 7. MODEL 4: MLP tabular, lebih cocok daripada CNN untuk 8 fitur tabular
# ============================================================

print("\n\nTraining label-aware MLP untuk tabular Gamma features...")

tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

mlp_label_model = Sequential([
    Input(shape=(feature_dim,)),

    Dense(128, activation="relu"),
    BatchNormalization(),
    Dropout(0.25),

    Dense(128, activation="relu"),
    BatchNormalization(),
    Dropout(0.20),

    Dense(64, activation="relu"),
    BatchNormalization(),
    Dropout(0.15),

    Dense(32, activation="relu"),
    Dropout(0.10),

    Dense(1, activation="sigmoid")
])

mlp_label_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

early_stop_mlp = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_mlp = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=7,
    min_lr=1e-6,
    verbose=1
)

start = time.time()

history_mlp_label = mlp_label_model.fit(
    X_train_mix_scaled,
    y_train_mix,
    validation_data=(X_val_mix_scaled, y_val_mix),
    epochs=200,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[early_stop_mlp, reduce_lr_mlp],
    verbose=1
)

print(f"MLP training time: {time.time() - start:.2f} detik")

y_val_prob_mlp_label = mlp_label_model.predict(X_val_mix_scaled, verbose=0).flatten()
y_test_prob_mlp_label = mlp_label_model.predict(X_test_mix_scaled, verbose=0).flatten()

best_th_mlp, best_score_mlp, df_th_mlp = find_best_threshold(
    y_val_mix,
    y_val_prob_mlp_label,
    metric="macro_f1"
)

result_mlp_label = evaluate_binary_model(
    "MLP Label-Aware",
    y_val_mix,
    y_val_prob_mlp_label,
    y_test_mix,
    y_test_prob_mlp_label,
    best_th_mlp
)


# ============================================================
# 8. Ensemble probabilitas: RF + Extra Trees + SVM + MLP
# ============================================================

print("\n\nEvaluasi Ensemble Probability Averaging...")

# Pastikan semua probabilitas dari validation/test memakai urutan data yang sama
y_val_prob_ensemble = (
    y_val_prob_svm_label +
    y_val_prob_rf_label +
    y_val_prob_et_label +
    y_val_prob_mlp_label
) / 4

y_test_prob_ensemble = (
    y_test_prob_svm_label +
    y_test_prob_rf_label +
    y_test_prob_et_label +
    y_test_prob_mlp_label
) / 4

best_th_ensemble, best_score_ensemble, df_th_ensemble = find_best_threshold(
    y_val_mix,
    y_val_prob_ensemble,
    metric="macro_f1"
)

result_ensemble_label = evaluate_binary_model(
    "Ensemble Label-Aware",
    y_val_mix,
    y_val_prob_ensemble,
    y_test_mix,
    y_test_prob_ensemble,
    best_th_ensemble
)


# ============================================================
# 9. Ringkasan semua model label-aware
# ============================================================

label_aware_results = pd.DataFrame([
    result_svm_label,
    result_rf_label,
    result_et_label,
    result_mlp_label,
    result_ensemble_label
])

print("\n" + "="*80)
print("RINGKASAN HASIL LABEL-AWARE MODELS")
print("="*80)

display(label_aware_results.sort_values(
    by="Test Macro F1",
    ascending=False
).round(4))

label_aware_results.to_csv(
    "gamma_only_acgan_mixed_label_aware_results.csv",
    index=False
)

print("\nHasil disimpan sebagai gamma_only_acgan_mixed_label_aware_results.csv")


# ============================================================
# 10. Lihat threshold terbaik setiap model
# ============================================================

print("\nBest threshold per model:")
print(f"SVM        : {best_th_svm:.2f}")
print(f"RF         : {best_th_rf:.2f}")
print(f"ExtraTrees : {best_th_et:.2f}")
print(f"MLP        : {best_th_mlp:.2f}")
print(f"Ensemble   : {best_th_ensemble:.2f}")
# Out:
# Class weights:
# {0: np.float64(1.0052356020942408), 1: np.float64(0.9948186528497409)}
#
#
# Training label-aware SVM...
# SVM training time: 8.23 detik
#
# ================================================================================
# SVM Label-Aware | BEST THRESHOLD = 0.66
# ================================================================================
#
# VALIDATION SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.7855
# Balanced Accuracy : 0.7868
# Precision Macro   : 0.8349
# Recall Macro      : 0.7868
# F1 Macro          : 0.7778
# F1 Weighted       : 0.7775
#
# Confusion Matrix:
# [[718  16]
#  [301 443]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.98      0.82       734
#  Label 1 (After)       0.97      0.60      0.74       744
#
#         accuracy                           0.79      1478
#        macro avg       0.83      0.79      0.78      1478
#     weighted avg       0.84      0.79      0.78      1478
#
#
# TEST SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.7861
# Balanced Accuracy : 0.7869
# Precision Macro   : 0.8405
# Recall Macro      : 0.7869
# F1 Macro          : 0.7775
# F1 Weighted       : 0.7773
#
# Confusion Matrix:
# [[728  10]
#  [307 437]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.70      0.99      0.82       738
#  Label 1 (After)       0.98      0.59      0.73       744
#
#         accuracy                           0.79      1482
#        macro avg       0.84      0.79      0.78      1482
#     weighted avg       0.84      0.79      0.78      1482
#
#
#
# Training label-aware Random Forest...
# Random Forest training time: 4.09 detik
#
# ================================================================================
# Random Forest Label-Aware | BEST THRESHOLD = 0.39
# ================================================================================
#
# VALIDATION SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8248
# Balanced Accuracy : 0.8237
# Precision Macro   : 0.8604
# Recall Macro      : 0.8237
# F1 Macro          : 0.8200
# F1 Weighted       : 0.8202
#
# Confusion Matrix:
# [[489 245]
#  [ 14 730]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.67      0.79       734
#  Label 1 (After)       0.75      0.98      0.85       744
#
#         accuracy                           0.82      1478
#        macro avg       0.86      0.82      0.82      1478
#     weighted avg       0.86      0.82      0.82      1478
#
#
# TEST SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8178
# Balanced Accuracy : 0.8171
# Precision Macro   : 0.8575
# Recall Macro      : 0.8171
# F1 Macro          : 0.8124
# F1 Weighted       : 0.8125
#
# Confusion Matrix:
# [[480 258]
#  [ 12 732]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.98      0.65      0.78       738
#  Label 1 (After)       0.74      0.98      0.84       744
#
#         accuracy                           0.82      1482
#        macro avg       0.86      0.82      0.81      1482
#     weighted avg       0.86      0.82      0.81      1482
#
#
#
# Training label-aware Extra Trees...
# Extra Trees training time: 2.49 detik
#
# ================================================================================
# Extra Trees Label-Aware | BEST THRESHOLD = 0.45
# ================================================================================
#
# VALIDATION SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8248
# Balanced Accuracy : 0.8237
# Precision Macro   : 0.8591
# Recall Macro      : 0.8237
# F1 Macro          : 0.8201
# F1 Weighted       : 0.8203
#
# Confusion Matrix:
# [[491 243]
#  [ 16 728]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.67      0.79       734
#  Label 1 (After)       0.75      0.98      0.85       744
#
#         accuracy                           0.82      1478
#        macro avg       0.86      0.82      0.82      1478
#     weighted avg       0.86      0.82      0.82      1478
#
#
# TEST SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8171
# Balanced Accuracy : 0.8165
# Precision Macro   : 0.8557
# Recall Macro      : 0.8165
# F1 Macro          : 0.8118
# F1 Weighted       : 0.8120
#
# Confusion Matrix:
# [[481 257]
#  [ 14 730]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.65      0.78       738
#  Label 1 (After)       0.74      0.98      0.84       744
#
#         accuracy                           0.82      1482
#        macro avg       0.86      0.82      0.81      1482
#     weighted avg       0.86      0.82      0.81      1482
#
#
#
# Training label-aware MLP untuk tabular Gamma features...
# Epoch 1/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7286 - loss: 0.5373 - val_accuracy: 0.7713 - val_loss: 0.5158 - learning_rate: 5.0000e-04
# Epoch 2/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7607 - loss: 0.4666 - val_accuracy: 0.7794 - val_loss: 0.4441 - learning_rate: 5.0000e-04
# Epoch 3/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7633 - loss: 0.4456 - val_accuracy: 0.7713 - val_loss: 0.4229 - learning_rate: 5.0000e-04
# Epoch 4/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7669 - loss: 0.4259 - val_accuracy: 0.7693 - val_loss: 0.3943 - learning_rate: 5.0000e-04
# Epoch 5/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7682 - loss: 0.4110 - val_accuracy: 0.7963 - val_loss: 0.3856 - learning_rate: 5.0000e-04
# Epoch 6/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7739 - loss: 0.3958 - val_accuracy: 0.7700 - val_loss: 0.3708 - learning_rate: 5.0000e-04
# Epoch 7/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7691 - loss: 0.3903 - val_accuracy: 0.7652 - val_loss: 0.3659 - learning_rate: 5.0000e-04
# Epoch 8/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7769 - loss: 0.3813 - val_accuracy: 0.7876 - val_loss: 0.3804 - learning_rate: 5.0000e-04
# Epoch 9/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7789 - loss: 0.3731 - val_accuracy: 0.7876 - val_loss: 0.3505 - learning_rate: 5.0000e-04
# Epoch 10/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7766 - loss: 0.3644 - val_accuracy: 0.7869 - val_loss: 0.3642 - learning_rate: 5.0000e-04
# Epoch 11/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7743 - loss: 0.3636 - val_accuracy: 0.7862 - val_loss: 0.3582 - learning_rate: 5.0000e-04
# Epoch 12/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7772 - loss: 0.3595 - val_accuracy: 0.7936 - val_loss: 0.3629 - learning_rate: 5.0000e-04
# Epoch 13/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7830 - loss: 0.3566 - val_accuracy: 0.7963 - val_loss: 0.3468 - learning_rate: 5.0000e-04
# Epoch 14/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7808 - loss: 0.3530 - val_accuracy: 0.7909 - val_loss: 0.3404 - learning_rate: 5.0000e-04
# Epoch 15/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.3494 - val_accuracy: 0.7889 - val_loss: 0.3554 - learning_rate: 5.0000e-04
# Epoch 16/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7808 - loss: 0.3498 - val_accuracy: 0.7916 - val_loss: 0.3548 - learning_rate: 5.0000e-04
# Epoch 17/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7839 - loss: 0.3452 - val_accuracy: 0.7984 - val_loss: 0.3546 - learning_rate: 5.0000e-04
# Epoch 18/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7834 - loss: 0.3436 - val_accuracy: 0.7963 - val_loss: 0.3485 - learning_rate: 5.0000e-04
# Epoch 19/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7792 - loss: 0.3427 - val_accuracy: 0.7828 - val_loss: 0.3687 - learning_rate: 5.0000e-04
# Epoch 20/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7784 - loss: 0.3413 - val_accuracy: 0.7984 - val_loss: 0.3407 - learning_rate: 5.0000e-04
# Epoch 21/200
# 197/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7874 - loss: 0.3427
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7866 - loss: 0.3410 - val_accuracy: 0.7930 - val_loss: 0.3512 - learning_rate: 5.0000e-04
# Epoch 22/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7801 - loss: 0.3378 - val_accuracy: 0.7963 - val_loss: 0.3399 - learning_rate: 2.5000e-04
# Epoch 23/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7817 - loss: 0.3335 - val_accuracy: 0.7991 - val_loss: 0.3401 - learning_rate: 2.5000e-04
# Epoch 24/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.3315 - val_accuracy: 0.7957 - val_loss: 0.3385 - learning_rate: 2.5000e-04
# Epoch 25/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.3295 - val_accuracy: 0.7970 - val_loss: 0.3326 - learning_rate: 2.5000e-04
# Epoch 26/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7852 - loss: 0.3341 - val_accuracy: 0.8072 - val_loss: 0.3287 - learning_rate: 2.5000e-04
# Epoch 27/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 0.3316 - val_accuracy: 0.8004 - val_loss: 0.3336 - learning_rate: 2.5000e-04
# Epoch 28/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7808 - loss: 0.3347 - val_accuracy: 0.8011 - val_loss: 0.3329 - learning_rate: 2.5000e-04
# Epoch 29/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7865 - loss: 0.3309 - val_accuracy: 0.8011 - val_loss: 0.3342 - learning_rate: 2.5000e-04
# Epoch 30/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7830 - loss: 0.3294 - val_accuracy: 0.7963 - val_loss: 0.3330 - learning_rate: 2.5000e-04
# Epoch 31/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7896 - loss: 0.3283 - val_accuracy: 0.7997 - val_loss: 0.3319 - learning_rate: 2.5000e-04
# Epoch 32/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7850 - loss: 0.3279 - val_accuracy: 0.7963 - val_loss: 0.3281 - learning_rate: 2.5000e-04
# Epoch 33/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7765 - loss: 0.3289 - val_accuracy: 0.8011 - val_loss: 0.3271 - learning_rate: 2.5000e-04
# Epoch 34/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7854 - loss: 0.3277 - val_accuracy: 0.7991 - val_loss: 0.3343 - learning_rate: 2.5000e-04
# Epoch 35/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7817 - loss: 0.3292 - val_accuracy: 0.7977 - val_loss: 0.3323 - learning_rate: 2.5000e-04
# Epoch 36/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7888 - loss: 0.3286 - val_accuracy: 0.8004 - val_loss: 0.3315 - learning_rate: 2.5000e-04
# Epoch 37/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.3246 - val_accuracy: 0.8011 - val_loss: 0.3265 - learning_rate: 2.5000e-04
# Epoch 38/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7879 - loss: 0.3260 - val_accuracy: 0.7991 - val_loss: 0.3258 - learning_rate: 2.5000e-04
# Epoch 39/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7882 - loss: 0.3262 - val_accuracy: 0.8011 - val_loss: 0.3265 - learning_rate: 2.5000e-04
# Epoch 40/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7837 - loss: 0.3259 - val_accuracy: 0.7970 - val_loss: 0.3287 - learning_rate: 2.5000e-04
# Epoch 41/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7850 - loss: 0.3270 - val_accuracy: 0.7984 - val_loss: 0.3275 - learning_rate: 2.5000e-04
# Epoch 42/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 0.3214 - val_accuracy: 0.8018 - val_loss: 0.3264 - learning_rate: 2.5000e-04
# Epoch 43/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7799 - loss: 0.3259 - val_accuracy: 0.7828 - val_loss: 0.3222 - learning_rate: 2.5000e-04
# Epoch 44/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.3249 - val_accuracy: 0.8024 - val_loss: 0.3287 - learning_rate: 2.5000e-04
# Epoch 45/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7820 - loss: 0.3210 - val_accuracy: 0.7828 - val_loss: 0.3253 - learning_rate: 2.5000e-04
# Epoch 46/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 0.3214 - val_accuracy: 0.7842 - val_loss: 0.3209 - learning_rate: 2.5000e-04
# Epoch 47/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7907 - loss: 0.3231 - val_accuracy: 0.8038 - val_loss: 0.3256 - learning_rate: 2.5000e-04
# Epoch 48/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7917 - loss: 0.3248 - val_accuracy: 0.8031 - val_loss: 0.3253 - learning_rate: 2.5000e-04
# Epoch 49/200
#  42/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7937 - loss: 0.3217
# [CV] END C=5, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   2.3s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   1.5s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.01, kernel=poly; total time=   1.4s
# [CV] END C=1, class_weight=balanced, degree=4, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END C=1, class_weight=balanced, degree=4, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   1.7s
# [CV] END C=200, class_weight=None, degree=3, gamma=scale, kernel=sigmoid; total time=   1.3s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=auto, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.005, kernel=rbf; total time=   1.7s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=sigmoid; total time=   1.4s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.5, kernel=sigmoid; total time=   1.9s
# 116/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7921 - loss: 0.3213
# [CV] END bootstrap=True, class_weight=None, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   8.5s
# [CV] END bootstrap=True, class_weight=None, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   6.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  13.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=True, class_weight=None, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  49.7s
# [CV] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  40.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=700; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=True, class_weight=None, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   2.9s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   1.9s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.5, kernel=poly; total time=   3.7s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.5, kernel=poly; total time=   3.8s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   2.0s
# [CV] END C=200, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   3.2s
# [CV] END C=100, class_weight=None, degree=2, gamma=0.01, kernel=sigmoid; total time=   1.6s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   2.0s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   1.9s
# [CV] END C=10, class_weight=balanced, degree=4, gamma=0.001, kernel=poly; total time=   1.9s
# [CV] END C=50, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time=   4.4s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=0.001, kernel=poly; total time=   2.0s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=1, kernel=rbf; total time=   3.3s
# [CV] END C=25, class_weight=None, degree=4, gamma=0.5, kernel=poly; total time= 2.9min
# [CV] END C=5, class_weight=balanced, degree=4, gamma=auto, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=auto, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=auto, kernel=rbf; total time=   1.5s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=auto, kernel=rbf; total time=   1.4s
# [CV] END C=50, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   3.4s
# [CV] END C=50, class_weight=balanced, degree=4, gamma=0.1, kernel=poly; total time=   3.0s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.05, kernel=sigmoid; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.05, kernel=sigmoid; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.05, kernel=sigmoid; total time=   2.0s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=sigmoid; total time=   2.5s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=sigmoid; total time=   2.5s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=scale, kernel=sigmoid; total time=   1.8s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=scale, kernel=sigmoid; total time=   1.5s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=scale, kernel=sigmoid; total time=   1.6s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=poly; total time= 1.0min
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=poly; total time= 1.1min
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=rbf; total time=   2.0s
# [CV] END C=50, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=50, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid; total time=   1.9s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=5, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   2.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   1.4s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.01, kernel=poly; total time=   1.3s
# [CV] END C=1, class_weight=balanced, degree=4, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   1.8s
# [CV] END C=200, class_weight=None, degree=3, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=200, class_weight=None, degree=3, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=auto, kernel=sigmoid; total time=   1.5s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.7s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.005, kernel=rbf; total time=   1.6s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=sigmoid; total time=   1.4s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=sigmoid; total time=   1.3s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.5, kernel=sigmoid; total time=   1.8s
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7901 - loss: 0.3215 - val_accuracy: 0.8024 - val_loss: 0.3264 - learning_rate: 2.5000e-04
# Epoch 50/200
#   1/216 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7500 - loss: 0.3786
# [CV] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.1s
# [CV] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid; total time=   2.0s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid; total time=   1.5s
# [CV] END C=5, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid; total time=   1.4s
# [CV] END C=1, class_weight=balanced, degree=2, gamma=0.5, kernel=poly; total time=   1.5s
# [CV] END C=1, class_weight=balanced, degree=2, gamma=0.5, kernel=poly; total time=   1.5s
# [CV] END C=200, class_weight=None, degree=4, gamma=0.5, kernel=rbf; total time=   4.3s
# [CV] END C=1, class_weight=None, degree=4, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=1, class_weight=None, degree=4, gamma=scale, kernel=sigmoid; total time=   1.4s
# [CV] END C=1, class_weight=None, degree=4, gamma=scale, kernel=sigmoid; total time=   1.5s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=sigmoid; total time=   1.6s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=sigmoid; total time=   1.6s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=2, gamma=0.1, kernel=rbf; total time=   1.2s
# [CV] END C=200, class_weight=balanced, degree=3, gamma=0.01, kernel=sigmoid; total time=   1.3s
# [CV] END C=5, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.4s
# [CV] END C=5, class_weight=None, degree=4, gamma=auto, kernel=rbf; total time=   1.3s
# [CV] END C=25, class_weight=balanced, degree=3, gamma=1, kernel=rbf; total time=   1.9s
# [CV] END C=25, class_weight=balanced, degree=3, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END C=50, class_weight=None, degree=3, gamma=0.001, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=0.005, kernel=rbf; total time=   1.9s
# [CV] END C=50, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid; total time=   1.8s
# [CV] END C=25, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid; total time=   1.7s
# [CV] END C=5, class_weight=balanced, degree=3, gamma=0.05, kernel=rbf; total time=   1.4s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   1.9s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   1.4s
# [CV] END C=0.1, class_weight=None, degree=4, gamma=1, kernel=rbf; total time=   1.4s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.01, kernel=poly; total time=   1.3s
# [CV] END C=1, class_weight=balanced, degree=4, gamma=0.01, kernel=rbf; total time=   1.7s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   1.8s
# [CV] END C=25, class_weight=None, degree=2, gamma=1, kernel=rbf; total time=   1.8s
# [CV] END C=200, class_weight=None, degree=3, gamma=scale, kernel=sigmoid; total time=   1.3s
# [CV] END C=100, class_weight=balanced, degree=4, gamma=auto, kernel=sigmoid; total time=   1.5s
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.7s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.005, kernel=rbf; total time=   1.6s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.005, kernel=rbf; total time=   1.5s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=sigmoid; total time=   2.0s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.5, kernel=sigmoid; total time=   1.5s
#  74/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7927 - loss: 0.3233
# [CV] END C=100, class_weight=None, degree=4, gamma=1, kernel=sigmoid; total time=   1.7s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.005, kernel=rbf; total time=   1.5s
# [CV] END C=100, class_weight=None, degree=4, gamma=auto, kernel=sigmoid; total time=   1.3s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.5, kernel=sigmoid; total time=   1.8s
# [CV] END C=50, class_weight=balanced, degree=2, gamma=0.5, kernel=sigmoid; total time=   1.2s
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7826 - loss: 0.3247 - val_accuracy: 0.8051 - val_loss: 0.3241 - learning_rate: 2.5000e-04
# Epoch 51/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7869 - loss: 0.3212 - val_accuracy: 0.7821 - val_loss: 0.3230 - learning_rate: 2.5000e-04
# Epoch 52/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7930 - loss: 0.3223 - val_accuracy: 0.8004 - val_loss: 0.3305 - learning_rate: 2.5000e-04
# Epoch 53/200
# 208/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7883 - loss: 0.3197
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7892 - loss: 0.3220 - val_accuracy: 0.7963 - val_loss: 0.3306 - learning_rate: 2.5000e-04
# Epoch 54/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7943 - loss: 0.3220 - val_accuracy: 0.8011 - val_loss: 0.3222 - learning_rate: 1.2500e-04
# Epoch 55/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7914 - loss: 0.3177 - val_accuracy: 0.8018 - val_loss: 0.3228 - learning_rate: 1.2500e-04
# Epoch 56/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7922 - loss: 0.3221 - val_accuracy: 0.8024 - val_loss: 0.3203 - learning_rate: 1.2500e-04
# Epoch 57/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7872 - loss: 0.3193 - val_accuracy: 0.8038 - val_loss: 0.3218 - learning_rate: 1.2500e-04
# Epoch 58/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7834 - loss: 0.3172 - val_accuracy: 0.8038 - val_loss: 0.3202 - learning_rate: 1.2500e-04
# Epoch 59/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7960 - loss: 0.3153 - val_accuracy: 0.8024 - val_loss: 0.3206 - learning_rate: 1.2500e-04
# Epoch 60/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.3137 - val_accuracy: 0.8065 - val_loss: 0.3206 - learning_rate: 1.2500e-04
# Epoch 61/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7902 - loss: 0.3167 - val_accuracy: 0.8031 - val_loss: 0.3220 - learning_rate: 1.2500e-04
# Epoch 62/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7911 - loss: 0.3216 - val_accuracy: 0.8072 - val_loss: 0.3226 - learning_rate: 1.2500e-04
# Epoch 63/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7972 - loss: 0.3172 - val_accuracy: 0.8018 - val_loss: 0.3216 - learning_rate: 1.2500e-04
# Epoch 64/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.3163 - val_accuracy: 0.8045 - val_loss: 0.3185 - learning_rate: 1.2500e-04
# Epoch 65/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7956 - loss: 0.3154 - val_accuracy: 0.8058 - val_loss: 0.3204 - learning_rate: 1.2500e-04
# Epoch 66/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.3133 - val_accuracy: 0.8051 - val_loss: 0.3185 - learning_rate: 1.2500e-04
# Epoch 67/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7876 - loss: 0.3164 - val_accuracy: 0.8106 - val_loss: 0.3198 - learning_rate: 1.2500e-04
# Epoch 68/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7938 - loss: 0.3140 - val_accuracy: 0.8051 - val_loss: 0.3211 - learning_rate: 1.2500e-04
# Epoch 69/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7953 - loss: 0.3152 - val_accuracy: 0.7997 - val_loss: 0.3231 - learning_rate: 1.2500e-04
# Epoch 70/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7860 - loss: 0.3174 - val_accuracy: 0.8031 - val_loss: 0.3209 - learning_rate: 1.2500e-04
# Epoch 71/200
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7959 - loss: 0.3124
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7959 - loss: 0.3116 - val_accuracy: 0.8072 - val_loss: 0.3188 - learning_rate: 1.2500e-04
# Epoch 72/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7964 - loss: 0.3126 - val_accuracy: 0.8099 - val_loss: 0.3177 - learning_rate: 6.2500e-05
# Epoch 73/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7944 - loss: 0.3139 - val_accuracy: 0.8078 - val_loss: 0.3182 - learning_rate: 6.2500e-05
# Epoch 74/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.3128 - val_accuracy: 0.8072 - val_loss: 0.3179 - learning_rate: 6.2500e-05
# Epoch 75/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7941 - loss: 0.3143 - val_accuracy: 0.8078 - val_loss: 0.3183 - learning_rate: 6.2500e-05
# Epoch 76/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7922 - loss: 0.3117 - val_accuracy: 0.8099 - val_loss: 0.3165 - learning_rate: 6.2500e-05
# Epoch 77/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7970 - loss: 0.3177 - val_accuracy: 0.8092 - val_loss: 0.3149 - learning_rate: 6.2500e-05
# Epoch 78/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7967 - loss: 0.3140 - val_accuracy: 0.8106 - val_loss: 0.3156 - learning_rate: 6.2500e-05
# Epoch 79/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7963 - loss: 0.3106 - val_accuracy: 0.8099 - val_loss: 0.3158 - learning_rate: 6.2500e-05
# Epoch 80/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7957 - loss: 0.3102 - val_accuracy: 0.8106 - val_loss: 0.3151 - learning_rate: 6.2500e-05
# Epoch 81/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8008 - loss: 0.3091 - val_accuracy: 0.8078 - val_loss: 0.3146 - learning_rate: 6.2500e-05
# Epoch 82/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8016 - loss: 0.3133 - val_accuracy: 0.8085 - val_loss: 0.3167 - learning_rate: 6.2500e-05
# Epoch 83/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8002 - loss: 0.3088 - val_accuracy: 0.8085 - val_loss: 0.3161 - learning_rate: 6.2500e-05
# Epoch 84/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7892 - loss: 0.3140 - val_accuracy: 0.8092 - val_loss: 0.3167 - learning_rate: 6.2500e-05
# Epoch 85/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.3114 - val_accuracy: 0.8099 - val_loss: 0.3158 - learning_rate: 6.2500e-05
# Epoch 86/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.3109 - val_accuracy: 0.8099 - val_loss: 0.3146 - learning_rate: 6.2500e-05
# Epoch 87/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7973 - loss: 0.3088 - val_accuracy: 0.8085 - val_loss: 0.3156 - learning_rate: 6.2500e-05
# Epoch 88/200
# 207/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7915 - loss: 0.3140
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7878 - loss: 0.3156 - val_accuracy: 0.8099 - val_loss: 0.3151 - learning_rate: 6.2500e-05
# Epoch 89/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7975 - loss: 0.3110 - val_accuracy: 0.8092 - val_loss: 0.3159 - learning_rate: 3.1250e-05
# Epoch 90/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7925 - loss: 0.3116 - val_accuracy: 0.8106 - val_loss: 0.3148 - learning_rate: 3.1250e-05
# Epoch 91/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7920 - loss: 0.3095 - val_accuracy: 0.8099 - val_loss: 0.3153 - learning_rate: 3.1250e-05
# Epoch 92/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7948 - loss: 0.3064 - val_accuracy: 0.8112 - val_loss: 0.3156 - learning_rate: 3.1250e-05
# Epoch 93/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7917 - loss: 0.3106 - val_accuracy: 0.8099 - val_loss: 0.3161 - learning_rate: 3.1250e-05
# Epoch 94/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7990 - loss: 0.3090 - val_accuracy: 0.8099 - val_loss: 0.3156 - learning_rate: 3.1250e-05
# Epoch 95/200
# 204/216 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7881 - loss: 0.3118
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7938 - loss: 0.3097 - val_accuracy: 0.8099 - val_loss: 0.3160 - learning_rate: 3.1250e-05
# Epoch 96/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8034 - loss: 0.3090 - val_accuracy: 0.8099 - val_loss: 0.3154 - learning_rate: 1.5625e-05
# Epoch 97/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7989 - loss: 0.3113 - val_accuracy: 0.8099 - val_loss: 0.3154 - learning_rate: 1.5625e-05
# Epoch 98/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7960 - loss: 0.3119 - val_accuracy: 0.8106 - val_loss: 0.3153 - learning_rate: 1.5625e-05
# Epoch 99/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8008 - loss: 0.3092 - val_accuracy: 0.8106 - val_loss: 0.3147 - learning_rate: 1.5625e-05
# Epoch 100/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.3101 - val_accuracy: 0.8099 - val_loss: 0.3146 - learning_rate: 1.5625e-05
# Epoch 101/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8008 - loss: 0.3100 - val_accuracy: 0.8099 - val_loss: 0.3148 - learning_rate: 1.5625e-05
# Epoch 102/200
# 210/216 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7941 - loss: 0.3132
# Epoch 102: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7938 - loss: 0.3130 - val_accuracy: 0.8106 - val_loss: 0.3151 - learning_rate: 1.5625e-05
# Epoch 103/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7924 - loss: 0.3109 - val_accuracy: 0.8099 - val_loss: 0.3152 - learning_rate: 7.8125e-06
# Epoch 104/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7920 - loss: 0.3096 - val_accuracy: 0.8106 - val_loss: 0.3150 - learning_rate: 7.8125e-06
# Epoch 105/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7948 - loss: 0.3103 - val_accuracy: 0.8106 - val_loss: 0.3147 - learning_rate: 7.8125e-06
# Epoch 106/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7970 - loss: 0.3112 - val_accuracy: 0.8106 - val_loss: 0.3147 - learning_rate: 7.8125e-06
# Epoch 106: early stopping
# Restoring model weights from the end of the best epoch: 86.
# MLP training time: 82.77 detik
#
# ================================================================================
# MLP Label-Aware | BEST THRESHOLD = 0.50
# ================================================================================
#
# VALIDATION SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8099
# Balanced Accuracy : 0.8089
# Precision Macro   : 0.8355
# Recall Macro      : 0.8089
# F1 Macro          : 0.8058
# F1 Weighted       : 0.8060
#
# Confusion Matrix:
# [[492 242]
#  [ 39 705]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.93      0.67      0.78       734
#  Label 1 (After)       0.74      0.95      0.83       744
#
#         accuracy                           0.81      1478
#        macro avg       0.84      0.81      0.81      1478
#     weighted avg       0.83      0.81      0.81      1478
#
#
# TEST SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.7962
# Balanced Accuracy : 0.7956
# Precision Macro   : 0.8217
# Recall Macro      : 0.7956
# F1 Macro          : 0.7919
# F1 Weighted       : 0.7920
#
# Confusion Matrix:
# [[483 255]
#  [ 47 697]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.91      0.65      0.76       738
#  Label 1 (After)       0.73      0.94      0.82       744
#
#         accuracy                           0.80      1482
#        macro avg       0.82      0.80      0.79      1482
#     weighted avg       0.82      0.80      0.79      1482
#
#
#
# Evaluasi Ensemble Probability Averaging...
#
# ================================================================================
# Ensemble Label-Aware | BEST THRESHOLD = 0.38
# ================================================================================
#
# VALIDATION SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8227
# Balanced Accuracy : 0.8217
# Precision Macro   : 0.8592
# Recall Macro      : 0.8217
# F1 Macro          : 0.8178
# F1 Weighted       : 0.8180
#
# Confusion Matrix:
# [[486 248]
#  [ 14 730]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.66      0.79       734
#  Label 1 (After)       0.75      0.98      0.85       744
#
#         accuracy                           0.82      1478
#        macro avg       0.86      0.82      0.82      1478
#     weighted avg       0.86      0.82      0.82      1478
#
#
# TEST SET, REAL + SYNTHETIC
# --------------------------------------------------------------------------------
# Accuracy          : 0.8178
# Balanced Accuracy : 0.8171
# Precision Macro   : 0.8568
# Recall Macro      : 0.8171
# F1 Macro          : 0.8125
# F1 Weighted       : 0.8126
#
# Confusion Matrix:
# [[481 257]
#  [ 13 731]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
# Label 0 (Before)       0.97      0.65      0.78       738
#  Label 1 (After)       0.74      0.98      0.84       744
#
#         accuracy                           0.82      1482
#        macro avg       0.86      0.82      0.81      1482
#     weighted avg       0.86      0.82      0.81      1482
#
#
# ================================================================================
# RINGKASAN HASIL LABEL-AWARE MODELS
# ================================================================================
#                        Model  Best Threshold  Val Accuracy  \
# 4       Ensemble Label-Aware            0.38        0.8227
# 1  Random Forest Label-Aware            0.39        0.8248
# 2    Extra Trees Label-Aware            0.45        0.8248
# 3            MLP Label-Aware            0.50        0.8099
# 0            SVM Label-Aware            0.66        0.7855
#
#    Val Balanced Accuracy  Val Macro F1  Val Weighted F1  Test Accuracy  \
# 4                 0.8217        0.8178           0.8180         0.8178
# 1                 0.8237        0.8200           0.8202         0.8178
# 2                 0.8237        0.8201           0.8203         0.8171
# 3                 0.8089        0.8058           0.8060         0.7962
# 0                 0.7868        0.7778           0.7775         0.7861
#
#    Test Balanced Accuracy  Test Macro F1  Test Weighted F1
# 4                  0.8171         0.8125            0.8126
# 1                  0.8171         0.8124            0.8125
# 2                  0.8165         0.8118            0.8120
# 3                  0.7956         0.7919            0.7920
# 0                  0.7869         0.7775            0.7773
# Hasil disimpan sebagai gamma_only_acgan_mixed_label_aware_results.csv
#
# Best threshold per model:
# SVM        : 0.66
# RF         : 0.39
# ExtraTrees : 0.45
# MLP        : 0.50
# Ensemble   : 0.38
